# %%
import pandas as pd
import numpy as np

# %%
user_id = int(input('user id : '))
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# Out:
# user id : 107

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
eat_info =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/eat_info.csv')
cbf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/'+str(user_id)+'_cbf.csv')
ncf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/ncf_scores.csv')

# %%
eat_info
# Out:
#      p_id  Unnamed: 0       name                          address  \
# 0     553           0  원조할아버지손두부                서울특별시 광진구 자양로 324
# 1     383           1       서북면옥              서울특별시 광진구 자양로 199-1
# 2      78           2     궤도에오르다       서울특별시 광진구 광나루로 416 건희빌딩 1F
# 3     715           3        콩이네  서울특별시 광진구 긴고랑로9길 28 중곡제일시장 103호
# 4      45           4      건대우동집       서울특별시 광진구 아차산로 201 동성빌딩 1F
# ..    ...         ...        ...                              ...
# 841   225         841       마우로아             서울특별시 광진구 능동로 320 1F
# 842    81         842        글래시           서울특별시 광진구 능동로 23-14 1F
# 843   215         843         리바    서울특별시 광진구 워커힐로 177 비스타 워커힐 1F
# 844   270         844          몽             서울특별시 광진구 아차산로33길 25
# 845   760         845      페어이너프           서울특별시 광진구 뚝섬로 613-1 2F
#
#              category  price  rvw_cnt   rating  \
# 0    한정식 / 백반 / 정통 한식   5000       72 4.500000
# 1           국수 / 면 요리   5000       94 4.200000
# ...

# %%
 eat_info=eat_info[['p_id','name','address']]

# %%
eat_info
# Out:
#      p_id       name                          address
# 0     553  원조할아버지손두부                서울특별시 광진구 자양로 324
# 1     383       서북면옥              서울특별시 광진구 자양로 199-1
# 2      78     궤도에오르다       서울특별시 광진구 광나루로 416 건희빌딩 1F
# 3     715        콩이네  서울특별시 광진구 긴고랑로9길 28 중곡제일시장 103호
# 4      45      건대우동집       서울특별시 광진구 아차산로 201 동성빌딩 1F
# ..    ...        ...                              ...
# 841   225       마우로아             서울특별시 광진구 능동로 320 1F
# 842    81        글래시           서울특별시 광진구 능동로 23-14 1F
# 843   215         리바    서울특별시 광진구 워커힐로 177 비스타 워커힐 1F
# 844   270          몽             서울특별시 광진구 아차산로33길 25
# 845   760      페어이너프           서울특별시 광진구 뚝섬로 613-1 2F
#
# [846 rows x 3 columns]

# %%
cbf=cbf[['p_id','cbf_score']]
cbf
# Out:
#      p_id  cbf_score
# 0       0   0.000383
# 1       1   0.002406
# 2       2   0.000070
# 3       3   0.000096
# 4       4   0.000569
# ..    ...        ...
# 841   841   0.012272
# 842   842   0.000021
# 843   843   0.000025
# 844   844        NaN
# 845   845        NaN
#
# [846 rows x 2 columns]

# %%
ncf
# Out:
#        u_id       p_id  ncf_score
# 0       107  36.000000   0.249218
# 1       107  79.000000   0.095857
# 2       107 120.000000   0.002111
# 3       107  81.000000   0.474309
# 4       107 350.000000   0.249819
# ...     ...        ...        ...
# 25315   143 786.000000   0.000001
# 25316   143 650.000000   0.000008
# 25317   143 597.000000   0.000632
# 25318   143 685.000000   0.000000
# 25319   143 344.000000   0.000084
#
# [25320 rows x 3 columns]

# %%
ncf=ncf[ncf['u_id']==107]

# %%
ncf
# Out:
#      u_id       p_id  ncf_score
# 0     107  36.000000   0.249218
# 1     107  79.000000   0.095857
# 2     107 120.000000   0.002111
# 3     107  81.000000   0.474309
# 4     107 350.000000   0.249819
# ..    ...        ...        ...
# 839   107 502.000000   0.000000
# 840   107 362.000000   0.000012
# 841   107  96.000000   0.000169
# 842   107 512.000000   0.000050
# 843   107 539.000000   0.000035
#
# [844 rows x 3 columns]

# %%
df=pd.merge(eat_info, cbf, left_on='p_id', right_on ='p_id',how ='left')
df=pd.merge(df, ncf, left_on='p_id', right_on ='p_id',how ='left')
df
# Out:
#      p_id       name                          address  cbf_score       u_id  \
# 0     553  원조할아버지손두부                서울특별시 광진구 자양로 324   0.001554 107.000000
# 1     383       서북면옥              서울특별시 광진구 자양로 199-1   0.000064 107.000000
# 2      78     궤도에오르다       서울특별시 광진구 광나루로 416 건희빌딩 1F   0.000054 107.000000
# 3     715        콩이네  서울특별시 광진구 긴고랑로9길 28 중곡제일시장 103호   0.000015 107.000000
# 4      45      건대우동집       서울특별시 광진구 아차산로 201 동성빌딩 1F   0.000080 107.000000
# ..    ...        ...                              ...        ...        ...
# 841   225       마우로아             서울특별시 광진구 능동로 320 1F   0.000003 107.000000
# 842    81        글래시           서울특별시 광진구 능동로 23-14 1F   0.000001 107.000000
# 843   215         리바    서울특별시 광진구 워커힐로 177 비스타 워커힐 1F   0.000000 107.000000
# 844   270          몽             서울특별시 광진구 아차산로33길 25   0.000000 107.000000
# 845   760      페어이너프           서울특별시 광진구 뚝섬로 613-1 2F   0.000922 107.000000
#
#      ncf_score
# 0     0.002546
# 1     0.000034
# ...

# %%
df['result'] = df['cbf_score'] * df['ncf_score']

# %%
df.sort_values('result',ascending = False).head(10)
# Out:
#      p_id       name                            address  cbf_score       u_id  \
# 280   538        요마시            서울특별시 광진구 천호대로102길 7 1F   0.050955 107.000000
# 825    19   WAVE bar             서울특별시 광진구 능동로19길 18 B1   0.024394 107.000000
# 348   286       미미전병                서울특별시 광진구 뚝섬로27길 55   0.012118 107.000000
# 208   768     포차조개구이                  서울특별시 광진구 용마산로 40   0.028362 107.000000
# 124   382  서민떡볶이야채곱창                  서울특별시 광진구 용마산로 58   0.037072 107.000000
# 562   266    모서리에커피집                 서울특별시 광진구 능동로17길 5   0.007277 107.000000
# 336    27      강경수참치               서울특별시 광진구 아차산로33길 34   0.007047 107.000000
# 307   264        모리본                서울특별시 광진구 긴고랑로15길 6   0.006206 107.000000
# 709   685      카페노어스  서울특별시 광진구 구의강변로 96 현대아파트 6단지상가 1F   0.002625 107.000000
# 224   487      어사랑횟집               서울특별시 광진구 동일로 164 1F   0.002572 107.000000
#
#      ncf_score   result
# 280   0.347397 0.017702
# 825   0.471738 0.011507
# 348   0.356486 0.004320
# ...
