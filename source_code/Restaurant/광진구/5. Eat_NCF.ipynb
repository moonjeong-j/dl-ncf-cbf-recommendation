# %%
pip uninstall scikit-learn -y
# Out:
# Found existing installation: scikit-learn 1.0.2
# Uninstalling scikit-learn-1.0.2:
#   Successfully uninstalled scikit-learn-1.0.2

# %%
pip uninstall cornac -y
# Out:
# Found existing installation: cornac 1.14.2
# Uninstalling cornac-1.14.2:
#   Successfully uninstalled cornac-1.14.2

# %%
pip uninstall tensorflow==2.9.1 -y
# Out:
# Found existing installation: tensorflow 1.15.2
# Uninstalling tensorflow-1.15.2:
#   Successfully uninstalled tensorflow-1.15.2

# %%
pip install scikit-learn==0.22.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 9.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.1.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.4.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.1 which is incompatible.
# Successfully installed scikit-learn-0.22.1

# %%
pip install cornac==1.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cornac==1.6.1
#   Downloading cornac-1.6.1-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 37.5 MB/s
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.7.3)
# Installing collected packages: cornac
# Successfully installed cornac-1.6.1

# %%
pip install tensorflow==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.15.2
#   Downloading tensorflow-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (110.5 MB)
#      |████████████████████████████████| 110.5 MB 40 kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.47.0)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 62.2 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.8.1)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.4 MB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 25.2 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.14.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.37.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=ee121355b55a0a8cc32a1cf4cf948a907153cb13cd157d9bfd1a87d27db4b1ef
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
#     Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.2 tensorflow-estimator-1.15.1

# %%
# pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 33 kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.46.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.15.2

# %%
pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 34 kB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 51.7 MB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 64.1 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.47.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.1 MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=40e5ce2c6e030bf6aa01e2791506912c562f1a3c1a831ef8d56b7063b095a91b
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorboard<2.9,>=2.8, but you have tensorboard 1.15.0 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorflow-estimator<2.9,>=2.8, but you have tensorflow-estimator 1.15.1 which is incompatible.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.2

# %%
# %tensorflow_version 1.15
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# WARNING: Tensorflow 1 is deprecated, and support will be removed on August 1, 2022.
# After that, `%tensorflow_version 1.x` will throw an error.
#
# Your notebook should be updated to use Tensorflow 2.
# See the guide at https://www.tensorflow.org/guide/migrate#migrate-from-tensorflow-1x-to-tensorflow-2.
#
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cornac
import cornac.eval_methods
from cornac.eval_methods import RatioSplit, base_method
from cornac.hyperopt import Continuous, Discrete, RandomSearch
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# 추천할 top k개의 장소
TOP_K = 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_score_board.csv', index_col =0)

# %%
data_df['rating'] =data_df['rating'].astype('float')
data_df = data_df.rename({'u_id':'userID','p_id':'itemID'},axis=1)
#data_df = data_df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
data_df = data_df.fillna(5)

# %%
data_df
# Out:
#       itemID  rating
# u_id
# 0        498     0.0
# 0        332     5.0
# 0        139     0.0
# 0        254     0.0
# 0        199     3.0
# ...      ...     ...
# 2528     279     0.0
# 2529     448     5.0
# 2529     138     5.0
# 2530     357     0.0
# 2531     410     5.0
#
# [7130 rows x 2 columns]

# %%
data_df.reset_index(inplace=True)
data_df
# Out:
#       u_id  itemID  rating
# 0        0     498     0.0
# 1        0     332     5.0
# 2        0     139     0.0
# 3        0     254     0.0
# 4        0     199     3.0
# ...    ...     ...     ...
# 7125  2528     279     0.0
# 7126  2529     448     5.0
# 7127  2529     138     5.0
# 7128  2530     357     0.0
# 7129  2531     410     5.0
#
# [7130 rows x 3 columns]

# %%
data = [tuple(x) for x in data_df.values]
data
# Out:
# [(0.0, 498.0, 0.0),
#  (0.0, 332.0, 5.0),
#  (0.0, 139.0, 0.0),
#  (0.0, 254.0, 0.0),
#  (0.0, 199.0, 3.0),
#  (0.0, 284.0, 3.0),
#  (0.0, 139.0, 0.0),
#  (0.0, 368.0, 3.0),
#  (0.0, 235.0, 3.0),
#  (0.0, 278.0, 5.0),
#  (0.0, 278.0, 5.0),
#  (0.0, 452.0, 3.0),
#  (0.0, 168.0, 5.0),
#  (0.0, 440.0, 3.0),
#  (0.0, 227.0, 5.0),
#  (0.0, 578.0, 3.0),
#  (0.0, 138.0, 3.0),
#  (0.0, 194.0, 0.0),
#  (0.0, 244.0, 3.0),
#  (0.0, 499.0, 5.0),
#  (0.0, 334.0, 3.0),
#  (0.0, 586.0, 5.0),
#  (0.0, 101.0, 3.0),
#  (0.0, 140.0, 0.0),
#  (0.0, 611.0, 3.0),
#  (0.0, 393.0, 0.0),
#  (0.0, 63.0, 3.0),
#  (0.0, 368.0, 5.0),
#  (1.0, 469.0, 0.0),
#  (1.0, 416.0, 5.0),
#  (1.0, 191.0, 3.0),
#  (1.0, 416.0, 5.0),
#  (2.0, 520.0, 3.0),
#  (3.0, 400.0, 5.0),
#  (3.0, 127.0, 5.0),
#  (4.0, 470.0, 3.0),
#  (5.0, 564.0, 3.0),
#  (5.0, 654.0, 3.0),
#  (5.0, 246.0, 3.0),
#  (5.0, 557.0, 3.0),
#  (5.0, 284.0, 5.0),
#  (5.0, 191.0, 3.0),
#  (5.0, 10.0, 3.0),
#  (5.0, 541.0, 3.0),
#  (5.0, 140.0, 3.0),
#  (5.0, 541.0, 0.0),
#  (5.0, 376.0, 3.0),
#  (5.0, 420.0, 5.0),
#  (5.0, 602.0, 5.0),
#  (5.0, 400.0, 3.0),
#  (5.0, 376.0, 3.0),
#  (5.0, 400.0, 5.0),
#  (5.0, 60.0, 0.0),
#  (5.0, 510.0, 3.0),
#  (5.0, 460.0, 0.0),
#  (5.0, 387.0, 3.0),
#  (5.0, 182.0, 0.0),
#  (5.0, 61.0, 0.0),
#  (6.0, 40.0, 5.0),
#  (6.0, 602.0, 5.0),
#  (6.0, 404.0, 0.0),
#  (6.0, 353.0, 0.0),
#  (7.0, 526.0, 0.0),
#  (7.0, 596.0, 3.0),
#  (7.0, 437.0, 3.0),
#  (7.0, 576.0, 0.0),
#  (7.0, 378.0, 5.0),
#  (7.0, 124.0, 3.0),
#  (8.0, 276.0, 5.0),
#  (9.0, 359.0, 0.0),
#  (10.0, 235.0, 5.0),
#  (11.0, 489.0, 5.0),
#  (12.0, 119.0, 0.0),
#  (12.0, 96.0, 5.0),
#  (12.0, 242.0, 3.0),
#  (13.0, 564.0, 3.0),
#  (13.0, 564.0, 5.0),
#  (14.0, 55.0, 5.0),
#  (15.0, 654.0, 3.0),
#  (15.0, 654.0, 3.0),
#  (15.0, 602.0, 5.0),
#  (16.0, 500.0, 5.0),
#  (17.0, 568.0, 5.0),
#  (18.0, 400.0, 5.0),
#  (18.0, 549.0, 3.0),
#  (18.0, 267.0, 3.0),
#  (18.0, 55.0, 3.0),
#  (18.0, 155.0, 0.0),
#  (18.0, 256.0, 0.0),
#  (18.0, 549.0, 3.0),
#  (18.0, 155.0, 0.0),
#  (18.0, 63.0, 3.0),
#  (18.0, 349.0, 0.0),
#  (18.0, 448.0, 3.0),
#  (19.0, 276.0, 5.0),
#  (19.0, 279.0, 3.0),
#  (20.0, 159.0, 3.0),
#  (20.0, 555.0, 3.0),
#  (20.0, 129.0, 5.0),
#  (21.0, 443.0, 0.0),
#  (22.0, 279.0, 3.0),
#  (23.0, 191.0, 5.0),
#  (24.0, 580.0, 5.0),
#  (24.0, 580.0, 5.0),
#  (25.0, 48.0, 3.0),
#  (25.0, 602.0, 5.0),
#  (26.0, 637.0, 5.0),
#  (27.0, 138.0, 5.0),
#  (27.0, 672.0, 5.0),
#  (27.0, 289.0, 3.0),
#  (28.0, 562.0, 5.0),
#  (28.0, 334.0, 5.0),
#  (29.0, 322.0, 0.0),
#  (29.0, 322.0, 0.0),
#  (30.0, 397.0, 0.0),
#  (31.0, 279.0, 5.0),
#  (31.0, 118.0, 3.0),
#  (31.0, 658.0, 0.0),
#  (31.0, 399.0, 5.0),
#  (31.0, 101.0, 3.0),
#  (31.0, 310.0, 5.0),
#  (31.0, 170.0, 0.0),
#  (31.0, 368.0, 3.0),
#  (31.0, 189.0, 5.0),
#  (31.0, 279.0, 5.0),
#  (31.0, 279.0, 5.0),
#  (31.0, 147.0, 3.0),
#  (31.0, 238.0, 0.0),
#  (31.0, 658.0, 5.0),
#  (31.0, 452.0, 5.0),
#  (32.0, 497.0, 3.0),
#  (32.0, 189.0, 5.0),
#  (32.0, 465.0, 0.0),
#  (32.0, 101.0, 3.0),
#  (32.0, 552.0, 0.0),
#  (32.0, 34.0, 5.0),
#  (32.0, 399.0, 3.0),
#  (33.0, 400.0, 5.0),
#  (34.0, 400.0, 5.0),
#  (34.0, 146.0, 5.0),
#  (34.0, 626.0, 5.0),
#  (35.0, 99.0, 5.0),
#  (36.0, 171.0, 5.0),
#  (37.0, 457.0, 5.0),
#  (38.0, 309.0, 5.0),
#  (39.0, 89.0, 3.0),
#  (39.0, 462.0, 0.0),
#  (39.0, 658.0, 3.0),
#  (39.0, 89.0, 3.0),
#  (39.0, 368.0, 3.0),
#  (39.0, 662.0, 5.0),
#  (39.0, 378.0, 3.0),
#  (39.0, 257.0, 5.0),
#  (39.0, 86.0, 5.0),
#  (39.0, 276.0, 5.0),
#  (39.0, 324.0, 5.0),
#  (39.0, 368.0, 3.0),
#  (39.0, 198.0, 3.0),
#  (40.0, 626.0, 0.0),
#  (41.0, 637.0, 0.0),
#  (42.0, 452.0, 0.0),
#  (42.0, 624.0, 5.0),
#  (42.0, 634.0, 5.0),
#  (42.0, 279.0, 3.0),
#  (42.0, 279.0, 3.0),
#  (42.0, 127.0, 5.0),
#  (42.0, 375.0, 5.0),
#  (42.0, 526.0, 3.0),
#  (42.0, 284.0, 5.0),
#  (42.0, 284.0, 5.0),
#  (42.0, 201.0, 5.0),
#  (43.0, 440.0, 3.0),
#  (44.0, 89.0, 5.0),
#  (44.0, 89.0, 5.0),
#  (44.0, 249.0, 5.0),
#  (44.0, 616.0, 3.0),
#  (45.0, 70.0, 5.0),
#  (45.0, 586.0, 5.0),
#  (46.0, 527.0, 3.0),
#  (46.0, 540.0, 3.0),
#  (46.0, 626.0, 5.0),
#  (46.0, 280.0, 3.0),
#  (46.0, 229.0, 5.0),
#  (47.0, 131.0, 5.0),
#  (47.0, 478.0, 5.0),
#  (47.0, 245.0, 5.0),
#  (47.0, 45.0, 3.0),
#  (47.0, 69.0, 0.0),
#  (48.0, 279.0, 5.0),
#  (49.0, 357.0, 5.0),
#  (49.0, 323.0, 5.0),
#  (49.0, 637.0, 5.0),
#  (49.0, 334.0, 5.0),
#  (49.0, 357.0, 5.0),
#  (50.0, 488.0, 0.0),
#  (51.0, 602.0, 5.0),
#  (51.0, 194.0, 5.0),
#  (52.0, 86.0, 5.0),
#  (53.0, 468.0, 0.0),
#  (54.0, 318.0, 3.0),
#  (54.0, 11.0, 3.0),
#  (54.0, 11.0, 3.0),
#  (55.0, 121.0, 3.0),
#  (56.0, 368.0, 3.0),
#  (57.0, 182.0, 3.0),
#  (58.0, 283.0, 5.0),
#  (59.0, 60.0, 5.0),
#  (60.0, 359.0, 5.0),
#  (61.0, 121.0, 5.0),
#  (62.0, 358.0, 5.0),
#  (62.0, 235.0, 3.0),
#  (63.0, 279.0, 5.0),
#  (64.0, 626.0, 5.0),
#  (64.0, 279.0, 5.0),
#  (64.0, 40.0, 5.0),
#  (64.0, 306.0, 5.0),
#  (65.0, 580.0, 5.0),
#  (65.0, 632.0, 0.0),
#  (66.0, 334.0, 0.0),
#  (66.0, 304.0, 3.0),
#  (67.0, 602.0, 3.0),
#  (67.0, 611.0, 3.0),
#  (67.0, 337.0, 5.0),
#  (67.0, 322.0, 3.0),
#  (67.0, 279.0, 3.0),
#  (67.0, 353.0, 3.0),
#  (67.0, 322.0, 3.0),
#  (68.0, 275.0, 5.0),
#  (69.0, 147.0, 5.0),
#  (70.0, 235.0, 5.0),
#  (71.0, 3.0, 5.0),
#  (72.0, 159.0, 0.0),
#  (72.0, 324.0, 5.0),
#  (73.0, 394.0, 3.0),
#  (74.0, 400.0, 5.0),
#  (75.0, 462.0, 0.0),
#  (76.0, 159.0, 0.0),
#  (77.0, 26.0, 5.0),
#  (77.0, 154.0, 5.0),
#  (77.0, 160.0, 5.0),
#  (77.0, 349.0, 5.0),
#  (77.0, 359.0, 3.0),
#  (77.0, 26.0, 5.0),
#  (77.0, 656.0, 3.0),
#  (77.0, 309.0, 5.0),
#  (77.0, 323.0, 5.0),
#  (77.0, 448.0, 5.0),
#  (77.0, 234.0, 3.0),
#  (77.0, 160.0, 5.0),
#  (77.0, 322.0, 5.0),
#  (77.0, 562.0, 5.0),
#  (77.0, 586.0, 3.0),
#  (77.0, 331.0, 5.0),
#  (77.0, 322.0, 5.0),
#  (77.0, 570.0, 5.0),
#  (77.0, 355.0, 5.0),
#  (78.0, 173.0, 3.0),
#  (79.0, 504.0, 5.0),
#  (80.0, 159.0, 0.0),
#  (81.0, 169.0, 3.0),
#  (82.0, 235.0, 5.0),
#  (82.0, 348.0, 5.0),
#  (83.0, 619.0, 3.0),
#  (83.0, 331.0, 5.0),
#  (84.0, 646.0, 0.0),
#  (85.0, 289.0, 0.0),
#  (86.0, 400.0, 0.0),
#  (87.0, 51.0, 3.0),
#  (88.0, 309.0, 5.0),
#  (89.0, 279.0, 5.0),
#  (90.0, 654.0, 5.0),
#  (91.0, 334.0, 5.0),
#  (91.0, 608.0, 5.0),
#  (91.0, 88.0, 5.0),
#  (91.0, 14.0, 5.0),
#  (91.0, 88.0, 5.0),
#  (91.0, 595.0, 5.0),
#  (92.0, 147.0, 3.0),
#  (92.0, 59.0, 0.0),
#  (92.0, 452.0, 3.0),
#  (93.0, 279.0, 3.0),
#  (93.0, 279.0, 3.0),
#  (94.0, 275.0, 3.0),
#  (94.0, 315.0, 5.0),
#  (94.0, 332.0, 3.0),
#  (94.0, 462.0, 5.0),
#  (94.0, 667.0, 5.0),
#  (94.0, 51.0, 3.0),
#  (94.0, 271.0, 3.0),
#  (94.0, 646.0, 3.0),
#  (94.0, 391.0, 5.0),
#  (94.0, 101.0, 3.0),
#  (94.0, 640.0, 3.0),
#  (94.0, 237.0, 3.0),
#  (94.0, 540.0, 3.0),
#  (94.0, 194.0, 3.0),
#  (94.0, 260.0, 3.0),
#  (94.0, 536.0, 3.0),
#  (94.0, 602.0, 5.0),
#  (94.0, 387.0, 3.0),
#  (94.0, 626.0, 3.0),
#  (95.0, 310.0, 5.0),
#  (96.0, 276.0, 5.0),
#  (97.0, 271.0, 3.0),
#  (97.0, 289.0, 5.0),
#  (97.0, 602.0, 5.0),
#  (97.0, 199.0, 5.0),
#  (97.0, 410.0, 5.0),
#  (97.0, 197.0, 5.0),
#  (97.0, 359.0, 5.0),
#  (97.0, 199.0, 0.0),
#  (97.0, 191.0, 5.0),
#  (98.0, 287.0, 3.0),
#  (98.0, 633.0, 3.0),
#  (98.0, 586.0, 5.0),
#  (98.0, 138.0, 3.0),
#  (99.0, 599.0, 5.0),
#  (100.0, 619.0, 3.0),
#  (101.0, 400.0, 0.0),
#  (102.0, 276.0, 5.0),
#  (103.0, 415.0, 5.0),
#  (104.0, 400.0, 0.0),
#  (104.0, 37.0, 3.0),
#  (104.0, 402.0, 5.0),
#  (104.0, 83.0, 3.0),
#  (105.0, 294.0, 3.0),
#  (105.0, 194.0, 5.0),
#  (105.0, 400.0, 5.0),
#  (105.0, 400.0, 5.0),
#  (105.0, 101.0, 3.0),
#  (105.0, 171.0, 5.0),
#  (105.0, 191.0, 5.0),
#  (105.0, 237.0, 3.0),
#  (106.0, 614.0, 5.0),
#  (106.0, 279.0, 5.0),
#  (106.0, 626.0, 5.0),
#  (106.0, 324.0, 5.0),
#  (106.0, 376.0, 5.0),
#  (106.0, 626.0, 5.0),
#  (106.0, 489.0, 5.0),
#  (107.0, 376.0, 3.0),
#  (108.0, 440.0, 5.0),
#  (109.0, 646.0, 0.0),
#  (109.0, 322.0, 5.0),
#  (109.0, 624.0, 0.0),
#  (109.0, 322.0, 5.0),
#  (110.0, 168.0, 5.0),
#  (110.0, 287.0, 5.0),
#  (110.0, 550.0, 5.0),
#  (110.0, 500.0, 5.0),
#  (111.0, 208.0, 5.0),
#  (111.0, 440.0, 3.0),
#  (111.0, 208.0, 5.0),
#  (112.0, 566.0, 3.0),
#  (112.0, 10.0, 0.0),
#  (112.0, 440.0, 5.0),
#  (112.0, 147.0, 3.0),
#  (112.0, 620.0, 0.0),
#  (112.0, 658.0, 0.0),
#  (112.0, 237.0, 3.0),
#  (112.0, 602.0, 5.0),
#  (112.0, 586.0, 3.0),
#  (113.0, 536.0, 5.0),
#  (114.0, 86.0, 5.0),
#  (114.0, 255.0, 5.0),
#  (115.0, 619.0, 5.0),
#  (116.0, 538.0, 0.0),
#  (117.0, 619.0, 5.0),
#  (117.0, 279.0, 5.0),
#  (117.0, 430.0, 5.0),
#  (117.0, 210.0, 5.0),
#  (117.0, 279.0, 5.0),
#  (117.0, 191.0, 5.0),
#  (117.0, 619.0, 5.0),
#  (117.0, 309.0, 5.0),
#  (117.0, 279.0, 5.0),
#  (118.0, 43.0, 5.0),
#  (119.0, 279.0, 5.0),
#  (120.0, 536.0, 5.0),
#  (121.0, 55.0, 3.0),
#  (122.0, 260.0, 5.0),
#  (122.0, 586.0, 5.0),
#  (122.0, 420.0, 3.0),
#  (123.0, 115.0, 5.0),
#  (123.0, 97.0, 3.0),
#  (124.0, 566.0, 0.0),
#  (125.0, 301.0, 5.0),
#  (126.0, 145.0, 3.0),
#  (127.0, 120.0, 5.0),
#  (127.0, 608.0, 5.0),
#  (127.0, 466.0, 5.0),
#  (128.0, 70.0, 5.0),
#  (128.0, 400.0, 5.0),
#  (129.0, 281.0, 3.0),
#  (129.0, 623.0, 3.0),
#  (129.0, 509.0, 5.0),
#  (129.0, 63.0, 5.0),
#  (129.0, 658.0, 5.0),
#  (130.0, 199.0, 0.0),
#  (131.0, 242.0, 0.0),
#  (131.0, 86.0, 5.0),
#  (131.0, 497.0, 3.0),
#  (131.0, 294.0, 3.0),
#  (132.0, 191.0, 3.0),
#  (132.0, 306.0, 5.0),
#  (133.0, 279.0, 5.0),
#  (134.0, 171.0, 5.0),
#  (135.0, 279.0, 5.0),
#  (135.0, 104.0, 5.0),
#  (135.0, 440.0, 5.0),
#  (136.0, 400.0, 5.0),
#  (136.0, 469.0, 3.0),
#  (137.0, 191.0, 5.0),
#  (138.0, 86.0, 5.0),
#  (138.0, 104.0, 3.0),
#  (139.0, 654.0, 5.0),
#  (140.0, 359.0, 3.0),
#  (140.0, 359.0, 5.0),
#  (140.0, 469.0, 3.0),
#  (140.0, 400.0, 5.0),
#  (140.0, 626.0, 5.0),
#  (140.0, 337.0, 3.0),
#  (140.0, 55.0, 5.0),
#  (141.0, 602.0, 5.0),
#  (142.0, 292.0, 3.0),
#  (142.0, 309.0, 5.0),
#  (142.0, 79.0, 3.0),
#  (142.0, 79.0, 3.0),
#  (143.0, 420.0, 0.0),
#  (144.0, 129.0, 5.0),
#  (144.0, 171.0, 5.0),
#  (144.0, 171.0, 5.0),
#  (144.0, 171.0, 5.0),
#  (144.0, 138.0, 5.0),
#  (144.0, 171.0, 5.0),
#  (145.0, 359.0, 0.0),
#  (146.0, 237.0, 3.0),
#  (146.0, 654.0, 3.0),
#  (146.0, 371.0, 3.0),
#  (146.0, 399.0, 3.0),
#  (146.0, 455.0, 5.0),
#  (146.0, 246.0, 0.0),
#  (146.0, 376.0, 5.0),
#  (146.0, 645.0, 3.0),
#  (147.0, 331.0, 3.0),
#  (148.0, 309.0, 5.0),
#  (149.0, 526.0, 0.0),
#  (149.0, 658.0, 3.0),
#  (149.0, 191.0, 3.0),
#  (149.0, 191.0, 0.0),
#  (150.0, 246.0, 5.0),
#  (150.0, 40.0, 3.0),
#  (150.0, 246.0, 5.0),
#  (151.0, 207.0, 3.0),
#  (151.0, 602.0, 5.0),
#  (151.0, 337.0, 5.0),
#  (151.0, 546.0, 5.0),
#  (152.0, 72.0, 5.0),
#  (152.0, 45.0, 5.0),
#  (152.0, 208.0, 5.0),
#  (152.0, 70.0, 3.0),
#  (152.0, 246.0, 3.0),
#  (152.0, 208.0, 5.0),
#  (152.0, 654.0, 5.0),
#  (152.0, 654.0, 5.0),
#  (152.0, 563.0, 3.0),
#  (152.0, 443.0, 5.0),
#  (152.0, 80.0, 5.0),
#  (153.0, 359.0, 3.0),
#  (153.0, 364.0, 5.0),
#  (154.0, 654.0, 5.0),
#  (155.0, 415.0, 5.0),
#  (156.0, 203.0, 3.0),
#  (157.0, 171.0, 5.0),
#  (158.0, 60.0, 3.0),
#  (159.0, 331.0, 3.0),
#  (159.0, 626.0, 3.0),
#  (159.0, 654.0, 3.0),
#  (159.0, 37.0, 0.0),
#  (160.0, 37.0, 5.0),
#  (160.0, 86.0, 5.0),
#  (161.0, 191.0, 3.0),
#  (162.0, 260.0, 5.0),
#  (163.0, 191.0, 5.0),
#  (163.0, 199.0, 5.0),
#  (163.0, 279.0, 3.0),
#  (163.0, 96.0, 3.0),
#  (163.0, 626.0, 5.0),
#  (163.0, 191.0, 5.0),
#  (163.0, 7.0, 0.0),
#  (163.0, 400.0, 3.0),
#  (163.0, 191.0, 3.0),
#  (163.0, 626.0, 5.0),
#  (163.0, 626.0, 5.0),
#  (163.0, 602.0, 5.0),
#  (163.0, 637.0, 5.0),
#  (163.0, 626.0, 5.0),
#  (164.0, 229.0, 0.0),
#  (165.0, 359.0, 0.0),
#  (166.0, 454.0, 3.0),
#  (166.0, 309.0, 5.0),
#  (166.0, 454.0, 3.0),
#  (166.0, 563.0, 5.0),
#  (166.0, 654.0, 3.0),
#  (166.0, 387.0, 5.0),
#  (166.0, 654.0, 3.0),
#  (166.0, 329.0, 5.0),
#  (166.0, 562.0, 5.0),
#  (166.0, 416.0, 5.0),
#  (166.0, 359.0, 0.0),
#  (166.0, 448.0, 3.0),
#  (166.0, 416.0, 5.0),
#  (167.0, 645.0, 0.0),
#  (167.0, 433.0, 3.0),
#  (167.0, 276.0, 3.0),
#  (167.0, 348.0, 0.0),
#  (167.0, 247.0, 3.0),
#  (168.0, 633.0, 5.0),
#  (168.0, 400.0, 5.0),
#  (168.0, 619.0, 3.0),
#  (168.0, 224.0, 3.0),
#  (169.0, 208.0, 5.0),
#  (169.0, 440.0, 5.0),
#  (169.0, 208.0, 5.0),
#  (170.0, 416.0, 0.0),
#  (170.0, 416.0, 0.0),
#  (171.0, 294.0, 3.0),
#  (172.0, 191.0, 0.0),
#  (172.0, 400.0, 5.0),
#  (172.0, 369.0, 5.0),
#  (172.0, 276.0, 5.0),
#  (173.0, 410.0, 5.0),
#  (174.0, 645.0, 0.0),
#  (175.0, 26.0, 5.0),
#  (175.0, 26.0, 5.0),
#  (176.0, 229.0, 5.0),
#  (177.0, 613.0, 5.0),
#  (177.0, 404.0, 3.0),
#  (177.0, 191.0, 5.0),
#  (177.0, 637.0, 0.0),
#  (177.0, 646.0, 0.0),
#  (177.0, 584.0, 5.0),
#  (177.0, 275.0, 3.0),
#  (177.0, 39.0, 5.0),
#  (178.0, 580.0, 3.0),
#  (179.0, 359.0, 3.0),
#  (179.0, 194.0, 5.0),
#  (180.0, 386.0, 5.0),
#  (181.0, 400.0, 5.0),
#  (182.0, 279.0, 3.0),
#  (183.0, 387.0, 3.0),
#  (184.0, 101.0, 3.0),
#  (185.0, 63.0, 5.0),
#  (185.0, 89.0, 5.0),
#  (185.0, 208.0, 0.0),
#  (185.0, 334.0, 5.0),
#  (185.0, 208.0, 0.0),
#  (185.0, 89.0, 5.0),
#  (186.0, 489.0, 5.0),
#  (186.0, 371.0, 5.0),
#  (187.0, 101.0, 0.0),
#  (187.0, 279.0, 5.0),
#  (187.0, 191.0, 5.0),
#  (187.0, 509.0, 5.0),
#  (188.0, 602.0, 5.0),
#  (189.0, 448.0, 5.0),
#  (189.0, 171.0, 5.0),
#  (190.0, 284.0, 5.0),
#  (190.0, 199.0, 5.0),
#  (190.0, 337.0, 5.0),
#  (190.0, 619.0, 5.0),
#  (191.0, 115.0, 5.0),
#  (191.0, 159.0, 3.0),
#  (191.0, 60.0, 3.0),
#  (191.0, 476.0, 0.0),
#  (191.0, 619.0, 3.0),
#  (191.0, 83.0, 0.0),
#  (191.0, 118.0, 5.0),
#  (191.0, 199.0, 5.0),
#  (191.0, 309.0, 3.0),
#  (191.0, 580.0, 3.0),
#  (192.0, 400.0, 5.0),
#  (192.0, 199.0, 5.0),
#  (192.0, 440.0, 5.0),
#  (192.0, 279.0, 3.0),
#  (192.0, 70.0, 5.0),
#  (193.0, 63.0, 5.0),
#  (193.0, 443.0, 3.0),
#  (193.0, 403.0, 5.0),
#  (193.0, 375.0, 5.0),
#  (193.0, 242.0, 3.0),
#  (194.0, 579.0, 5.0),
#  (194.0, 654.0, 3.0),
#  (195.0, 475.0, 5.0),
#  (196.0, 37.0, 5.0),
#  (196.0, 374.0, 5.0),
#  (196.0, 322.0, 5.0),
#  (196.0, 159.0, 5.0),
#  (196.0, 403.0, 5.0),
#  (196.0, 284.0, 5.0),
#  (196.0, 374.0, 5.0),
#  (196.0, 306.0, 3.0),
#  (196.0, 55.0, 5.0),
#  (196.0, 374.0, 5.0),
#  (196.0, 151.0, 3.0),
#  (196.0, 306.0, 3.0),
#  (196.0, 159.0, 5.0),
#  (196.0, 279.0, 3.0),
#  (196.0, 540.0, 3.0),
#  (196.0, 322.0, 5.0),
#  (196.0, 101.0, 3.0),
#  (196.0, 289.0, 3.0),
#  (196.0, 306.0, 3.0),
#  (196.0, 306.0, 5.0),
#  (196.0, 37.0, 5.0),
#  (196.0, 637.0, 5.0),
#  (197.0, 420.0, 3.0),
#  (197.0, 191.0, 5.0),
#  (197.0, 289.0, 5.0),
#  (197.0, 86.0, 5.0),
#  (197.0, 279.0, 3.0),
#  (198.0, 409.0, 5.0),
#  (199.0, 68.0, 5.0),
#  (200.0, 400.0, 5.0),
#  (201.0, 194.0, 0.0),
#  (201.0, 189.0, 5.0),
#  (202.0, 138.0, 3.0),
#  (203.0, 619.0, 5.0),
#  (204.0, 60.0, 5.0),
#  (205.0, 602.0, 3.0),
#  (205.0, 194.0, 5.0),
#  (206.0, 160.0, 5.0),
#  (206.0, 637.0, 5.0),
#  (206.0, 448.0, 5.0),
#  (206.0, 231.0, 5.0),
#  (206.0, 615.0, 5.0),
#  (206.0, 591.0, 5.0),
#  (206.0, 398.0, 5.0),
#  (206.0, 257.0, 5.0),
#  (206.0, 474.0, 5.0),
#  (206.0, 648.0, 0.0),
#  (207.0, 479.0, 5.0),
#  (207.0, 279.0, 5.0),
#  (207.0, 376.0, 5.0),
#  (207.0, 403.0, 5.0),
#  (208.0, 150.0, 5.0),
#  (209.0, 235.0, 3.0),
#  (210.0, 129.0, 5.0),
#  (211.0, 416.0, 3.0),
#  (212.0, 378.0, 5.0),
#  (212.0, 267.0, 5.0),
#  (212.0, 359.0, 5.0),
#  (213.0, 129.0, 0.0),
#  (214.0, 279.0, 5.0),
#  (214.0, 640.0, 5.0),
#  (214.0, 543.0, 5.0),
#  (214.0, 235.0, 3.0),
#  (214.0, 296.0, 5.0),
#  (214.0, 400.0, 5.0),
#  (214.0, 448.0, 5.0),
#  (214.0, 55.0, 5.0),
#  (214.0, 309.0, 5.0),
#  (214.0, 70.0, 5.0),
#  (214.0, 440.0, 5.0),
#  (214.0, 619.0, 5.0),
#  (214.0, 196.0, 5.0),
#  (214.0, 177.0, 5.0),
#  (215.0, 620.0, 5.0),
#  (215.0, 309.0, 0.0),
#  (215.0, 620.0, 5.0),
#  (215.0, 83.0, 5.0),
#  (216.0, 371.0, 3.0),
#  (217.0, 118.0, 5.0),
#  (218.0, 440.0, 3.0),
#  (219.0, 591.0, 5.0),
#  (220.0, 199.0, 5.0),
#  (221.0, 296.0, 3.0),
#  (221.0, 400.0, 3.0),
#  (221.0, 194.0, 5.0),
#  (221.0, 45.0, 5.0),
#  (221.0, 440.0, 3.0),
#  (221.0, 420.0, 5.0),
#  (221.0, 637.0, 5.0),
#  (221.0, 394.0, 5.0),
#  (221.0, 400.0, 5.0),
#  (221.0, 400.0, 5.0),
#  (221.0, 191.0, 5.0),
#  (221.0, 602.0, 5.0),
#  (221.0, 536.0, 5.0),
#  (221.0, 309.0, 5.0),
#  (221.0, 279.0, 3.0),
#  (221.0, 235.0, 5.0),
#  (221.0, 129.0, 5.0),
#  (221.0, 279.0, 5.0),
#  (221.0, 637.0, 5.0),
#  (221.0, 348.0, 5.0),
#  (221.0, 536.0, 3.0),
#  (222.0, 464.0, 3.0),
#  (223.0, 602.0, 3.0),
#  (223.0, 37.0, 5.0),
#  (223.0, 171.0, 5.0),
#  (224.0, 350.0, 3.0),
#  (224.0, 11.0, 5.0),
#  (224.0, 549.0, 5.0),
#  (224.0, 626.0, 3.0),
#  (224.0, 37.0, 5.0),
#  (224.0, 86.0, 5.0),
#  (224.0, 182.0, 3.0),
#  (224.0, 503.0, 3.0),
#  (224.0, 446.0, 5.0),
#  (224.0, 549.0, 5.0),
#  (224.0, 63.0, 5.0),
#  (224.0, 194.0, 5.0),
#  (224.0, 662.0, 5.0),
#  (224.0, 11.0, 5.0),
#  (224.0, 24.0, 5.0),
#  (224.0, 80.0, 3.0),
#  (224.0, 415.0, 5.0),
#  (224.0, 37.0, 5.0),
#  (224.0, 470.0, 5.0),
#  (224.0, 654.0, 5.0),
#  (224.0, 646.0, 5.0),
#  (224.0, 440.0, 5.0),
#  (224.0, 547.0, 3.0),
#  (224.0, 517.0, 5.0),
#  (224.0, 136.0, 5.0),
#  (224.0, 169.0, 3.0),
#  (224.0, 99.0, 5.0),
#  (224.0, 654.0, 5.0),
#  (224.0, 129.0, 3.0),
#  (224.0, 254.0, 3.0),
#  (224.0, 55.0, 3.0),
#  (224.0, 359.0, 5.0),
#  (224.0, 407.0, 3.0),
#  (224.0, 455.0, 5.0),
#  (225.0, 209.0, 5.0),
#  (226.0, 53.0, 5.0),
#  (226.0, 646.0, 0.0),
#  (226.0, 520.0, 5.0),
#  (226.0, 53.0, 5.0),
#  (227.0, 662.0, 0.0),
#  (228.0, 197.0, 5.0),
#  (229.0, 99.0, 5.0),
#  (230.0, 309.0, 5.0),
#  (231.0, 646.0, 0.0),
#  (232.0, 191.0, 5.0),
#  (233.0, 96.0, 0.0),
#  (234.0, 171.0, 5.0),
#  (235.0, 289.0, 5.0),
#  (236.0, 276.0, 0.0),
#  (237.0, 191.0, 5.0),
#  (238.0, 386.0, 5.0),
#  (239.0, 344.0, 3.0),
#  (240.0, 602.0, 3.0),
#  (241.0, 309.0, 3.0),
#  (242.0, 348.0, 5.0),
#  (243.0, 391.0, 5.0),
#  (244.0, 279.0, 5.0),
#  (245.0, 279.0, 5.0),
#  (245.0, 230.0, 5.0),
#  (245.0, 191.0, 5.0),
#  (245.0, 359.0, 5.0),
#  (245.0, 400.0, 5.0),
#  (246.0, 646.0, 0.0),
#  (246.0, 103.0, 3.0),
#  (247.0, 279.0, 5.0),
#  (248.0, 400.0, 5.0),
#  (249.0, 403.0, 5.0),
#  (250.0, 578.0, 0.0),
#  (250.0, 481.0, 5.0),
#  (251.0, 138.0, 0.0),
#  (251.0, 321.0, 5.0),
#  (251.0, 524.0, 5.0),
#  (252.0, 45.0, 3.0),
#  (253.0, 200.0, 3.0),
#  (254.0, 309.0, 5.0),
#  (254.0, 400.0, 5.0),
#  (255.0, 245.0, 5.0),
#  (255.0, 32.0, 3.0),
#  (255.0, 348.0, 3.0),
#  (256.0, 420.0, 0.0),
#  (257.0, 55.0, 3.0),
#  (257.0, 602.0, 5.0),
#  (258.0, 281.0, 5.0),
#  (259.0, 57.0, 5.0),
#  (260.0, 481.0, 5.0),
#  (261.0, 469.0, 0.0),
#  (262.0, 279.0, 5.0),
#  (263.0, 70.0, 3.0),
#  (263.0, 279.0, 5.0),
#  (264.0, 632.0, 5.0),
#  (265.0, 480.0, 3.0),
#  (266.0, 440.0, 0.0),
#  (267.0, 400.0, 5.0),
#  (267.0, 279.0, 0.0),
#  (267.0, 309.0, 5.0),
#  (267.0, 529.0, 0.0),
#  (267.0, 529.0, 0.0),
#  (267.0, 279.0, 0.0),
#  (267.0, 579.0, 0.0),
#  (267.0, 24.0, 5.0),
#  (267.0, 464.0, 5.0),
#  (267.0, 154.0, 5.0),
#  (267.0, 55.0, 3.0),
#  (267.0, 279.0, 0.0),
#  (267.0, 191.0, 5.0),
#  (267.0, 52.0, 5.0),
#  (267.0, 154.0, 5.0),
#  (267.0, 359.0, 0.0),
#  (267.0, 145.0, 5.0),
#  (267.0, 619.0, 3.0),
#  (267.0, 39.0, 3.0),
#  (267.0, 191.0, 5.0),
#  (268.0, 169.0, 3.0),
#  (268.0, 272.0, 5.0),
#  (269.0, 637.0, 5.0),
#  (270.0, 608.0, 5.0),
#  (271.0, 387.0, 3.0),
#  (271.0, 376.0, 3.0),
#  (272.0, 191.0, 5.0),
#  (272.0, 415.0, 5.0),
#  (272.0, 86.0, 5.0),
#  (272.0, 191.0, 5.0),
#  (272.0, 393.0, 5.0),
#  (273.0, 654.0, 5.0),
#  (273.0, 65.0, 0.0),
#  (273.0, 655.0, 5.0),
#  (273.0, 359.0, 5.0),
#  (273.0, 279.0, 3.0),
#  (273.0, 210.0, 3.0),
#  (274.0, 191.0, 0.0),
#  (275.0, 123.0, 5.0),
#  (275.0, 329.0, 5.0),
#  (275.0, 292.0, 5.0),
#  (276.0, 86.0, 5.0),
#  (276.0, 616.0, 3.0),
#  (276.0, 260.0, 5.0),
#  (276.0, 462.0, 5.0),
#  (276.0, 237.0, 3.0),
#  (277.0, 26.0, 5.0),
#  (277.0, 26.0, 5.0),
#  (278.0, 209.0, 5.0),
#  (279.0, 550.0, 5.0),
#  (279.0, 415.0, 5.0),
#  (280.0, 507.0, 3.0),
#  (281.0, 11.0, 5.0),
#  (282.0, 46.0, 0.0),
#  (283.0, 602.0, 5.0),
#  (284.0, 349.0, 5.0),
#  (285.0, 393.0, 5.0),
#  (286.0, 191.0, 5.0),
#  (287.0, 626.0, 3.0),
#  (288.0, 180.0, 3.0),
#  (288.0, 602.0, 3.0),
#  (288.0, 448.0, 5.0),
#  (288.0, 199.0, 5.0),
#  (288.0, 348.0, 0.0),
#  (289.0, 70.0, 3.0),
#  (289.0, 51.0, 5.0),
#  (289.0, 279.0, 3.0),
#  (290.0, 334.0, 5.0),
#  (291.0, 410.0, 3.0),
#  (291.0, 64.0, 5.0),
#  (292.0, 526.0, 5.0),
#  (293.0, 73.0, 5.0),
#  (294.0, 104.0, 3.0),
#  (294.0, 191.0, 5.0),
#  (294.0, 279.0, 5.0),
#  (294.0, 404.0, 3.0),
#  (295.0, 462.0, 0.0),
#  (295.0, 229.0, 0.0),
#  (296.0, 309.0, 5.0),
#  (297.0, 440.0, 3.0),
#  (297.0, 550.0, 3.0),
#  (297.0, 199.0, 5.0),
#  (298.0, 262.0, 5.0),
#  (299.0, 621.0, 5.0),
#  (299.0, 159.0, 5.0),
#  (300.0, 197.0, 5.0),
#  (300.0, 332.0, 3.0),
#  (300.0, 331.0, 0.0),
#  (300.0, 197.0, 5.0),
#  (300.0, 197.0, 5.0),
#  (300.0, 257.0, 0.0),
#  (300.0, 209.0, 0.0),
#  (300.0, 197.0, 5.0),
#  (301.0, 397.0, 3.0),
#  (302.0, 646.0, 3.0),
#  (302.0, 619.0, 5.0),
#  (303.0, 276.0, 5.0),
#  (304.0, 637.0, 3.0),
#  (305.0, 276.0, 5.0),
#  (305.0, 550.0, 5.0),
#  (305.0, 359.0, 5.0),
#  (305.0, 440.0, 5.0),
#  (306.0, 147.0, 5.0),
#  (307.0, 440.0, 3.0),
#  (308.0, 614.0, 3.0),
#  (309.0, 52.0, 3.0),
#  (309.0, 470.0, 3.0),
#  (309.0, 440.0, 3.0),
#  (309.0, 440.0, 3.0),
#  (309.0, 101.0, 3.0),
#  (309.0, 194.0, 3.0),
#  (309.0, 199.0, 3.0),
#  (309.0, 356.0, 5.0),
#  (310.0, 13.0, 3.0),
#  (310.0, 168.0, 5.0),
#  (310.0, 398.0, 5.0),
#  (310.0, 540.0, 3.0),
#  (311.0, 215.0, 3.0),
#  (312.0, 481.0, 3.0),
#  (313.0, 602.0, 5.0),
#  (314.0, 279.0, 5.0),
#  (315.0, 89.0, 3.0),
#  (315.0, 89.0, 3.0),
#  (315.0, 359.0, 3.0),
#  (316.0, 440.0, 0.0),
#  (316.0, 101.0, 3.0),
#  (316.0, 138.0, 5.0),
#  (316.0, 63.0, 5.0),
#  (317.0, 191.0, 5.0),
#  (318.0, 619.0, 0.0),
#  (318.0, 191.0, 5.0),
#  (319.0, 217.0, 5.0),
#  (320.0, 649.0, 5.0),
#  (321.0, 279.0, 5.0),
#  (322.0, 229.0, 3.0),
#  (322.0, 294.0, 3.0),
#  (322.0, 632.0, 3.0),
#  (322.0, 332.0, 5.0),
#  (322.0, 584.0, 3.0),
#  (322.0, 459.0, 3.0),
#  (322.0, 672.0, 3.0),
#  (322.0, 127.0, 3.0),
#  (322.0, 523.0, 3.0),
#  (322.0, 509.0, 3.0),
#  (322.0, 358.0, 3.0),
#  (322.0, 658.0, 5.0),
#  (322.0, 440.0, 3.0),
#  (322.0, 358.0, 3.0),
#  (322.0, 358.0, 3.0),
#  (322.0, 658.0, 3.0),
#  (322.0, 589.0, 3.0),
#  (322.0, 235.0, 5.0),
#  (322.0, 577.0, 5.0),
#  (323.0, 306.0, 5.0),
#  (324.0, 101.0, 5.0),
#  (324.0, 400.0, 5.0),
#  (325.0, 70.0, 5.0),
#  (326.0, 400.0, 0.0),
#  (327.0, 586.0, 5.0),
#  (327.0, 159.0, 0.0),
#  (327.0, 182.0, 5.0),
#  (327.0, 275.0, 5.0),
#  (327.0, 275.0, 5.0),
#  (327.0, 376.0, 0.0),
#  (328.0, 229.0, 0.0),
#  (329.0, 199.0, 5.0),
#  (329.0, 637.0, 5.0),
#  (329.0, 448.0, 5.0),
#  (329.0, 70.0, 5.0),
#  (329.0, 295.0, 5.0),
#  (330.0, 296.0, 3.0),
#  (331.0, 191.0, 5.0),
#  (331.0, 566.0, 3.0),
#  (331.0, 654.0, 5.0),
#  (331.0, 279.0, 5.0),
#  (332.0, 617.0, 5.0),
#  (333.0, 191.0, 5.0),
#  (334.0, 359.0, 0.0),
#  (335.0, 415.0, 0.0),
#  (336.0, 65.0, 5.0),
#  (336.0, 210.0, 5.0),
#  (336.0, 210.0, 5.0),
#  (337.0, 191.0, 5.0),
#  (337.0, 60.0, 3.0),
#  (337.0, 626.0, 5.0),
#  (337.0, 279.0, 5.0),
#  (338.0, 448.0, 5.0),
#  (339.0, 257.0, 5.0),
#  (340.0, 580.0, 5.0),
#  (340.0, 188.0, 5.0),
#  (341.0, 284.0, 5.0),
#  (342.0, 440.0, 3.0),
#  (343.0, 97.0, 5.0),
#  (344.0, 632.0, 0.0),
#  (345.0, 550.0, 5.0),
#  (345.0, 619.0, 5.0),
#  (345.0, 89.0, 5.0),
#  (345.0, 89.0, 5.0),
#  (345.0, 440.0, 3.0),
#  (346.0, 626.0, 5.0),
#  (347.0, 616.0, 3.0),
#  (347.0, 189.0, 5.0),
#  (347.0, 189.0, 5.0),
#  (347.0, 637.0, 3.0),
#  (347.0, 512.0, 3.0),
#  (348.0, 138.0, 5.0),
#  (349.0, 178.0, 5.0),
#  ...]

# %%
ncf = cornac.models.recommender.Recommender('NeuMF')
ncf.early_stop
# Out:
# <bound method Recommender.early_stop of <cornac.models.recommender.Recommender object at 0x7fb7986dd610>>

# %%
# Instantiate evaluation metrics
ndcg = cornac.metrics.NDCG(k=TOP_K)
pre = cornac.metrics.Precision(k=TOP_K)
rec = cornac.metrics.Recall(k=TOP_K)
fm = cornac.metrics.FMeasure(k=TOP_K)

# %%
#Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=data,
    test_size=0.1,
    val_size=0.1,
    rating_threshold=1.0,
    seed=123,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_neg=50,
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

# RandomSearch
rs_neumf = RandomSearch(
    model = neumf,
    space=[
        Discrete("num_epochs", [50, 100, 150, 200]),
        Discrete("num_factors", [4, 8]),
        Discrete("batch_size", [128, 256, 512]),
        Continuous("lr", 0.001, 0.01)
    ],
    metric = fm,
    eval_method = ratio_split
)
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 2220
# Number of items = 628
# Number of ratings = 5223
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 3.9
# ---
# Test data:
# Number of users = 373
# Number of items = 215
# Number of ratings = 529
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Validation data:
# Number of users = 350
# Number of items = 207
# Number of ratings = 505
# ---
# Total users = 2220
# Total items = 628

# %%
# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[rs_neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# [RandomSearch_NeuMF] Training started!
# Evaluating: {'batch_size': 512, 'lr': 0.007416597884709045, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.200591 (delta = -0.010448)
# Evaluating: {'batch_size': 512, 'lr': 0.005961832921746022, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 5, stopped epoch = 10
# - best monitored value = 0.207549 (delta = -0.014070)
# Evaluating: {'batch_size': 256, 'lr': 0.00982687778546154, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 14, stopped epoch = 19
# - best monitored value = 0.238005 (delta = -0.001994)
# Evaluating: {'batch_size': 512, 'lr': 0.002259556863673461, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 12, stopped epoch = 17
# - best monitored value = 0.204113 (delta = -0.000767)
# Evaluating: {'batch_size': 128, 'lr': 0.0075614473664563754, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 12, stopped epoch = 17
# - best monitored value = 0.212440 (delta = -0.003764)
# Evaluating: {'batch_size': 256, 'lr': 0.007252796594667422, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 3, stopped epoch = 8
# - best monitored value = 0.201748 (delta = -0.007662)
# Evaluating: {'batch_size': 256, 'lr': 0.0026424255740815, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 3, stopped epoch = 8
# - best monitored value = 0.206983 (delta = -0.007545)
# Evaluating: {'batch_size': 512, 'lr': 0.0057864482838717955, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 5, stopped epoch = 10
# - best monitored value = 0.208296 (delta = -0.022218)
# Evaluating: {'batch_size': 128, 'lr': 0.005428762991131081, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 3, stopped epoch = 8
# - best monitored value = 0.204616 (delta = -0.015145)
# Evaluating: {'batch_size': 128, 'lr': 0.007501990443131995, 'num_epochs': 100, 'num_factors': 8}
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 13, stopped epoch = 18
# - best monitored value = 0.236887 (delta = -0.004249)
# Best parameter settings: {'batch_size': 128, 'lr': 0.007501990443131995, 'num_epochs': 100, 'num_factors': 8}
# F1@5 = 0.0642
#
# [RandomSearch_NeuMF] Evaluation started!
# Ranking:   0%|          | 0/373 [00:00<?, ?it/s]
# Ranking:   0%|          | 0/350 [00:00<?, ?it/s]
# VALIDATION:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Time (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------
# RandomSearch_NeuMF | 0.0642 | 0.1288 |      0.0414 |   0.1655 |   0.5901
#
# TEST:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------- + --------
# RandomSearch_NeuMF | 0.0618 | 0.1251 |      0.0394 |   0.1658 |  654.2181 |   0.6216

# %%
print('Random search: ', rs_neumf.best_params)
# Out:
# Random search:  {'batch_size': 128, 'lr': 0.007501990443131995, 'num_epochs': 100, 'num_factors': 8}

# %%
ratio_split = RatioSplit(
    data=data,
    test_size=0,
    rating_threshold=1.0,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    num_factors = rs_neumf.best_params['num_factors'],
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_epochs = rs_neumf.best_params['num_epochs'],
    lr=rs_neumf.best_params['lr'],
    num_neg=50,
    batch_size = rs_neumf.best_params['batch_size'],
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 2532
# Number of items = 673
# Number of ratings = 6383
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 3.9
# ---
# Test data:
# Number of users = 2532
# Number of items = 673
# Number of ratings = 6383
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 2532
# Total items = 673
#
# [NeuMF] Training started!
#   0%|          | 0/100 [00:00<?, ?it/s]
# [NeuMF] Evaluation started!
# Ranking:   0%|          | 0/2532 [00:00<?, ?it/s]
# TEST:
# ...
#       |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ----- + ------ + ------ + ----------- + -------- + --------- + --------
# NeuMF | 0.4738 | 0.9881 |      0.3799 |   0.9542 |  585.8294 |   3.5808

# %%
# import pandas as pd
# pred_user = pd.read_csv('../../common/data/survey_result.csv')
# pred_user = set(pred_user['u_id'])

# %%
all_prediction = pd.DataFrame(columns=['u_id','p_id','ncf_score'])

for u_idx, u_id in tqdm(enumerate(data_df['u_id'].unique())):
  
      tmp = pd.DataFrame(neumf.rank(u_idx)).T
      tmp['u_id'] = u_id
      tmp = pd.DataFrame(tmp,columns=['u_id',0,1])
      tmp.rename(columns={0:'p_id',1:'ncf_score'}, inplace=True)
      all_prediction = all_prediction.append(tmp)
# Out:
# 2532it [01:27, 28.86it/s]

# %%
all_prediction
# Out:
#      u_id   p_id     ncf_score
# 0       0   26.0  9.988504e-01
# 1       0  207.0  9.193783e-01
# 2       0  198.0  8.940697e-08
# 3       0  454.0  1.193486e-01
# 4       0   43.0  1.192093e-07
# ..    ...    ...           ...
# 668  2531  428.0  0.000000e+00
# 669  2531  427.0  0.000000e+00
# 670  2531  426.0  0.000000e+00
# 671  2531  425.0  0.000000e+00
# 672  2531    0.0  4.334912e-08
#
# [1704036 rows x 3 columns]

# %%
len(all_prediction['u_id']==107)
# Out:
# 1704036

# %%
all_prediction.to_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/광진구_restuarant_ncf_scores.csv',index=False)

# %%
a = pd.DataFrame(neumf.rank(1)).T
a
# Out:
#          0         1
# 0    150.0  0.000000
# 1      7.0  0.999925
# 2      1.0  0.002877
# 3     35.0  0.512236
# 4     83.0  0.000000
# ..     ...       ...
# 668  438.0  0.000000
# 669  437.0  0.000000
# 670  436.0  0.000000
# 671  435.0  0.000000
# 672    0.0  0.000000
#
# [673 rows x 2 columns]

# %%
len(a.iloc[:,0].unique())
# Out:
# 673

# %%
# a = pd.DataFrame(neumf.rank(2)).T
# a

# %%
len(a.iloc[:,0].unique())
# Out:
# 673

# %%
a.to_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_exxxx2')

# %%
from keras.models import load_model

ncf.save('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5')
# Out:
# Using TensorFlow backend.
# '/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_14-21-04-991292.pkl'

# %%
a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_exxxx2')

# %%
# neumf = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_14-21-04-991292.pkl')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-fc1cb57d544a> in <module>()
# ----> 1 neumf = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_14-21-04-991292.pkl')
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144
#     145   if isinstance(filepath, six.string_types):
# --> 146     loader_impl.parse_saved_model(filepath)
#     147     return saved_model_load.load(filepath, compile)
#     148
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#      81                   (export_dir,
#      82                    constants.SAVED_MODEL_FILENAME_PBTXT,
# ---> 83                    constants.SAVED_MODEL_FILENAME_PB))
#      84
#      85
#
# OSError: SavedModel file does not exist at: /content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_14-21-04-991292.pkl/{saved_model.pbtxt|saved_model.pb}
