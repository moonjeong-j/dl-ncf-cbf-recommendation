# %%
import pandas as pd
import numpy as np
import math

# %%
# get size of vector
def mag(x):
    return math.sqrt(sum(i**2 for i in x))

# %%
res_matrix = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_res_matrix.csv')
user_matrix = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_user_matrix.csv')
group_count = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_group_count.csv',names=['group','count'])

# %%
res_matrix
# Out:
#      Unnamed: 0  group_64  group_0  group_1  group_2  group_3  group_4  \
# 0             0       274       19       14        1        8        4
# 1             1        77        6       11        2        5        9
# 2             2        26        7        2        1        2        1
# 3             3        23        2        1        1        0        2
# 4             4         4        0        0        0        0        0
# ..          ...       ...      ...      ...      ...      ...      ...
# 668         668         1        0        0        0        0        0
# 669         669         9        0        2        0        0        0
# 670         670        13        0        1        0        1        1
# 671         671         5        0        0        1        0        0
# 672         672         3        0        0        0        0        0
#
#      group_5  group_6  group_7  ...  group_110  group_111  group_112  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
group_count.drop([0], inplace =True)

# %%
res_matrix.rename(columns={'Unnamed: 0':'p_id'}, inplace=True)
res_matrix.set_index('p_id', drop=True, inplace=True)
group_count.set_index('group', drop=True, inplace=True)

# %%
user_matrix
# Out:
#       Unnamed: 0  group_64  group_0  group_1  group_2  group_3  group_4  \
# 0            876        12        2        0        0        1        4
# 1           1049         1        0        0        0        0        0
# 2            674         7        0        0        0        1        0
# 3           1596         7        1        1        0        0        0
# 4           2150         3        0        0        0        0        0
# ...          ...       ...      ...      ...      ...      ...      ...
# 2527         434         0        2        0        0        0        0
# 2528        2485         2        0        0        0        0        2
# 2529        1621         1        0        0        0        1        0
# 2530         333         2        0        1        0        0        2
# 2531         137         1        0        0        0        0        1
#
#       group_5  group_6  group_7  ...  group_110  group_111  group_112  \
# ...

# %%
user_matrix.rename(columns={'Unnamed: 0':'u_id'}, inplace=True)
# user_matrix.set_index('u_id', drop=True, inplace=True)

# %%
user_matrix
# Out:
#       u_id  group_64  group_0  group_1  group_2  group_3  group_4  group_5  \
# 0      876        12        2        0        0        1        4        0
# 1     1049         1        0        0        0        0        0        0
# 2      674         7        0        0        0        1        0        1
# 3     1596         7        1        1        0        0        0        0
# 4     2150         3        0        0        0        0        0        0
# ...    ...       ...      ...      ...      ...      ...      ...      ...
# 2527   434         0        2        0        0        0        0        0
# 2528  2485         2        0        0        0        0        2        0
# 2529  1621         1        0        0        0        1        0        0
# 2530   333         2        0        1        0        0        2        1
# 2531   137         1        0        0        0        0        1        0
#
# ...

# %%
user_matrix.set_index('u_id', drop=True, inplace=True)

# %%
user_matrix
# Out:
#       group_64  group_0  group_1  group_2  group_3  group_4  group_5  group_6  \
# u_id
# 876         12        2        0        0        1        4        0       10
# 1049         1        0        0        0        0        0        0        0
# 674          7        0        0        0        1        0        1        2
# 1596         7        1        1        0        0        0        0        5
# 2150         3        0        0        0        0        0        0        1
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 434          0        2        0        0        0        0        0        0
# 2485         2        0        0        0        0        2        0        2
# 1621         1        0        0        0        1        0        0        0
# 333          2        0        1        0        0        2        1        5
# 137          1        0        0        0        0        1        0        1
#
# ...

# %%
res_matrix
# Out:
#       group_64  group_0  group_1  group_2  group_3  group_4  group_5  group_6  \
# p_id
# 0          274       19       14        1        8        4        6       16
# 1           77        6       11        2        5        9        4        8
# 2           26        7        2        1        2        1        0        1
# 3           23        2        1        1        0        2        1       15
# 4            4        0        0        0        0        0        0        0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 668          1        0        0        0        0        0        0        0
# 669          9        0        2        0        0        0        1        0
# 670         13        0        1        0        1        1        0        1
# 671          5        0        0        1        0        0        0        0
# 672          3        0        0        0        0        0        0        0
#
# ...

# %%
group_count.head()
# Out:
#           count
# group
# group_64    786
# group_0      45
# group_1      80
# group_2      13
# group_3      32

# %%
p_m = pd.DataFrame(np.array(res_matrix) * (1/np.array(group_count['count'])), index=res_matrix.index)
p_m = p_m.iloc[:,:].div(p_m.sum(axis=1), axis=0).fillna(0)
u_m = pd.DataFrame(np.array(user_matrix) * (1/np.array(group_count['count'])), index=user_matrix.index)
u_m = u_m.iloc[:,:].div(u_m.sum(axis=1), axis=0).fillna(0)

# %%
p_m
# Out:
#            0         1         2         3         4         5         6    \
# p_id
# 0     0.009248  0.011201  0.004642  0.002041  0.006632  0.003216  0.009363
# 1     0.002892  0.003935  0.004058  0.004541  0.004612  0.008050  0.006945
# 2     0.004351  0.020462  0.003289  0.010119  0.008221  0.003986  0.000000
# 3     0.002661  0.004042  0.001137  0.006995  0.000000  0.005511  0.005349
# 4     0.004077  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 668   0.005826  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 669   0.003765  0.000000  0.008221  0.000000  0.000000  0.000000  0.019343
# 670   0.005337  0.000000  0.004033  0.000000  0.010083  0.009777  0.000000
# 671   0.006467  0.000000  0.000000  0.078205  0.000000  0.000000  0.000000
# 672   0.026739  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
u_m
# Out:
#            0         1         2    3         4         5         6    \
# u_id
# 876   0.003000  0.008735  0.000000  0.0  0.006142  0.023822  0.000000
# 1049  0.004781  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 674   0.003552  0.000000  0.000000  0.0  0.012465  0.000000  0.023463
# 1596  0.007806  0.019479  0.010957  0.0  0.000000  0.000000  0.000000
# 2150  0.007469  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# ...        ...       ...       ...  ...       ...       ...       ...
# 434   0.000000  0.213317  0.000000  0.0  0.000000  0.000000  0.000000
# 2485  0.005901  0.000000  0.000000  0.0  0.000000  0.140559  0.000000
# 1621  0.001016  0.000000  0.000000  0.0  0.024956  0.000000  0.000000
# 333   0.001466  0.000000  0.007200  0.0  0.000000  0.034909  0.033882
# 137   0.004655  0.000000  0.000000  0.0  0.000000  0.110879  0.000000
#
#            7        8    9    ...  110  111       112       113       114  \
# u_id                          ...
# ...

# %%
p_m.to_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_normalized_item_matrix.csv')
u_m.to_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_normalized_user_matrix.csv')

# %%
group_count.to_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_group_count.csv')
