# %%
import pandas as pd
import numpy as np

# %%
user_id = int(input('user id : '))
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# Out:
# user id : 107

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
eat_info =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_restaurant_info.csv')
cbf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/강남구_restuarant_'+str(user_id)+'_cbf.csv')
ncf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/강남구_restuarant_ncf_scores.csv')

# %%
eat_info
# Out:
#         name                       address          category  price  rvw_cnt  \
# 0    김북순큰남비집  서울특별시 강남구 압구정로2길 15 신사아이빌 1F  한정식 / 백반 / 정통 한식   5000       25
# 1      두부공작소         서울특별시 강남구 강남대로160길 21  한정식 / 백반 / 정통 한식   5000       16
# 2    빌라드스파이시        서울특별시 강남구 도산대로13길 14-3             기타 한식   5000       38
# 3       스쿨푸드            서울특별시 강남구 도산대로 139             기타 한식   5000       11
# 4         송옥      서울특별시 강남구 강남대로154길 43 2F         국수 / 면 요리   5000       11
# ..       ...                           ...               ...    ...      ...
# 768     요술포차           서울특별시 강남구 테헤란로19길 5             일반 주점  25000        5
# 769   전통주갤러리        서울특별시 강남구 테헤란로5길 51-20        전통 주점 / 포차  25000        2
# 770   더블린테라스  서울특별시 강남구 강남대로94길 27-15 태리빌딩       치킨 / 호프 / 펍  25000        1
# 771      술술술        서울특별시 강남구 강남대로98길 12-5             일반 주점  25000        2
# 772      다슬음  서울특별시 강남구 강남대로62길 23 역삼빌딩 1F             일반 주점  25000        1
#
#       rating       lat        lng  p_id  \
# ...

# %%
 eat_info=eat_info[['p_id','name','address','category','price',]]

# %%
eat_info
# Out:
#      p_id     name                       address          category  price
# 0      88  김북순큰남비집  서울특별시 강남구 압구정로2길 15 신사아이빌 1F  한정식 / 백반 / 정통 한식   5000
# 1     166    두부공작소         서울특별시 강남구 강남대로160길 21  한정식 / 백반 / 정통 한식   5000
# 2     322  빌라드스파이시        서울특별시 강남구 도산대로13길 14-3             기타 한식   5000
# 3     398     스쿨푸드            서울특별시 강남구 도산대로 139             기타 한식   5000
# 4     376       송옥      서울특별시 강남구 강남대로154길 43 2F         국수 / 면 요리   5000
# ..    ...      ...                           ...               ...    ...
# 768   528     요술포차           서울특별시 강남구 테헤란로19길 5             일반 주점  25000
# 769   591   전통주갤러리        서울특별시 강남구 테헤란로5길 51-20        전통 주점 / 포차  25000
# 770   148   더블린테라스  서울특별시 강남구 강남대로94길 27-15 태리빌딩       치킨 / 호프 / 펍  25000
# 771   381      술술술        서울특별시 강남구 강남대로98길 12-5             일반 주점  25000
# 772   131      다슬음  서울특별시 강남구 강남대로62길 23 역삼빌딩 1F             일반 주점  25000
#
# [773 rows x 5 columns]

# %%
cbf=cbf[['p_id','cbf_score']]
cbf
# Out:
#      p_id  cbf_score
# 0       0   0.000012
# 1       1   0.000018
# 2       2   0.000087
# 3       3   0.000023
# 4       4   0.000045
# ..    ...        ...
# 768   768   0.000000
# 769   769   0.000002
# 770   770   0.000000
# 771   771        NaN
# 772   772        NaN
#
# [773 rows x 2 columns]

# %%
ncf
# Out:
#          u_id       p_id  ncf_score
# 0           0   0.000000   0.768067
# 1           0  95.000000   0.007135
# 2           0  62.000000   0.020776
# 3           0 120.000000   0.008198
# 4           0  32.000000   0.125435
# ...       ...        ...        ...
# 3223546  4180 539.000000   0.000021
# 3223547  4180 697.000000   0.000089
# 3223548  4180 758.000000   0.001147
# 3223549  4180 607.000000   0.000000
# 3223550  4180 715.000000   0.000039
#
# [3223551 rows x 3 columns]

# %%
ncf=ncf[ncf['u_id']==107]

# %%
ncf
# Out:
#        u_id       p_id  ncf_score
# 82497   107  89.000000   0.033299
# 82498   107  34.000000   0.002965
# 82499   107  40.000000   0.111992
# 82500   107 111.000000   0.000075
# 82501   107 165.000000   0.076170
# ...     ...        ...        ...
# 83263   107 596.000000   0.000000
# 83264   107 597.000000   0.000002
# 83265   107 255.000000   0.000000
# 83266   107 249.000000   0.000000
# 83267   107 573.000000   0.000004
#
# [771 rows x 3 columns]

# %%
df=pd.merge(eat_info, cbf, left_on='p_id', right_on ='p_id',how ='left')
df=pd.merge(df, ncf, left_on='p_id', right_on ='p_id',how ='left')
df
# Out:
#      p_id     name                       address          category  price  \
# 0      88  김북순큰남비집  서울특별시 강남구 압구정로2길 15 신사아이빌 1F  한정식 / 백반 / 정통 한식   5000
# 1     166    두부공작소         서울특별시 강남구 강남대로160길 21  한정식 / 백반 / 정통 한식   5000
# 2     322  빌라드스파이시        서울특별시 강남구 도산대로13길 14-3             기타 한식   5000
# 3     398     스쿨푸드            서울특별시 강남구 도산대로 139             기타 한식   5000
# 4     376       송옥      서울특별시 강남구 강남대로154길 43 2F         국수 / 면 요리   5000
# ..    ...      ...                           ...               ...    ...
# 768   528     요술포차           서울특별시 강남구 테헤란로19길 5             일반 주점  25000
# 769   591   전통주갤러리        서울특별시 강남구 테헤란로5길 51-20        전통 주점 / 포차  25000
# 770   148   더블린테라스  서울특별시 강남구 강남대로94길 27-15 태리빌딩       치킨 / 호프 / 펍  25000
# 771   381      술술술        서울특별시 강남구 강남대로98길 12-5             일반 주점  25000
# 772   131      다슬음  서울특별시 강남구 강남대로62길 23 역삼빌딩 1F             일반 주점  25000
#
#      cbf_score       u_id  ncf_score
# 0     0.000003 107.000000   0.003950
# ...

# %%
df['result'] = df['cbf_score'] * df['ncf_score']

# %%
del df['u_id']

# %%
df.sort_values('result',ascending = False).head(10)
# Out:
#      p_id     name                       address          category  price  \
# 494    15     가가솥밥        서울특별시 강남구 역삼로5길 19  1F  한정식 / 백반 / 정통 한식  15000
# 15     37   강승월한식당       서울특별시 강남구 논현로175길 61 2F  한정식 / 백반 / 정통 한식   5000
# 129    10    Lu307     서울특별시 강남구 압구정로10길 30-7 1F    이자카야 / 오뎅 / 꼬치  15000
# 663    68      구구당         서울특별시 강남구 강남대로102길 35             퓨전 양식  15000
# 144    16  가로수길 소소         서울특별시 강남구 강남대로154길 41    이자카야 / 오뎅 / 꼬치  25000
# 368    75    그 우동집             서울특별시 강남구 역삼로7길 7             기타 한식   5000
# 117   153   덴푸라키이로     서울특별시 강남구 논현로153길 51 102호  돈부리 / 일본 카레 / 벤토  15000
# 192   425     신사완쯔    서울특별시 강남구 강남대로154길 11 애경빌딩             퓨전 중식  15000
# 767     2      29펍         서울특별시 강남구 강남대로110길 14       치킨 / 호프 / 펍  25000
# 646   435     써브웨이  서울특별시 강남구 강남대로96길 12 지천빌딩 1F   브런치 / 버거 / 샌드위치   5000
#
#      cbf_score  ncf_score   result
# 494   0.001246   0.062523 0.000078
# 15    0.000688   0.071217 0.000049
# 129   0.001880   0.025679 0.000048
# ...
