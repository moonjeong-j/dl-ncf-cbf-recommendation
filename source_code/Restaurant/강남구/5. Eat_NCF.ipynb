# %%
pip uninstall scikit-learn -y
# Out:
# Found existing installation: scikit-learn 1.0.2
# Uninstalling scikit-learn-1.0.2:
#   Successfully uninstalled scikit-learn-1.0.2

# %%
pip uninstall cornac -y
# Out:
# Found existing installation: cornac 1.14.2
# Uninstalling cornac-1.14.2:
#   Successfully uninstalled cornac-1.14.2

# %%
pip uninstall tensorflow==2.9.1 -y
# Out:
# Found existing installation: tensorflow 1.15.2
# Uninstalling tensorflow-1.15.2:
#   Successfully uninstalled tensorflow-1.15.2

# %%
pip install scikit-learn==0.22.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 9.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.1.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.4.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.1 which is incompatible.
# Successfully installed scikit-learn-0.22.1

# %%
pip install cornac==1.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cornac==1.6.1
#   Downloading cornac-1.6.1-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 4.7 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.7.3)
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.21.6)
# Installing collected packages: cornac
# Successfully installed cornac-1.6.1

# %%
pip install tensorflow==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.15.2
#   Downloading tensorflow-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (110.5 MB)
#      |████████████████████████████████| 110.5 MB 37 kB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.15.0)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 53.7 MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.17.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.47.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.37.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.14.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.2.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.2 MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.8.1)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 32.3 MB/s
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=5a0b8c34d9e81e7d85e82e6cd8de8c9a626c3e938ed9293609b8485949168aea
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
#     Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.2 tensorflow-estimator-1.15.1

# %%
# pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 33 kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.46.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.15.2

# %%
pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 34 kB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 51.7 MB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 64.1 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.47.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.1 MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=40e5ce2c6e030bf6aa01e2791506912c562f1a3c1a831ef8d56b7063b095a91b
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorboard<2.9,>=2.8, but you have tensorboard 1.15.0 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorflow-estimator<2.9,>=2.8, but you have tensorflow-estimator 1.15.1 which is incompatible.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.2

# %%
# %tensorflow_version 1.15
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# WARNING: Tensorflow 1 is deprecated, and support will be removed on August 1, 2022.
# After that, `%tensorflow_version 1.x` will throw an error.
#
# Your notebook should be updated to use Tensorflow 2.
# See the guide at https://www.tensorflow.org/guide/migrate#migrate-from-tensorflow-1x-to-tensorflow-2.
#
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cornac
import cornac.eval_methods
from cornac.eval_methods import RatioSplit, base_method
from cornac.hyperopt import Continuous, Discrete, RandomSearch
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# 추천할 top k개의 장소
TOP_K = 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_restuarant_score_board.csv', index_col =0)

# %%
data_df['rating'] =data_df['rating'].astype('float')
data_df = data_df.rename({'u_id':'userID','p_id':'itemID'},axis=1)
#data_df = data_df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
data_df = data_df.fillna(5)

# %%
data_df
# Out:
#       itemID  rating
# u_id
# 0        491     5.0
# 0        689     5.0
# 0        491     0.0
# 0        306     3.0
# 0        633     0.0
# ...      ...     ...
# 4180     659     3.0
# 4180     491     3.0
# 4180     382     5.0
# 4180     264     5.0
# 4180     619     5.0
#
# [17135 rows x 2 columns]

# %%
data_df.reset_index(inplace=True)
data_df
# Out:
#        u_id  itemID  rating
# 0         0     491     5.0
# 1         0     689     5.0
# 2         0     491     0.0
# 3         0     306     3.0
# 4         0     633     0.0
# ...     ...     ...     ...
# 17130  4180     659     3.0
# 17131  4180     491     3.0
# 17132  4180     382     5.0
# 17133  4180     264     5.0
# 17134  4180     619     5.0
#
# [17135 rows x 3 columns]

# %%
data = [tuple(x) for x in data_df.values]
data
# Out:
# [(0.0, 491.0, 5.0),
#  (0.0, 689.0, 5.0),
#  (0.0, 491.0, 0.0),
#  (0.0, 306.0, 3.0),
#  (0.0, 633.0, 0.0),
#  (0.0, 689.0, 5.0),
#  (0.0, 472.0, 3.0),
#  (0.0, 603.0, 3.0),
#  (0.0, 347.0, 3.0),
#  (0.0, 435.0, 3.0),
#  (0.0, 82.0, 3.0),
#  (0.0, 382.0, 0.0),
#  (0.0, 648.0, 0.0),
#  (0.0, 435.0, 5.0),
#  (0.0, 375.0, 5.0),
#  (0.0, 114.0, 5.0),
#  (0.0, 435.0, 3.0),
#  (0.0, 243.0, 3.0),
#  (0.0, 713.0, 3.0),
#  (0.0, 264.0, 5.0),
#  (0.0, 603.0, 3.0),
#  (0.0, 551.0, 3.0),
#  (0.0, 683.0, 3.0),
#  (0.0, 315.0, 3.0),
#  (0.0, 591.0, 0.0),
#  (0.0, 435.0, 3.0),
#  (1.0, 315.0, 3.0),
#  (1.0, 598.0, 3.0),
#  (2.0, 124.0, 5.0),
#  (3.0, 323.0, 0.0),
#  (4.0, 250.0, 3.0),
#  (4.0, 28.0, 3.0),
#  (4.0, 250.0, 3.0),
#  (4.0, 347.0, 3.0),
#  (4.0, 639.0, 5.0),
#  (4.0, 316.0, 5.0),
#  (4.0, 402.0, 5.0),
#  (4.0, 402.0, 5.0),
#  (4.0, 402.0, 5.0),
#  (4.0, 402.0, 3.0),
#  (4.0, 639.0, 5.0),
#  (4.0, 659.0, 5.0),
#  (4.0, 24.0, 3.0),
#  (4.0, 583.0, 3.0),
#  (4.0, 616.0, 3.0),
#  (4.0, 583.0, 3.0),
#  (4.0, 118.0, 3.0),
#  (4.0, 89.0, 3.0),
#  (4.0, 250.0, 3.0),
#  (4.0, 155.0, 3.0),
#  (4.0, 609.0, 5.0),
#  (4.0, 363.0, 5.0),
#  (4.0, 118.0, 3.0),
#  (4.0, 105.0, 3.0),
#  (4.0, 617.0, 3.0),
#  (4.0, 617.0, 5.0),
#  (4.0, 617.0, 3.0),
#  (4.0, 55.0, 5.0),
#  (4.0, 137.0, 3.0),
#  (4.0, 315.0, 5.0),
#  (4.0, 174.0, 3.0),
#  (4.0, 437.0, 3.0),
#  (4.0, 95.0, 3.0),
#  (4.0, 571.0, 3.0),
#  (4.0, 332.0, 3.0),
#  (4.0, 327.0, 3.0),
#  (4.0, 64.0, 5.0),
#  (4.0, 501.0, 5.0),
#  (4.0, 299.0, 3.0),
#  (4.0, 727.0, 5.0),
#  (4.0, 431.0, 3.0),
#  (4.0, 609.0, 5.0),
#  (4.0, 124.0, 5.0),
#  (4.0, 28.0, 3.0),
#  (4.0, 241.0, 3.0),
#  (4.0, 363.0, 5.0),
#  (4.0, 332.0, 3.0),
#  (4.0, 199.0, 5.0),
#  (4.0, 713.0, 5.0),
#  (4.0, 611.0, 5.0),
#  (4.0, 238.0, 5.0),
#  (4.0, 306.0, 3.0),
#  (4.0, 510.0, 5.0),
#  (4.0, 160.0, 3.0),
#  (4.0, 472.0, 5.0),
#  (4.0, 572.0, 3.0),
#  (4.0, 132.0, 5.0),
#  (4.0, 510.0, 5.0),
#  (4.0, 36.0, 3.0),
#  (4.0, 533.0, 5.0),
#  (4.0, 472.0, 5.0),
#  (4.0, 344.0, 5.0),
#  (4.0, 125.0, 5.0),
#  (4.0, 676.0, 3.0),
#  (4.0, 466.0, 3.0),
#  (4.0, 124.0, 5.0),
#  (4.0, 137.0, 3.0),
#  (4.0, 198.0, 0.0),
#  (4.0, 124.0, 5.0),
#  (4.0, 533.0, 3.0),
#  (4.0, 71.0, 5.0),
#  (4.0, 249.0, 3.0),
#  (4.0, 353.0, 0.0),
#  (4.0, 308.0, 5.0),
#  (4.0, 680.0, 5.0),
#  (4.0, 580.0, 5.0),
#  (4.0, 680.0, 3.0),
#  (4.0, 550.0, 3.0),
#  (4.0, 98.0, 5.0),
#  (4.0, 634.0, 3.0),
#  (4.0, 406.0, 5.0),
#  (4.0, 756.0, 5.0),
#  (4.0, 224.0, 5.0),
#  (4.0, 510.0, 5.0),
#  (4.0, 137.0, 3.0),
#  (4.0, 756.0, 3.0),
#  (4.0, 626.0, 5.0),
#  (4.0, 243.0, 5.0),
#  (4.0, 621.0, 3.0),
#  (4.0, 132.0, 5.0),
#  (4.0, 589.0, 3.0),
#  (4.0, 638.0, 5.0),
#  (4.0, 442.0, 5.0),
#  (4.0, 488.0, 3.0),
#  (5.0, 108.0, 0.0),
#  (6.0, 124.0, 5.0),
#  (7.0, 341.0, 5.0),
#  (7.0, 24.0, 5.0),
#  (7.0, 306.0, 5.0),
#  (7.0, 315.0, 5.0),
#  (7.0, 315.0, 5.0),
#  (8.0, 125.0, 5.0),
#  (8.0, 619.0, 0.0),
#  (9.0, 626.0, 5.0),
#  (10.0, 315.0, 5.0),
#  (10.0, 119.0, 5.0),
#  (10.0, 395.0, 3.0),
#  (11.0, 46.0, 3.0),
#  (11.0, 461.0, 3.0),
#  (11.0, 495.0, 3.0),
#  (11.0, 228.0, 0.0),
#  (11.0, 486.0, 3.0),
#  (11.0, 114.0, 3.0),
#  (11.0, 752.0, 3.0),
#  (11.0, 184.0, 3.0),
#  (11.0, 690.0, 3.0),
#  (11.0, 35.0, 3.0),
#  (11.0, 664.0, 3.0),
#  (11.0, 486.0, 5.0),
#  (11.0, 497.0, 3.0),
#  (11.0, 245.0, 5.0),
#  (11.0, 315.0, 3.0),
#  (11.0, 114.0, 3.0),
#  (11.0, 461.0, 5.0),
#  (11.0, 713.0, 5.0),
#  (11.0, 624.0, 3.0),
#  (11.0, 101.0, 3.0),
#  (11.0, 657.0, 3.0),
#  (11.0, 564.0, 3.0),
#  (11.0, 451.0, 5.0),
#  (11.0, 611.0, 5.0),
#  (11.0, 439.0, 5.0),
#  (11.0, 543.0, 3.0),
#  (11.0, 421.0, 3.0),
#  (11.0, 169.0, 5.0),
#  (11.0, 713.0, 5.0),
#  (11.0, 16.0, 3.0),
#  (11.0, 655.0, 3.0),
#  (11.0, 228.0, 3.0),
#  (11.0, 497.0, 3.0),
#  (11.0, 501.0, 3.0),
#  (11.0, 399.0, 3.0),
#  (11.0, 262.0, 3.0),
#  (11.0, 237.0, 3.0),
#  (11.0, 598.0, 3.0),
#  (11.0, 230.0, 3.0),
#  (11.0, 469.0, 0.0),
#  (11.0, 362.0, 3.0),
#  (11.0, 22.0, 3.0),
#  (11.0, 366.0, 3.0),
#  (11.0, 438.0, 3.0),
#  (11.0, 182.0, 5.0),
#  (11.0, 182.0, 3.0),
#  (11.0, 491.0, 3.0),
#  (11.0, 398.0, 3.0),
#  (11.0, 184.0, 3.0),
#  (11.0, 184.0, 3.0),
#  (11.0, 184.0, 5.0),
#  (11.0, 753.0, 3.0),
#  (11.0, 652.0, 3.0),
#  (11.0, 80.0, 3.0),
#  (11.0, 264.0, 3.0),
#  (11.0, 71.0, 5.0),
#  (11.0, 735.0, 0.0),
#  (11.0, 89.0, 3.0),
#  (11.0, 626.0, 5.0),
#  (11.0, 626.0, 3.0),
#  (11.0, 576.0, 3.0),
#  (11.0, 65.0, 3.0),
#  (11.0, 58.0, 3.0),
#  (11.0, 82.0, 5.0),
#  (11.0, 1.0, 3.0),
#  (11.0, 385.0, 0.0),
#  (11.0, 322.0, 0.0),
#  (11.0, 518.0, 0.0),
#  (11.0, 81.0, 3.0),
#  (11.0, 65.0, 5.0),
#  (11.0, 11.0, 5.0),
#  (11.0, 65.0, 3.0),
#  (11.0, 593.0, 3.0),
#  (11.0, 95.0, 0.0),
#  (11.0, 18.0, 0.0),
#  (11.0, 254.0, 3.0),
#  (11.0, 95.0, 0.0),
#  (11.0, 95.0, 5.0),
#  (11.0, 704.0, 3.0),
#  (11.0, 505.0, 5.0),
#  (11.0, 505.0, 3.0),
#  (11.0, 553.0, 3.0),
#  (11.0, 382.0, 5.0),
#  (11.0, 65.0, 3.0),
#  (11.0, 65.0, 3.0),
#  (11.0, 729.0, 3.0),
#  (12.0, 253.0, 3.0),
#  (12.0, 701.0, 5.0),
#  (12.0, 292.0, 3.0),
#  (12.0, 124.0, 5.0),
#  (12.0, 491.0, 5.0),
#  (12.0, 108.0, 5.0),
#  (12.0, 598.0, 3.0),
#  (12.0, 446.0, 0.0),
#  (12.0, 36.0, 3.0),
#  (12.0, 187.0, 3.0),
#  (12.0, 491.0, 5.0),
#  (12.0, 463.0, 3.0),
#  (12.0, 22.0, 5.0),
#  (12.0, 325.0, 5.0),
#  (12.0, 487.0, 5.0),
#  (12.0, 208.0, 3.0),
#  (12.0, 264.0, 3.0),
#  (12.0, 71.0, 3.0),
#  (12.0, 366.0, 5.0),
#  (12.0, 333.0, 3.0),
#  (12.0, 533.0, 3.0),
#  (12.0, 333.0, 5.0),
#  (12.0, 207.0, 5.0),
#  (12.0, 510.0, 5.0),
#  (12.0, 87.0, 0.0),
#  (12.0, 720.0, 3.0),
#  (12.0, 609.0, 3.0),
#  (12.0, 87.0, 5.0),
#  (12.0, 753.0, 3.0),
#  (12.0, 687.0, 3.0),
#  (12.0, 528.0, 3.0),
#  (12.0, 650.0, 3.0),
#  (12.0, 316.0, 0.0),
#  (12.0, 441.0, 0.0),
#  (12.0, 147.0, 3.0),
#  (12.0, 239.0, 0.0),
#  (12.0, 182.0, 3.0),
#  (12.0, 245.0, 5.0),
#  (12.0, 661.0, 3.0),
#  (12.0, 181.0, 3.0),
#  (12.0, 338.0, 3.0),
#  (12.0, 1.0, 5.0),
#  (13.0, 212.0, 0.0),
#  (14.0, 645.0, 5.0),
#  (14.0, 243.0, 5.0),
#  (15.0, 491.0, 5.0),
#  (15.0, 375.0, 3.0),
#  (15.0, 574.0, 5.0),
#  (15.0, 368.0, 3.0),
#  (15.0, 181.0, 0.0),
#  (15.0, 766.0, 5.0),
#  (15.0, 769.0, 0.0),
#  (15.0, 388.0, 5.0),
#  (15.0, 250.0, 0.0),
#  (16.0, 175.0, 0.0),
#  (16.0, 510.0, 3.0),
#  (16.0, 504.0, 3.0),
#  (16.0, 745.0, 3.0),
#  (16.0, 229.0, 0.0),
#  (16.0, 174.0, 0.0),
#  (16.0, 737.0, 0.0),
#  (16.0, 655.0, 5.0),
#  (17.0, 270.0, 3.0),
#  (17.0, 181.0, 5.0),
#  (18.0, 82.0, 5.0),
#  (19.0, 522.0, 5.0),
#  (19.0, 253.0, 5.0),
#  (19.0, 533.0, 3.0),
#  (19.0, 593.0, 3.0),
#  (19.0, 166.0, 3.0),
#  (19.0, 523.0, 3.0),
#  (19.0, 71.0, 3.0),
#  (19.0, 331.0, 5.0),
#  (20.0, 129.0, 0.0),
#  (21.0, 475.0, 3.0),
#  (22.0, 220.0, 3.0),
#  (22.0, 518.0, 3.0),
#  (22.0, 331.0, 5.0),
#  (23.0, 314.0, 3.0),
#  (23.0, 175.0, 5.0),
#  (23.0, 89.0, 3.0),
#  (23.0, 609.0, 3.0),
#  (23.0, 316.0, 3.0),
#  (23.0, 124.0, 5.0),
#  (23.0, 472.0, 0.0),
#  (23.0, 25.0, 0.0),
#  (24.0, 689.0, 5.0),
#  (25.0, 676.0, 0.0),
#  (25.0, 108.0, 5.0),
#  (26.0, 559.0, 5.0),
#  (27.0, 595.0, 3.0),
#  (28.0, 68.0, 3.0),
#  (29.0, 469.0, 3.0),
#  (30.0, 264.0, 5.0),
#  (30.0, 315.0, 5.0),
#  (30.0, 185.0, 5.0),
#  (30.0, 676.0, 5.0),
#  (31.0, 54.0, 5.0),
#  (32.0, 533.0, 5.0),
#  (32.0, 108.0, 3.0),
#  (33.0, 611.0, 5.0),
#  (33.0, 228.0, 3.0),
#  (33.0, 339.0, 3.0),
#  (34.0, 421.0, 5.0),
#  (35.0, 733.0, 5.0),
#  (36.0, 57.0, 5.0),
#  (36.0, 626.0, 5.0),
#  (37.0, 0.0, 5.0),
#  (38.0, 667.0, 3.0),
#  (39.0, 375.0, 5.0),
#  (40.0, 362.0, 5.0),
#  (41.0, 315.0, 3.0),
#  (41.0, 573.0, 3.0),
#  (41.0, 704.0, 3.0),
#  (41.0, 685.0, 5.0),
#  (41.0, 363.0, 5.0),
#  (42.0, 533.0, 5.0),
#  (43.0, 630.0, 5.0),
#  (43.0, 108.0, 5.0),
#  (43.0, 510.0, 5.0),
#  (43.0, 106.0, 5.0),
#  (43.0, 463.0, 5.0),
#  (44.0, 1.0, 5.0),
#  (45.0, 243.0, 0.0),
#  (46.0, 270.0, 3.0),
#  (46.0, 322.0, 0.0),
#  (46.0, 316.0, 5.0),
#  (46.0, 245.0, 5.0),
#  (46.0, 729.0, 5.0),
#  (46.0, 71.0, 3.0),
#  (46.0, 572.0, 3.0),
#  (46.0, 619.0, 3.0),
#  (47.0, 108.0, 3.0),
#  (48.0, 299.0, 3.0),
#  (48.0, 603.0, 0.0),
#  (49.0, 557.0, 0.0),
#  (50.0, 276.0, 5.0),
#  (50.0, 609.0, 5.0),
#  (50.0, 341.0, 5.0),
#  (50.0, 65.0, 5.0),
#  (50.0, 525.0, 0.0),
#  (50.0, 598.0, 5.0),
#  (50.0, 271.0, 3.0),
#  (51.0, 309.0, 0.0),
#  (51.0, 82.0, 3.0),
#  (51.0, 533.0, 5.0),
#  (51.0, 500.0, 3.0),
#  (51.0, 323.0, 5.0),
#  (51.0, 18.0, 5.0),
#  (51.0, 315.0, 3.0),
#  (51.0, 439.0, 5.0),
#  (51.0, 469.0, 3.0),
#  (52.0, 630.0, 5.0),
#  (52.0, 451.0, 0.0),
#  (53.0, 228.0, 5.0),
#  (54.0, 264.0, 0.0),
#  (55.0, 611.0, 3.0),
#  (55.0, 164.0, 5.0),
#  (55.0, 154.0, 3.0),
#  (55.0, 366.0, 3.0),
#  (56.0, 659.0, 3.0),
#  (57.0, 463.0, 5.0),
#  (58.0, 306.0, 5.0),
#  (58.0, 288.0, 3.0),
#  (58.0, 619.0, 5.0),
#  (58.0, 504.0, 3.0),
#  (59.0, 364.0, 0.0),
#  (60.0, 472.0, 5.0),
#  (60.0, 295.0, 5.0),
#  (61.0, 315.0, 5.0),
#  (61.0, 663.0, 5.0),
#  (61.0, 704.0, 5.0),
#  (61.0, 685.0, 5.0),
#  (61.0, 593.0, 5.0),
#  (61.0, 629.0, 5.0),
#  (61.0, 316.0, 5.0),
#  (62.0, 186.0, 3.0),
#  (62.0, 501.0, 5.0),
#  (62.0, 213.0, 5.0),
#  (62.0, 315.0, 5.0),
#  (62.0, 167.0, 5.0),
#  (62.0, 609.0, 5.0),
#  (62.0, 770.0, 5.0),
#  (62.0, 254.0, 3.0),
#  (62.0, 126.0, 5.0),
#  (62.0, 271.0, 3.0),
#  (62.0, 533.0, 5.0),
#  (63.0, 297.0, 5.0),
#  (64.0, 129.0, 3.0),
#  (65.0, 382.0, 0.0),
#  (66.0, 222.0, 3.0),
#  (66.0, 381.0, 5.0),
#  (67.0, 270.0, 3.0),
#  (67.0, 315.0, 3.0),
#  (68.0, 237.0, 5.0),
#  (68.0, 11.0, 5.0),
#  (69.0, 325.0, 3.0),
#  (69.0, 309.0, 5.0),
#  (70.0, 611.0, 0.0),
#  (71.0, 452.0, 3.0),
#  (71.0, 181.0, 5.0),
#  (71.0, 510.0, 5.0),
#  (71.0, 320.0, 5.0),
#  (71.0, 641.0, 5.0),
#  (71.0, 701.0, 3.0),
#  (71.0, 108.0, 5.0),
#  (71.0, 17.0, 5.0),
#  (71.0, 443.0, 5.0),
#  (71.0, 108.0, 5.0),
#  (71.0, 6.0, 5.0),
#  (71.0, 314.0, 3.0),
#  (71.0, 292.0, 5.0),
#  (71.0, 99.0, 5.0),
#  (71.0, 619.0, 5.0),
#  (71.0, 253.0, 0.0),
#  (71.0, 253.0, 5.0),
#  (71.0, 139.0, 5.0),
#  (71.0, 245.0, 5.0),
#  (71.0, 78.0, 3.0),
#  (71.0, 573.0, 5.0),
#  (71.0, 306.0, 3.0),
#  (71.0, 533.0, 5.0),
#  (71.0, 315.0, 5.0),
#  (71.0, 269.0, 3.0),
#  (71.0, 211.0, 5.0),
#  (71.0, 315.0, 0.0),
#  (71.0, 438.0, 3.0),
#  (71.0, 124.0, 5.0),
#  (71.0, 592.0, 5.0),
#  (71.0, 208.0, 5.0),
#  (71.0, 533.0, 5.0),
#  (71.0, 108.0, 5.0),
#  (71.0, 404.0, 5.0),
#  (71.0, 557.0, 3.0),
#  (71.0, 184.0, 5.0),
#  (71.0, 184.0, 5.0),
#  (71.0, 611.0, 5.0),
#  (71.0, 104.0, 3.0),
#  (71.0, 36.0, 5.0),
#  (71.0, 109.0, 5.0),
#  (71.0, 655.0, 5.0),
#  (71.0, 619.0, 5.0),
#  (71.0, 99.0, 3.0),
#  (71.0, 754.0, 3.0),
#  (71.0, 124.0, 5.0),
#  (71.0, 245.0, 5.0),
#  (71.0, 24.0, 3.0),
#  (71.0, 382.0, 3.0),
#  (71.0, 736.0, 5.0),
#  (71.0, 421.0, 5.0),
#  (71.0, 593.0, 5.0),
#  (71.0, 629.0, 5.0),
#  (71.0, 316.0, 5.0),
#  (71.0, 291.0, 5.0),
#  (71.0, 71.0, 3.0),
#  (71.0, 609.0, 3.0),
#  (72.0, 22.0, 5.0),
#  (72.0, 22.0, 3.0),
#  (72.0, 65.0, 5.0),
#  (73.0, 533.0, 5.0),
#  (73.0, 124.0, 5.0),
#  (74.0, 22.0, 3.0),
#  (74.0, 218.0, 0.0),
#  (74.0, 332.0, 0.0),
#  (75.0, 412.0, 0.0),
#  (75.0, 305.0, 0.0),
#  (76.0, 389.0, 3.0),
#  (76.0, 320.0, 5.0),
#  (76.0, 439.0, 5.0),
#  (77.0, 501.0, 5.0),
#  (78.0, 315.0, 5.0),
#  (79.0, 382.0, 3.0),
#  (80.0, 22.0, 5.0),
#  (81.0, 265.0, 5.0),
#  (82.0, 611.0, 5.0),
#  (83.0, 515.0, 0.0),
#  (83.0, 662.0, 5.0),
#  (83.0, 264.0, 5.0),
#  (83.0, 330.0, 5.0),
#  (83.0, 582.0, 3.0),
#  (83.0, 395.0, 5.0),
#  (84.0, 227.0, 5.0),
#  (84.0, 635.0, 0.0),
#  (85.0, 113.0, 0.0),
#  (86.0, 122.0, 3.0),
#  (86.0, 247.0, 3.0),
#  (86.0, 619.0, 3.0),
#  (86.0, 637.0, 5.0),
#  (86.0, 656.0, 5.0),
#  (86.0, 382.0, 3.0),
#  (86.0, 382.0, 3.0),
#  (86.0, 714.0, 5.0),
#  (86.0, 735.0, 3.0),
#  (86.0, 531.0, 3.0),
#  (86.0, 65.0, 5.0),
#  (86.0, 537.0, 5.0),
#  (86.0, 395.0, 5.0),
#  (87.0, 423.0, 5.0),
#  (87.0, 375.0, 5.0),
#  (88.0, 491.0, 5.0),
#  (89.0, 315.0, 0.0),
#  (89.0, 315.0, 5.0),
#  (89.0, 82.0, 5.0),
#  (90.0, 295.0, 5.0),
#  (91.0, 315.0, 5.0),
#  (91.0, 676.0, 3.0),
#  (91.0, 344.0, 5.0),
#  (91.0, 243.0, 5.0),
#  (91.0, 596.0, 3.0),
#  (91.0, 243.0, 5.0),
#  (91.0, 611.0, 3.0),
#  (91.0, 315.0, 5.0),
#  (91.0, 689.0, 5.0),
#  (91.0, 315.0, 5.0),
#  (91.0, 347.0, 3.0),
#  (91.0, 315.0, 5.0),
#  (91.0, 315.0, 5.0),
#  (91.0, 619.0, 5.0),
#  (91.0, 357.0, 3.0),
#  (91.0, 533.0, 5.0),
#  (91.0, 375.0, 5.0),
#  (91.0, 353.0, 5.0),
#  (91.0, 501.0, 5.0),
#  (91.0, 619.0, 5.0),
#  (91.0, 172.0, 3.0),
#  (91.0, 186.0, 5.0),
#  (91.0, 472.0, 5.0),
#  (91.0, 315.0, 5.0),
#  (91.0, 611.0, 5.0),
#  (91.0, 65.0, 5.0),
#  (91.0, 264.0, 3.0),
#  (91.0, 511.0, 3.0),
#  (91.0, 237.0, 5.0),
#  (91.0, 316.0, 3.0),
#  (91.0, 126.0, 5.0),
#  (91.0, 227.0, 5.0),
#  (91.0, 38.0, 5.0),
#  (91.0, 126.0, 5.0),
#  (92.0, 685.0, 5.0),
#  (93.0, 254.0, 3.0),
#  (94.0, 659.0, 5.0),
#  (95.0, 159.0, 5.0),
#  (95.0, 327.0, 5.0),
#  (95.0, 193.0, 5.0),
#  (95.0, 533.0, 3.0),
#  (95.0, 54.0, 5.0),
#  (95.0, 469.0, 3.0),
#  (95.0, 382.0, 5.0),
#  (95.0, 619.0, 5.0),
#  (95.0, 401.0, 3.0),
#  (95.0, 374.0, 5.0),
#  (95.0, 322.0, 0.0),
#  (95.0, 451.0, 5.0),
#  (95.0, 285.0, 5.0),
#  (95.0, 611.0, 3.0),
#  (95.0, 757.0, 3.0),
#  (95.0, 102.0, 0.0),
#  (95.0, 34.0, 5.0),
#  (95.0, 208.0, 5.0),
#  (95.0, 551.0, 5.0),
#  (95.0, 370.0, 0.0),
#  (95.0, 713.0, 5.0),
#  (95.0, 266.0, 5.0),
#  (95.0, 175.0, 3.0),
#  (95.0, 71.0, 5.0),
#  (95.0, 271.0, 5.0),
#  (95.0, 224.0, 3.0),
#  (95.0, 227.0, 5.0),
#  (95.0, 592.0, 5.0),
#  (95.0, 309.0, 5.0),
#  (95.0, 78.0, 5.0),
#  (95.0, 82.0, 5.0),
#  (95.0, 423.0, 5.0),
#  (95.0, 288.0, 3.0),
#  (95.0, 316.0, 5.0),
#  (95.0, 676.0, 5.0),
#  (95.0, 230.0, 5.0),
#  (95.0, 288.0, 3.0),
#  (95.0, 382.0, 3.0),
#  (95.0, 245.0, 5.0),
#  (95.0, 276.0, 5.0),
#  (96.0, 186.0, 5.0),
#  (96.0, 82.0, 5.0),
#  (96.0, 739.0, 0.0),
#  (97.0, 315.0, 3.0),
#  (97.0, 82.0, 5.0),
#  (97.0, 611.0, 3.0),
#  (97.0, 469.0, 0.0),
#  (97.0, 505.0, 3.0),
#  (97.0, 398.0, 3.0),
#  (97.0, 704.0, 3.0),
#  (97.0, 466.0, 0.0),
#  (97.0, 326.0, 3.0),
#  (97.0, 684.0, 3.0),
#  (97.0, 557.0, 5.0),
#  (97.0, 182.0, 0.0),
#  (97.0, 611.0, 3.0),
#  (97.0, 22.0, 3.0),
#  (97.0, 533.0, 3.0),
#  (97.0, 228.0, 5.0),
#  (97.0, 533.0, 5.0),
#  (98.0, 510.0, 5.0),
#  (99.0, 472.0, 0.0),
#  (99.0, 451.0, 0.0),
#  (100.0, 316.0, 3.0),
#  (101.0, 28.0, 5.0),
#  (102.0, 619.0, 5.0),
#  (103.0, 598.0, 0.0),
#  (104.0, 132.0, 5.0),
#  (104.0, 65.0, 5.0),
#  (104.0, 322.0, 5.0),
#  (105.0, 593.0, 5.0),
#  (105.0, 172.0, 3.0),
#  (105.0, 375.0, 5.0),
#  (106.0, 243.0, 5.0),
#  (106.0, 71.0, 5.0),
#  (106.0, 676.0, 5.0),
#  (106.0, 132.0, 5.0),
#  (106.0, 611.0, 5.0),
#  (106.0, 382.0, 3.0),
#  (106.0, 685.0, 0.0),
#  (106.0, 598.0, 5.0),
#  (106.0, 315.0, 5.0),
#  (107.0, 182.0, 5.0),
#  (108.0, 119.0, 0.0),
#  (109.0, 154.0, 5.0),
#  (110.0, 592.0, 5.0),
#  (111.0, 611.0, 3.0),
#  (112.0, 611.0, 5.0),
#  (113.0, 714.0, 5.0),
#  (113.0, 729.0, 5.0),
#  (113.0, 322.0, 5.0),
#  (114.0, 375.0, 3.0),
#  (115.0, 71.0, 5.0),
#  (116.0, 212.0, 5.0),
#  (117.0, 139.0, 5.0),
#  (118.0, 611.0, 0.0),
#  (119.0, 462.0, 5.0),
#  (120.0, 315.0, 5.0),
#  (121.0, 95.0, 3.0),
#  (122.0, 598.0, 0.0),
#  (123.0, 169.0, 5.0),
#  (123.0, 753.0, 0.0),
#  (124.0, 619.0, 5.0),
#  (125.0, 24.0, 5.0),
#  (126.0, 574.0, 5.0),
#  (126.0, 593.0, 5.0),
#  (127.0, 572.0, 5.0),
#  (127.0, 472.0, 5.0),
#  (127.0, 462.0, 5.0),
#  (127.0, 472.0, 5.0),
#  (127.0, 382.0, 5.0),
#  (127.0, 598.0, 5.0),
#  (127.0, 296.0, 5.0),
#  (127.0, 228.0, 5.0),
#  (127.0, 713.0, 5.0),
#  (127.0, 440.0, 5.0),
#  (127.0, 230.0, 5.0),
#  (127.0, 95.0, 5.0),
#  (127.0, 36.0, 5.0),
#  (127.0, 184.0, 5.0),
#  (127.0, 341.0, 5.0),
#  (127.0, 753.0, 5.0),
#  (127.0, 288.0, 5.0),
#  (127.0, 664.0, 5.0),
#  (127.0, 571.0, 5.0),
#  (127.0, 655.0, 5.0),
#  (127.0, 228.0, 5.0),
#  (128.0, 198.0, 3.0),
#  (129.0, 243.0, 3.0),
#  (129.0, 243.0, 3.0),
#  (129.0, 106.0, 3.0),
#  (129.0, 314.0, 3.0),
#  (129.0, 228.0, 3.0),
#  (129.0, 659.0, 3.0),
#  (129.0, 609.0, 3.0),
#  (129.0, 593.0, 5.0),
#  (129.0, 281.0, 3.0),
#  (129.0, 124.0, 5.0),
#  (129.0, 761.0, 5.0),
#  (129.0, 139.0, 3.0),
#  (129.0, 315.0, 5.0),
#  (129.0, 271.0, 3.0),
#  (129.0, 82.0, 5.0),
#  (130.0, 212.0, 5.0),
#  (131.0, 349.0, 5.0),
#  (131.0, 349.0, 5.0),
#  (131.0, 729.0, 5.0),
#  (131.0, 315.0, 3.0),
#  (131.0, 522.0, 5.0),
#  (131.0, 704.0, 5.0),
#  (131.0, 475.0, 5.0),
#  (131.0, 676.0, 3.0),
#  (131.0, 263.0, 5.0),
#  (132.0, 71.0, 5.0),
#  (133.0, 125.0, 0.0),
#  (134.0, 626.0, 5.0),
#  (134.0, 316.0, 5.0),
#  (135.0, 611.0, 5.0),
#  (136.0, 619.0, 0.0),
#  (137.0, 71.0, 5.0),
#  (138.0, 617.0, 3.0),
#  (138.0, 375.0, 3.0),
#  (139.0, 316.0, 5.0),
#  (139.0, 583.0, 5.0),
#  (139.0, 430.0, 5.0),
#  (139.0, 82.0, 5.0),
#  (139.0, 374.0, 5.0),
#  (139.0, 238.0, 5.0),
#  (139.0, 628.0, 5.0),
#  (139.0, 619.0, 5.0),
#  (139.0, 339.0, 3.0),
#  (139.0, 533.0, 5.0),
#  (139.0, 336.0, 5.0),
#  (139.0, 501.0, 5.0),
#  (139.0, 270.0, 5.0),
#  (139.0, 211.0, 5.0),
#  (139.0, 472.0, 3.0),
#  (140.0, 593.0, 0.0),
#  (140.0, 507.0, 0.0),
#  (141.0, 175.0, 5.0),
#  (142.0, 65.0, 3.0),
#  (143.0, 322.0, 3.0),
#  (143.0, 219.0, 5.0),
#  (143.0, 464.0, 5.0),
#  (144.0, 477.0, 5.0),
#  (145.0, 703.0, 5.0),
#  (146.0, 322.0, 0.0),
#  (147.0, 362.0, 5.0),
#  (148.0, 659.0, 5.0),
#  (149.0, 592.0, 5.0),
#  (150.0, 551.0, 0.0),
#  (151.0, 512.0, 0.0),
#  (151.0, 315.0, 5.0),
#  (152.0, 184.0, 0.0),
#  (153.0, 362.0, 5.0),
#  (154.0, 271.0, 5.0),
#  (154.0, 82.0, 5.0),
#  (155.0, 598.0, 3.0),
#  (155.0, 533.0, 3.0),
#  (155.0, 327.0, 5.0),
#  (155.0, 124.0, 5.0),
#  (155.0, 363.0, 5.0),
#  (155.0, 71.0, 3.0),
#  (156.0, 593.0, 0.0),
#  (157.0, 630.0, 5.0),
#  (157.0, 263.0, 5.0),
#  (157.0, 264.0, 5.0),
#  (157.0, 139.0, 5.0),
#  (157.0, 106.0, 3.0),
#  (157.0, 388.0, 0.0),
#  (157.0, 375.0, 5.0),
#  (157.0, 263.0, 5.0),
#  (157.0, 743.0, 3.0),
#  (157.0, 125.0, 3.0),
#  (157.0, 363.0, 5.0),
#  (157.0, 729.0, 5.0),
#  (157.0, 108.0, 3.0),
#  (157.0, 729.0, 5.0),
#  (157.0, 708.0, 3.0),
#  (157.0, 315.0, 5.0),
#  (157.0, 523.0, 5.0),
#  (157.0, 315.0, 5.0),
#  (157.0, 404.0, 3.0),
#  (157.0, 727.0, 3.0),
#  (157.0, 364.0, 5.0),
#  (157.0, 139.0, 5.0),
#  (157.0, 421.0, 3.0),
#  (157.0, 501.0, 5.0),
#  (157.0, 598.0, 5.0),
#  (157.0, 533.0, 3.0),
#  (157.0, 67.0, 3.0),
#  (157.0, 593.0, 5.0),
#  (157.0, 169.0, 5.0),
#  (157.0, 403.0, 3.0),
#  (157.0, 139.0, 5.0),
#  (157.0, 611.0, 5.0),
#  (157.0, 13.0, 5.0),
#  (157.0, 504.0, 3.0),
#  (157.0, 154.0, 3.0),
#  (157.0, 392.0, 5.0),
#  (157.0, 158.0, 5.0),
#  (157.0, 704.0, 5.0),
#  (157.0, 583.0, 5.0),
#  (157.0, 689.0, 5.0),
#  (157.0, 656.0, 5.0),
#  (157.0, 506.0, 3.0),
#  (157.0, 686.0, 5.0),
#  (157.0, 619.0, 5.0),
#  (157.0, 522.0, 5.0),
#  (157.0, 686.0, 5.0),
#  (157.0, 713.0, 3.0),
#  (158.0, 609.0, 3.0),
#  (158.0, 181.0, 5.0),
#  (158.0, 451.0, 3.0),
#  (158.0, 769.0, 5.0),
#  (159.0, 243.0, 5.0),
#  (160.0, 713.0, 5.0),
#  (160.0, 316.0, 3.0),
#  (160.0, 461.0, 5.0),
#  (160.0, 752.0, 5.0),
#  (160.0, 398.0, 3.0),
#  (160.0, 315.0, 5.0),
#  (160.0, 729.0, 5.0),
#  (160.0, 655.0, 5.0),
#  (160.0, 95.0, 3.0),
#  (161.0, 592.0, 5.0),
#  (162.0, 243.0, 5.0),
#  (162.0, 124.0, 5.0),
#  (163.0, 288.0, 5.0),
#  (164.0, 175.0, 5.0),
#  (164.0, 82.0, 5.0),
#  (164.0, 574.0, 5.0),
#  (164.0, 463.0, 5.0),
#  (164.0, 460.0, 5.0),
#  (164.0, 427.0, 5.0),
#  (164.0, 659.0, 5.0),
#  (164.0, 322.0, 5.0),
#  (165.0, 186.0, 5.0),
#  (165.0, 315.0, 3.0),
#  (165.0, 82.0, 5.0),
#  (165.0, 154.0, 5.0),
#  (165.0, 24.0, 5.0),
#  (165.0, 505.0, 5.0),
#  (165.0, 315.0, 5.0),
#  (165.0, 439.0, 3.0),
#  (165.0, 423.0, 5.0),
#  (165.0, 71.0, 5.0),
#  (165.0, 266.0, 5.0),
#  (165.0, 243.0, 5.0),
#  (165.0, 611.0, 5.0),
#  (165.0, 403.0, 3.0),
#  (165.0, 593.0, 3.0),
#  (165.0, 598.0, 3.0),
#  (165.0, 196.0, 3.0),
#  (165.0, 403.0, 3.0),
#  (165.0, 139.0, 5.0),
#  (165.0, 403.0, 3.0),
#  (166.0, 124.0, 0.0),
#  (166.0, 619.0, 5.0),
#  (166.0, 254.0, 3.0),
#  (166.0, 1.0, 3.0),
#  (166.0, 253.0, 5.0),
#  (166.0, 65.0, 5.0),
#  (167.0, 619.0, 5.0),
#  (167.0, 596.0, 3.0),
#  (167.0, 593.0, 3.0),
#  (168.0, 484.0, 0.0),
#  (169.0, 476.0, 5.0),
#  (169.0, 670.0, 3.0),
#  (169.0, 184.0, 5.0),
#  (169.0, 682.0, 5.0),
#  (169.0, 719.0, 5.0),
#  (170.0, 341.0, 0.0),
#  (170.0, 676.0, 5.0),
#  (171.0, 304.0, 5.0),
#  (172.0, 592.0, 5.0),
#  (172.0, 65.0, 3.0),
#  (172.0, 247.0, 3.0),
#  (173.0, 652.0, 5.0),
#  (173.0, 65.0, 5.0),
#  (174.0, 295.0, 3.0),
#  (175.0, 524.0, 5.0),
#  (175.0, 521.0, 3.0),
#  (175.0, 263.0, 5.0),
#  (176.0, 198.0, 5.0),
#  (176.0, 11.0, 5.0),
#  (177.0, 609.0, 5.0),
#  (178.0, 376.0, 5.0),
#  (179.0, 72.0, 5.0),
#  (180.0, 315.0, 5.0),
#  (180.0, 659.0, 5.0),
#  (181.0, 582.0, 5.0),
#  (181.0, 676.0, 5.0),
#  (181.0, 574.0, 5.0),
#  (181.0, 650.0, 0.0),
#  (181.0, 719.0, 5.0),
#  (181.0, 421.0, 5.0),
#  (182.0, 592.0, 5.0),
#  (183.0, 108.0, 5.0),
#  (184.0, 598.0, 0.0),
#  (185.0, 627.0, 5.0),
#  (186.0, 557.0, 5.0),
#  (187.0, 501.0, 5.0),
#  (188.0, 30.0, 5.0),
#  (189.0, 152.0, 5.0),
#  (190.0, 315.0, 5.0),
#  (191.0, 270.0, 0.0),
#  (192.0, 592.0, 5.0),
#  (193.0, 108.0, 5.0),
#  (193.0, 315.0, 5.0),
#  (193.0, 704.0, 5.0),
#  (194.0, 243.0, 5.0),
#  (194.0, 619.0, 5.0),
#  (195.0, 398.0, 5.0),
#  (195.0, 382.0, 5.0),
#  (195.0, 692.0, 5.0),
#  (195.0, 82.0, 3.0),
#  (195.0, 353.0, 3.0),
#  (195.0, 304.0, 5.0),
#  (195.0, 376.0, 5.0),
#  (195.0, 341.0, 5.0),
#  (195.0, 399.0, 3.0),
#  (195.0, 582.0, 5.0),
#  (195.0, 16.0, 3.0),
#  (196.0, 418.0, 5.0),
#  (196.0, 15.0, 5.0),
#  (197.0, 701.0, 0.0),
#  (197.0, 714.0, 5.0),
#  (197.0, 403.0, 0.0),
#  (197.0, 198.0, 3.0),
#  (197.0, 228.0, 5.0),
#  (198.0, 592.0, 5.0),
#  (198.0, 172.0, 5.0),
#  (198.0, 427.0, 5.0),
#  (198.0, 264.0, 5.0),
#  (198.0, 413.0, 5.0),
#  (198.0, 515.0, 5.0),
#  (198.0, 328.0, 3.0),
#  (198.0, 169.0, 3.0),
#  (198.0, 245.0, 5.0),
#  (198.0, 11.0, 5.0),
#  (198.0, 268.0, 3.0),
#  (198.0, 62.0, 5.0),
#  (198.0, 264.0, 5.0),
#  (198.0, 499.0, 3.0),
#  (198.0, 593.0, 5.0),
#  (198.0, 224.0, 3.0),
#  (198.0, 266.0, 3.0),
#  (198.0, 681.0, 5.0),
#  (198.0, 518.0, 3.0),
#  (198.0, 630.0, 5.0),
#  (198.0, 108.0, 5.0),
#  (198.0, 102.0, 5.0),
#  (198.0, 1.0, 5.0),
#  (198.0, 480.0, 5.0),
#  (198.0, 495.0, 3.0),
#  (198.0, 598.0, 5.0),
#  (198.0, 344.0, 5.0),
#  (198.0, 362.0, 5.0),
#  (198.0, 185.0, 0.0),
#  (198.0, 88.0, 5.0),
#  (198.0, 626.0, 5.0),
#  (198.0, 522.0, 5.0),
#  (198.0, 64.0, 0.0),
#  (198.0, 82.0, 5.0),
#  (198.0, 36.0, 5.0),
#  (198.0, 404.0, 5.0),
#  (198.0, 243.0, 5.0),
#  (198.0, 228.0, 3.0),
#  (198.0, 175.0, 5.0),
#  (198.0, 536.0, 3.0),
#  (198.0, 578.0, 5.0),
#  (198.0, 382.0, 5.0),
#  (198.0, 722.0, 3.0),
#  (198.0, 571.0, 5.0),
#  (198.0, 496.0, 5.0),
#  (198.0, 111.0, 5.0),
#  (199.0, 322.0, 5.0),
#  (200.0, 82.0, 5.0),
#  (200.0, 315.0, 5.0),
#  (200.0, 328.0, 3.0),
#  (200.0, 501.0, 5.0),
#  (201.0, 510.0, 5.0),
#  (202.0, 619.0, 5.0),
#  (203.0, 290.0, 3.0),
#  (204.0, 682.0, 5.0),
#  (205.0, 466.0, 5.0),
#  (205.0, 501.0, 5.0),
#  (206.0, 574.0, 5.0),
#  (207.0, 243.0, 3.0),
#  (207.0, 404.0, 5.0),
#  (208.0, 124.0, 5.0),
#  (209.0, 469.0, 5.0),
#  (210.0, 309.0, 3.0),
#  (210.0, 583.0, 3.0),
#  (210.0, 551.0, 3.0),
#  ...]

# %%
ncf = cornac.models.recommender.Recommender('NeuMF')
ncf.early_stop
# Out:
# <bound method Recommender.early_stop of <cornac.models.recommender.Recommender object at 0x7f29c83498d0>>

# %%
# Instantiate evaluation metrics
ndcg = cornac.metrics.NDCG(k=TOP_K)
pre = cornac.metrics.Precision(k=TOP_K)
rec = cornac.metrics.Recall(k=TOP_K)
fm = cornac.metrics.FMeasure(k=TOP_K)

# %%
#Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=data,
    test_size=0.1,
    val_size=0.1,
    rating_threshold=1.0,
    seed=123,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_neg=50,
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

# RandomSearch
rs_neumf = RandomSearch(
    model = neumf,
    space=[
        Discrete("num_epochs", [50, 100, 150, 200]),
        Discrete("num_factors", [4, 8]),
        Discrete("batch_size", [128, 256, 512]),
        Continuous("lr", 0.001, 0.01)
    ],
    metric = fm,
    eval_method = ratio_split
)
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 3718
# Number of items = 735
# Number of ratings = 12937
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 3.9
# ---
# Test data:
# Number of users = 816
# Number of items = 379
# Number of ratings = 1435
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Validation data:
# Number of users = 775
# Number of items = 380
# Number of ratings = 1438
# ---
# Total users = 3718
# Total items = 735

# %%
# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[rs_neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# [RandomSearch_NeuMF] Training started!
# Evaluating: {'batch_size': 512, 'lr': 0.007416597884709045, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.218167 (delta = -0.004148)
# Evaluating: {'batch_size': 512, 'lr': 0.005961832921746022, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 5, stopped epoch = 10
# - best monitored value = 0.219004 (delta = -0.006621)
# Evaluating: {'batch_size': 256, 'lr': 0.00982687778546154, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 5, stopped epoch = 10
# - best monitored value = 0.219471 (delta = -0.032542)
# Evaluating: {'batch_size': 512, 'lr': 0.002259556863673461, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.219236 (delta = -0.003871)
# Evaluating: {'batch_size': 128, 'lr': 0.0075614473664563754, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 3, stopped epoch = 8
# - best monitored value = 0.218575 (delta = -0.019690)
# Evaluating: {'batch_size': 256, 'lr': 0.007252796594667422, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 6, stopped epoch = 11
# - best monitored value = 0.218302 (delta = -0.015926)
# Evaluating: {'batch_size': 256, 'lr': 0.0026424255740815, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 12, stopped epoch = 17
# - best monitored value = 0.220882 (delta = -0.008977)
# Evaluating: {'batch_size': 512, 'lr': 0.0057864482838717955, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 3, stopped epoch = 8
# - best monitored value = 0.217696 (delta = -0.006200)
# Evaluating: {'batch_size': 128, 'lr': 0.005428762991131081, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 1, stopped epoch = 6
# - best monitored value = 0.215979 (delta = -0.004504)
# Evaluating: {'batch_size': 128, 'lr': 0.007501990443131995, 'num_epochs': 100, 'num_factors': 8}
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 2, stopped epoch = 7
# - best monitored value = 0.219940 (delta = -0.027201)
# Best parameter settings: {'batch_size': 512, 'lr': 0.0057864482838717955, 'num_epochs': 50, 'num_factors': 8}
# F1@5 = 0.0479
#
# [RandomSearch_NeuMF] Evaluation started!
# Ranking:   0%|          | 0/816 [00:00<?, ?it/s]
# Ranking:   0%|          | 0/775 [00:00<?, ?it/s]
# VALIDATION:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Time (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------
# RandomSearch_NeuMF | 0.0479 | 0.0771 |      0.0348 |   0.1054 |   1.2932
#
# TEST:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------- + --------
# RandomSearch_NeuMF | 0.0376 | 0.0617 |      0.0264 |   0.0855 | 1343.0973 |   1.4212

# %%
print('Random search: ', rs_neumf.best_params)
# Out:
# Random search:  {'batch_size': 512, 'lr': 0.0057864482838717955, 'num_epochs': 50, 'num_factors': 8}

# %%
ratio_split = RatioSplit(
    data=data,
    test_size=0,
    rating_threshold=1.0,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    num_factors = rs_neumf.best_params['num_factors'],
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_epochs = rs_neumf.best_params['num_epochs'],
    lr=rs_neumf.best_params['lr'],
    num_neg=50,
    batch_size = rs_neumf.best_params['batch_size'],
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 4181
# Number of items = 771
# Number of ratings = 16002
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 3.9
# ---
# Test data:
# Number of users = 4181
# Number of items = 771
# Number of ratings = 16002
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 4181
# Total items = 771
#
# [NeuMF] Training started!
#   0%|          | 0/50 [00:00<?, ?it/s]
# [NeuMF] Evaluation started!
# Ranking:   0%|          | 0/4181 [00:00<?, ?it/s]
# TEST:
# ...
#       |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ----- + ------ + ------ + ----------- + -------- + --------- + --------
# NeuMF | 0.3284 | 0.7045 |      0.2745 |   0.7057 |  783.9693 |   6.2789

# %%
# import pandas as pd
# pred_user = pd.read_csv('../../common/data/survey_result.csv')
# pred_user = set(pred_user['u_id'])

# %%
all_prediction = pd.DataFrame(columns=['u_id','p_id','ncf_score'])

for u_idx, u_id in tqdm(enumerate(data_df['u_id'].unique())):
  
      tmp = pd.DataFrame(neumf.rank(u_idx)).T
      tmp['u_id'] = u_id
      tmp = pd.DataFrame(tmp,columns=['u_id',0,1])
      tmp.rename(columns={0:'p_id',1:'ncf_score'}, inplace=True)
      all_prediction = all_prediction.append(tmp)

# %%
all_prediction
# Out:
#      u_id   p_id     ncf_score
# 0       0    0.0  7.680669e-01
# 1       0   95.0  7.134557e-03
# 2       0   62.0  2.077591e-02
# 3       0  120.0  8.197844e-03
# 4       0   32.0  1.254348e-01
# ..    ...    ...           ...
# 766  4180  539.0  2.130866e-05
# 767  4180  697.0  8.901954e-05
# 768  4180  758.0  1.146791e-03
# 769  4180  607.0  7.503782e-08
# 770  4180  715.0  3.904436e-05
#
# [3223551 rows x 3 columns]

# %%
len(all_prediction['u_id']==107)

# %%
all_prediction.to_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/강남구_restuarant_ncf_scores.csv',index=False)

# %%
a = pd.DataFrame(neumf.rank(1)).T
a
# Out:
#          0         1
# 0    266.0  0.005948
# 1    128.0  0.111813
# 2     37.0  0.019841
# 3    120.0  0.058922
# 4     13.0  0.032786
# ..     ...       ...
# 766  642.0  0.000004
# 767  720.0  0.000933
# 768  724.0  0.000095
# 769  607.0  0.000146
# 770  335.0  0.000943
#
# [771 rows x 2 columns]

# %%
len(a.iloc[:,0].unique())
# Out:
# 771

# %%
# a = pd.DataFrame(neumf.rank(2)).T
# a

# %%
len(a.iloc[:,0].unique())
# Out:
# 771

# %%
a.to_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_restuarant_exxxx2')

# %%
from keras.models import load_model

ncf.save('/content/drive/MyDrive/Colab Notebooks/data/강남구_restuarant_ncf_eat2.h5')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/data/강남구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_18-38-21-096662.pkl'

# %%
a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_restuarant_exxxx2')

# %%
# neumf = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_14-21-04-991292.pkl')
