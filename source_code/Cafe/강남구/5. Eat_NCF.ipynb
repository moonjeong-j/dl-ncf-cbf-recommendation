# %%
pip uninstall scikit-learn -y
# Out:
# Found existing installation: scikit-learn 1.0.2
# Uninstalling scikit-learn-1.0.2:
#   Successfully uninstalled scikit-learn-1.0.2

# %%
pip uninstall cornac -y
# Out:
# Found existing installation: cornac 1.14.2
# Uninstalling cornac-1.14.2:
#   Successfully uninstalled cornac-1.14.2

# %%
pip uninstall tensorflow==2.9.1 -y
# Out:
# Found existing installation: tensorflow 1.15.2
# Uninstalling tensorflow-1.15.2:
#   Successfully uninstalled tensorflow-1.15.2

# %%
pip install scikit-learn==0.22.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 9.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.1.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.4.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.1 which is incompatible.
# Successfully installed scikit-learn-0.22.1

# %%
pip install cornac==1.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cornac==1.6.1
#   Downloading cornac-1.6.1-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 8.4 MB/s
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (4.64.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.21.6)
# Installing collected packages: cornac
# Successfully installed cornac-1.6.1

# %%
pip install tensorflow==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.15.2
#   Downloading tensorflow-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (110.5 MB)
#      |████████████████████████████████| 110.5 MB 40 kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.47.0)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 62.2 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.8.1)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.4 MB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 25.2 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.14.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.37.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=ee121355b55a0a8cc32a1cf4cf948a907153cb13cd157d9bfd1a87d27db4b1ef
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
#     Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.2 tensorflow-estimator-1.15.1

# %%
# pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 33 kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.46.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.15.2

# %%
pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 34 kB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 51.7 MB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 64.1 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.47.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.1 MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=40e5ce2c6e030bf6aa01e2791506912c562f1a3c1a831ef8d56b7063b095a91b
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorboard<2.9,>=2.8, but you have tensorboard 1.15.0 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorflow-estimator<2.9,>=2.8, but you have tensorflow-estimator 1.15.1 which is incompatible.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.2

# %%
# %tensorflow_version 1.15
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# WARNING: Tensorflow 1 is deprecated, and support will be removed on August 1, 2022.
# After that, `%tensorflow_version 1.x` will throw an error.
#
# Your notebook should be updated to use Tensorflow 2.
# See the guide at https://www.tensorflow.org/guide/migrate#migrate-from-tensorflow-1x-to-tensorflow-2.
#
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cornac
import cornac.eval_methods
from cornac.eval_methods import RatioSplit, base_method
from cornac.hyperopt import Continuous, Discrete, RandomSearch
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# 추천할 top k개의 장소
TOP_K = 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_score_board.csv', index_col =0)

# %%
data_df['rating'] =data_df['rating'].astype('float')
data_df = data_df.rename({'u_id':'userID','p_id':'itemID'},axis=1)
#data_df = data_df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
data_df = data_df.fillna(5)

# %%
data_df
# Out:
#       itemID  rating
# u_id
# 0        701     5.0
# 0        594     3.0
# 0         17     5.0
# 0        182     5.0
# 0        443     5.0
# ...      ...     ...
# 2585     758     3.0
# 2586     308     5.0
# 2586     803     0.0
# 2586     204     5.0
# 2587     609     5.0
#
# [11294 rows x 2 columns]

# %%
data_df.reset_index(inplace=True)
data_df
# Out:
#        u_id  itemID  rating
# 0         0     701     5.0
# 1         0     594     3.0
# 2         0      17     5.0
# 3         0     182     5.0
# 4         0     443     5.0
# ...     ...     ...     ...
# 11289  2585     758     3.0
# 11290  2586     308     5.0
# 11291  2586     803     0.0
# 11292  2586     204     5.0
# 11293  2587     609     5.0
#
# [11294 rows x 3 columns]

# %%
data = [tuple(x) for x in data_df.values]
data
# Out:
# [(0.0, 701.0, 5.0),
#  (0.0, 594.0, 3.0),
#  (0.0, 17.0, 5.0),
#  (0.0, 182.0, 5.0),
#  (0.0, 443.0, 5.0),
#  (0.0, 55.0, 3.0),
#  (0.0, 560.0, 3.0),
#  (0.0, 452.0, 5.0),
#  (0.0, 115.0, 3.0),
#  (0.0, 520.0, 3.0),
#  (0.0, 117.0, 5.0),
#  (1.0, 425.0, 5.0),
#  (2.0, 344.0, 3.0),
#  (2.0, 236.0, 3.0),
#  (2.0, 234.0, 3.0),
#  (2.0, 234.0, 5.0),
#  (2.0, 629.0, 5.0),
#  (2.0, 613.0, 3.0),
#  (2.0, 22.0, 3.0),
#  (2.0, 629.0, 5.0),
#  (2.0, 656.0, 5.0),
#  (2.0, 700.0, 3.0),
#  (2.0, 563.0, 3.0),
#  (2.0, 319.0, 5.0),
#  (2.0, 758.0, 3.0),
#  (2.0, 147.0, 5.0),
#  (2.0, 385.0, 3.0),
#  (2.0, 810.0, 5.0),
#  (2.0, 118.0, 3.0),
#  (2.0, 715.0, 3.0),
#  (2.0, 178.0, 5.0),
#  (2.0, 639.0, 3.0),
#  (2.0, 529.0, 3.0),
#  (3.0, 185.0, 3.0),
#  (4.0, 646.0, 5.0),
#  (5.0, 443.0, 5.0),
#  (5.0, 425.0, 3.0),
#  (5.0, 283.0, 5.0),
#  (5.0, 836.0, 3.0),
#  (5.0, 788.0, 0.0),
#  (5.0, 385.0, 0.0),
#  (5.0, 557.0, 3.0),
#  (5.0, 656.0, 3.0),
#  (5.0, 549.0, 3.0),
#  (5.0, 81.0, 3.0),
#  (5.0, 284.0, 0.0),
#  (5.0, 573.0, 0.0),
#  (5.0, 356.0, 3.0),
#  (5.0, 720.0, 0.0),
#  (5.0, 836.0, 3.0),
#  (5.0, 635.0, 3.0),
#  (5.0, 768.0, 0.0),
#  (5.0, 635.0, 3.0),
#  (5.0, 635.0, 3.0),
#  (5.0, 145.0, 3.0),
#  (5.0, 860.0, 3.0),
#  (5.0, 356.0, 3.0),
#  (5.0, 27.0, 3.0),
#  (5.0, 357.0, 5.0),
#  (5.0, 847.0, 5.0),
#  (5.0, 319.0, 3.0),
#  (5.0, 166.0, 3.0),
#  (5.0, 657.0, 3.0),
#  (5.0, 269.0, 5.0),
#  (5.0, 385.0, 3.0),
#  (5.0, 425.0, 5.0),
#  (5.0, 85.0, 5.0),
#  (5.0, 279.0, 0.0),
#  (5.0, 532.0, 3.0),
#  (5.0, 50.0, 3.0),
#  (5.0, 269.0, 3.0),
#  (5.0, 127.0, 3.0),
#  (6.0, 561.0, 3.0),
#  (6.0, 422.0, 5.0),
#  (6.0, 557.0, 3.0),
#  (6.0, 279.0, 3.0),
#  (6.0, 232.0, 3.0),
#  (6.0, 376.0, 3.0),
#  (6.0, 82.0, 5.0),
#  (6.0, 164.0, 3.0),
#  (6.0, 58.0, 5.0),
#  (6.0, 476.0, 5.0),
#  (6.0, 536.0, 3.0),
#  (6.0, 385.0, 3.0),
#  (6.0, 584.0, 0.0),
#  (6.0, 402.0, 3.0),
#  (6.0, 422.0, 5.0),
#  (6.0, 348.0, 3.0),
#  (6.0, 278.0, 5.0),
#  (6.0, 340.0, 5.0),
#  (6.0, 234.0, 5.0),
#  (6.0, 779.0, 3.0),
#  (6.0, 844.0, 5.0),
#  (6.0, 443.0, 5.0),
#  (6.0, 693.0, 3.0),
#  (6.0, 345.0, 3.0),
#  (6.0, 656.0, 3.0),
#  (7.0, 85.0, 5.0),
#  (8.0, 657.0, 5.0),
#  (9.0, 831.0, 0.0),
#  (10.0, 383.0, 5.0),
#  (10.0, 865.0, 3.0),
#  (10.0, 845.0, 5.0),
#  (11.0, 425.0, 5.0),
#  (11.0, 45.0, 5.0),
#  (11.0, 543.0, 5.0),
#  (11.0, 603.0, 5.0),
#  (12.0, 779.0, 5.0),
#  (12.0, 357.0, 5.0),
#  (12.0, 758.0, 3.0),
#  (12.0, 561.0, 5.0),
#  (12.0, 230.0, 5.0),
#  (12.0, 140.0, 5.0),
#  (12.0, 765.0, 3.0),
#  (12.0, 62.0, 5.0),
#  (12.0, 130.0, 3.0),
#  (12.0, 422.0, 5.0),
#  (12.0, 308.0, 3.0),
#  (12.0, 310.0, 5.0),
#  (12.0, 562.0, 5.0),
#  (12.0, 762.0, 5.0),
#  (12.0, 629.0, 5.0),
#  (12.0, 629.0, 5.0),
#  (13.0, 422.0, 3.0),
#  (14.0, 205.0, 3.0),
#  (15.0, 629.0, 5.0),
#  (15.0, 350.0, 5.0),
#  (16.0, 826.0, 5.0),
#  (16.0, 385.0, 3.0),
#  (17.0, 579.0, 5.0),
#  (18.0, 310.0, 0.0),
#  (19.0, 826.0, 5.0),
#  (20.0, 183.0, 5.0),
#  (21.0, 532.0, 5.0),
#  (22.0, 762.0, 3.0),
#  (22.0, 279.0, 3.0),
#  (22.0, 435.0, 0.0),
#  (22.0, 629.0, 3.0),
#  (23.0, 173.0, 5.0),
#  (24.0, 608.0, 3.0),
#  (25.0, 866.0, 0.0),
#  (26.0, 712.0, 5.0),
#  (27.0, 384.0, 5.0),
#  (28.0, 147.0, 5.0),
#  (28.0, 279.0, 5.0),
#  (28.0, 254.0, 5.0),
#  (28.0, 845.0, 3.0),
#  (28.0, 16.0, 5.0),
#  (28.0, 768.0, 3.0),
#  (28.0, 234.0, 5.0),
#  (28.0, 557.0, 3.0),
#  (28.0, 169.0, 3.0),
#  (28.0, 44.0, 5.0),
#  (29.0, 575.0, 5.0),
#  (30.0, 422.0, 5.0),
#  (30.0, 784.0, 5.0),
#  (30.0, 37.0, 5.0),
#  (31.0, 145.0, 5.0),
#  (32.0, 356.0, 5.0),
#  (33.0, 447.0, 5.0),
#  (34.0, 557.0, 5.0),
#  (34.0, 147.0, 5.0),
#  (34.0, 422.0, 5.0),
#  (34.0, 92.0, 5.0),
#  (34.0, 79.0, 5.0),
#  (34.0, 147.0, 3.0),
#  (34.0, 92.0, 5.0),
#  (34.0, 430.0, 5.0),
#  (34.0, 357.0, 5.0),
#  (34.0, 575.0, 5.0),
#  (34.0, 44.0, 3.0),
#  (34.0, 629.0, 5.0),
#  (34.0, 31.0, 0.0),
#  (34.0, 543.0, 5.0),
#  (34.0, 81.0, 5.0),
#  (34.0, 629.0, 5.0),
#  (35.0, 860.0, 5.0),
#  (35.0, 357.0, 5.0),
#  (35.0, 646.0, 5.0),
#  (35.0, 699.0, 5.0),
#  (35.0, 109.0, 5.0),
#  (36.0, 49.0, 5.0),
#  (37.0, 430.0, 5.0),
#  (38.0, 357.0, 5.0),
#  (39.0, 339.0, 3.0),
#  (40.0, 635.0, 5.0),
#  (40.0, 762.0, 0.0),
#  (40.0, 329.0, 3.0),
#  (40.0, 440.0, 3.0),
#  (40.0, 594.0, 3.0),
#  (40.0, 357.0, 5.0),
#  (40.0, 594.0, 3.0),
#  (40.0, 340.0, 5.0),
#  (40.0, 82.0, 5.0),
#  (40.0, 398.0, 3.0),
#  (41.0, 846.0, 0.0),
#  (42.0, 64.0, 5.0),
#  (43.0, 561.0, 5.0),
#  (43.0, 166.0, 3.0),
#  (43.0, 49.0, 5.0),
#  (44.0, 220.0, 3.0),
#  (44.0, 356.0, 0.0),
#  (45.0, 443.0, 0.0),
#  (45.0, 308.0, 3.0),
#  (46.0, 230.0, 5.0),
#  (47.0, 107.0, 5.0),
#  (48.0, 339.0, 3.0),
#  (48.0, 463.0, 5.0),
#  (49.0, 363.0, 5.0),
#  (50.0, 635.0, 5.0),
#  (51.0, 268.0, 3.0),
#  (51.0, 284.0, 3.0),
#  (51.0, 351.0, 5.0),
#  (51.0, 842.0, 3.0),
#  (51.0, 278.0, 3.0),
#  (51.0, 169.0, 0.0),
#  (51.0, 145.0, 3.0),
#  (51.0, 532.0, 5.0),
#  (51.0, 794.0, 3.0),
#  (52.0, 563.0, 5.0),
#  (53.0, 640.0, 0.0),
#  (53.0, 115.0, 3.0),
#  (54.0, 629.0, 3.0),
#  (54.0, 850.0, 5.0),
#  (54.0, 584.0, 5.0),
#  (54.0, 230.0, 5.0),
#  (54.0, 810.0, 5.0),
#  (54.0, 340.0, 5.0),
#  (54.0, 130.0, 5.0),
#  (54.0, 430.0, 5.0),
#  (54.0, 199.0, 3.0),
#  (54.0, 765.0, 5.0),
#  (54.0, 412.0, 5.0),
#  (54.0, 762.0, 5.0),
#  (54.0, 363.0, 5.0),
#  (54.0, 601.0, 5.0),
#  (54.0, 656.0, 3.0),
#  (54.0, 768.0, 5.0),
#  (54.0, 45.0, 3.0),
#  (54.0, 469.0, 5.0),
#  (54.0, 363.0, 5.0),
#  (54.0, 831.0, 3.0),
#  (54.0, 79.0, 5.0),
#  (55.0, 532.0, 5.0),
#  (56.0, 145.0, 3.0),
#  (57.0, 399.0, 5.0),
#  (58.0, 440.0, 5.0),
#  (58.0, 779.0, 5.0),
#  (58.0, 147.0, 5.0),
#  (58.0, 788.0, 5.0),
#  (58.0, 458.0, 5.0),
#  (58.0, 55.0, 5.0),
#  (58.0, 772.0, 5.0),
#  (58.0, 67.0, 5.0),
#  (58.0, 385.0, 5.0),
#  (58.0, 196.0, 5.0),
#  (58.0, 425.0, 5.0),
#  (58.0, 443.0, 5.0),
#  (58.0, 55.0, 5.0),
#  (58.0, 278.0, 5.0),
#  (58.0, 241.0, 5.0),
#  (58.0, 794.0, 5.0),
#  (58.0, 868.0, 3.0),
#  (58.0, 629.0, 5.0),
#  (58.0, 758.0, 5.0),
#  (58.0, 557.0, 5.0),
#  (58.0, 812.0, 3.0),
#  (58.0, 788.0, 5.0),
#  (58.0, 656.0, 5.0),
#  (58.0, 557.0, 5.0),
#  (58.0, 635.0, 5.0),
#  (58.0, 531.0, 5.0),
#  (58.0, 812.0, 5.0),
#  (58.0, 129.0, 3.0),
#  (59.0, 762.0, 3.0),
#  (59.0, 435.0, 0.0),
#  (60.0, 857.0, 5.0),
#  (60.0, 584.0, 3.0),
#  (60.0, 351.0, 3.0),
#  (60.0, 847.0, 5.0),
#  (60.0, 591.0, 5.0),
#  (60.0, 810.0, 3.0),
#  (60.0, 557.0, 3.0),
#  (60.0, 284.0, 0.0),
#  (60.0, 504.0, 5.0),
#  (60.0, 385.0, 3.0),
#  (60.0, 532.0, 0.0),
#  (60.0, 273.0, 3.0),
#  (61.0, 425.0, 0.0),
#  (61.0, 656.0, 3.0),
#  (62.0, 794.0, 5.0),
#  (63.0, 536.0, 0.0),
#  (64.0, 656.0, 5.0),
#  (65.0, 269.0, 5.0),
#  (65.0, 341.0, 3.0),
#  (65.0, 284.0, 5.0),
#  (65.0, 271.0, 5.0),
#  (66.0, 495.0, 5.0),
#  (67.0, 82.0, 0.0),
#  (67.0, 115.0, 0.0),
#  (68.0, 345.0, 5.0),
#  (69.0, 356.0, 5.0),
#  (69.0, 234.0, 5.0),
#  (70.0, 93.0, 5.0),
#  (71.0, 610.0, 3.0),
#  (71.0, 273.0, 5.0),
#  (71.0, 536.0, 5.0),
#  (71.0, 273.0, 3.0),
#  (71.0, 846.0, 3.0),
#  (71.0, 871.0, 3.0),
#  (71.0, 387.0, 5.0),
#  (71.0, 104.0, 0.0),
#  (71.0, 405.0, 5.0),
#  (71.0, 405.0, 5.0),
#  (71.0, 351.0, 3.0),
#  (71.0, 468.0, 3.0),
#  (71.0, 58.0, 3.0),
#  (71.0, 273.0, 3.0),
#  (71.0, 209.0, 5.0),
#  (71.0, 629.0, 3.0),
#  (71.0, 38.0, 3.0),
#  (71.0, 44.0, 3.0),
#  (71.0, 821.0, 5.0),
#  (71.0, 532.0, 0.0),
#  (71.0, 230.0, 3.0),
#  (71.0, 779.0, 3.0),
#  (71.0, 161.0, 5.0),
#  (71.0, 115.0, 5.0),
#  (71.0, 161.0, 5.0),
#  (71.0, 170.0, 3.0),
#  (71.0, 810.0, 3.0),
#  (71.0, 79.0, 5.0),
#  (71.0, 692.0, 3.0),
#  (71.0, 765.0, 5.0),
#  (71.0, 160.0, 5.0),
#  (71.0, 225.0, 3.0),
#  (71.0, 635.0, 3.0),
#  (71.0, 425.0, 3.0),
#  (71.0, 456.0, 5.0),
#  (71.0, 185.0, 3.0),
#  (71.0, 693.0, 3.0),
#  (71.0, 635.0, 3.0),
#  (71.0, 160.0, 5.0),
#  (71.0, 147.0, 5.0),
#  (72.0, 340.0, 5.0),
#  (73.0, 44.0, 0.0),
#  (73.0, 279.0, 5.0),
#  (73.0, 62.0, 0.0),
#  (73.0, 656.0, 5.0),
#  (73.0, 138.0, 0.0),
#  (74.0, 147.0, 5.0),
#  (75.0, 712.0, 5.0),
#  (75.0, 826.0, 5.0),
#  (75.0, 712.0, 5.0),
#  (75.0, 363.0, 5.0),
#  (75.0, 225.0, 5.0),
#  (75.0, 145.0, 5.0),
#  (75.0, 147.0, 5.0),
#  (75.0, 425.0, 3.0),
#  (75.0, 536.0, 5.0),
#  (75.0, 850.0, 5.0),
#  (75.0, 749.0, 5.0),
#  (75.0, 279.0, 5.0),
#  (75.0, 632.0, 5.0),
#  (75.0, 443.0, 5.0),
#  (75.0, 236.0, 5.0),
#  (75.0, 130.0, 5.0),
#  (75.0, 138.0, 5.0),
#  (76.0, 537.0, 5.0),
#  (77.0, 282.0, 5.0),
#  (78.0, 835.0, 5.0),
#  (78.0, 629.0, 5.0),
#  (79.0, 239.0, 3.0),
#  (80.0, 571.0, 5.0),
#  (81.0, 646.0, 5.0),
#  (82.0, 794.0, 0.0),
#  (83.0, 443.0, 5.0),
#  (84.0, 586.0, 3.0),
#  (84.0, 799.0, 5.0),
#  (84.0, 147.0, 5.0),
#  (84.0, 147.0, 5.0),
#  (84.0, 871.0, 3.0),
#  (84.0, 257.0, 5.0),
#  (84.0, 592.0, 3.0),
#  (84.0, 44.0, 3.0),
#  (84.0, 629.0, 5.0),
#  (84.0, 561.0, 5.0),
#  (84.0, 435.0, 3.0),
#  (84.0, 345.0, 5.0),
#  (84.0, 340.0, 3.0),
#  (84.0, 81.0, 5.0),
#  (84.0, 341.0, 5.0),
#  (84.0, 483.0, 5.0),
#  (84.0, 269.0, 3.0),
#  (84.0, 450.0, 5.0),
#  (84.0, 405.0, 5.0),
#  (84.0, 584.0, 5.0),
#  (84.0, 425.0, 5.0),
#  (84.0, 79.0, 5.0),
#  (84.0, 779.0, 5.0),
#  (84.0, 563.0, 3.0),
#  (84.0, 402.0, 3.0),
#  (84.0, 775.0, 5.0),
#  (85.0, 405.0, 3.0),
#  (86.0, 273.0, 5.0),
#  (87.0, 825.0, 5.0),
#  (88.0, 562.0, 0.0),
#  (89.0, 425.0, 5.0),
#  (89.0, 45.0, 5.0),
#  (89.0, 601.0, 5.0),
#  (89.0, 845.0, 5.0),
#  (89.0, 225.0, 5.0),
#  (89.0, 227.0, 5.0),
#  (89.0, 319.0, 5.0),
#  (89.0, 710.0, 5.0),
#  (89.0, 388.0, 5.0),
#  (89.0, 398.0, 5.0),
#  (89.0, 265.0, 5.0),
#  (89.0, 678.0, 5.0),
#  (89.0, 220.0, 3.0),
#  (89.0, 821.0, 5.0),
#  (89.0, 344.0, 5.0),
#  (89.0, 351.0, 5.0),
#  (89.0, 265.0, 5.0),
#  (89.0, 306.0, 5.0),
#  (89.0, 562.0, 5.0),
#  (89.0, 700.0, 3.0),
#  (89.0, 523.0, 5.0),
#  (89.0, 208.0, 5.0),
#  (89.0, 145.0, 3.0),
#  (89.0, 38.0, 5.0),
#  (89.0, 543.0, 5.0),
#  (90.0, 585.0, 3.0),
#  (90.0, 591.0, 3.0),
#  (90.0, 395.0, 3.0),
#  (90.0, 676.0, 3.0),
#  (90.0, 31.0, 5.0),
#  (90.0, 846.0, 3.0),
#  (90.0, 357.0, 5.0),
#  (90.0, 279.0, 3.0),
#  (90.0, 435.0, 3.0),
#  (90.0, 532.0, 3.0),
#  (90.0, 385.0, 5.0),
#  (90.0, 603.0, 3.0),
#  (90.0, 606.0, 5.0),
#  (90.0, 435.0, 3.0),
#  (90.0, 587.0, 5.0),
#  (90.0, 382.0, 5.0),
#  (90.0, 206.0, 5.0),
#  (90.0, 629.0, 5.0),
#  (91.0, 598.0, 5.0),
#  (91.0, 644.0, 3.0),
#  (91.0, 629.0, 5.0),
#  (92.0, 79.0, 5.0),
#  (93.0, 757.0, 5.0),
#  (93.0, 158.0, 5.0),
#  (93.0, 826.0, 3.0),
#  (94.0, 383.0, 3.0),
#  (94.0, 350.0, 5.0),
#  (95.0, 479.0, 5.0),
#  (95.0, 443.0, 5.0),
#  (95.0, 280.0, 3.0),
#  (95.0, 140.0, 0.0),
#  (95.0, 271.0, 5.0),
#  (96.0, 768.0, 5.0),
#  (97.0, 758.0, 5.0),
#  (97.0, 758.0, 5.0),
#  (98.0, 293.0, 5.0),
#  (99.0, 462.0, 5.0),
#  (100.0, 420.0, 5.0),
#  (100.0, 630.0, 5.0),
#  (101.0, 363.0, 5.0),
#  (102.0, 761.0, 5.0),
#  (103.0, 656.0, 5.0),
#  (104.0, 261.0, 5.0),
#  (105.0, 284.0, 3.0),
#  (106.0, 532.0, 3.0),
#  (106.0, 787.0, 3.0),
#  (106.0, 234.0, 3.0),
#  (106.0, 762.0, 5.0),
#  (106.0, 228.0, 5.0),
#  (106.0, 762.0, 3.0),
#  (106.0, 762.0, 5.0),
#  (106.0, 265.0, 5.0),
#  (106.0, 239.0, 3.0),
#  (106.0, 138.0, 3.0),
#  (106.0, 282.0, 3.0),
#  (106.0, 44.0, 3.0),
#  (106.0, 341.0, 3.0),
#  (106.0, 742.0, 0.0),
#  (106.0, 749.0, 3.0),
#  (106.0, 38.0, 3.0),
#  (106.0, 563.0, 5.0),
#  (107.0, 395.0, 5.0),
#  (108.0, 213.0, 5.0),
#  (108.0, 810.0, 5.0),
#  (108.0, 772.0, 5.0),
#  (108.0, 536.0, 5.0),
#  (108.0, 435.0, 3.0),
#  (108.0, 230.0, 5.0),
#  (108.0, 575.0, 3.0),
#  (108.0, 115.0, 3.0),
#  (108.0, 425.0, 5.0),
#  (108.0, 425.0, 5.0),
#  (108.0, 384.0, 5.0),
#  (108.0, 38.0, 5.0),
#  (108.0, 94.0, 3.0),
#  (108.0, 561.0, 3.0),
#  (108.0, 350.0, 5.0),
#  (108.0, 261.0, 5.0),
#  (108.0, 127.0, 5.0),
#  (108.0, 762.0, 5.0),
#  (108.0, 425.0, 5.0),
#  (108.0, 82.0, 5.0),
#  (108.0, 560.0, 5.0),
#  (108.0, 44.0, 5.0),
#  (108.0, 44.0, 5.0),
#  (108.0, 800.0, 3.0),
#  (108.0, 584.0, 5.0),
#  (108.0, 147.0, 5.0),
#  (109.0, 363.0, 5.0),
#  (110.0, 390.0, 5.0),
#  (110.0, 206.0, 5.0),
#  (111.0, 308.0, 0.0),
#  (112.0, 598.0, 5.0),
#  (112.0, 127.0, 5.0),
#  (112.0, 81.0, 5.0),
#  (113.0, 199.0, 3.0),
#  (113.0, 425.0, 3.0),
#  (114.0, 632.0, 5.0),
#  (114.0, 603.0, 5.0),
#  (115.0, 679.0, 5.0),
#  (116.0, 284.0, 0.0),
#  (117.0, 584.0, 5.0),
#  (118.0, 536.0, 3.0),
#  (119.0, 339.0, 5.0),
#  (120.0, 49.0, 3.0),
#  (120.0, 220.0, 5.0),
#  (120.0, 699.0, 3.0),
#  (120.0, 433.0, 5.0),
#  (120.0, 138.0, 3.0),
#  (120.0, 656.0, 5.0),
#  (120.0, 336.0, 3.0),
#  (120.0, 440.0, 3.0),
#  (121.0, 339.0, 3.0),
#  (121.0, 500.0, 5.0),
#  (121.0, 422.0, 5.0),
#  (121.0, 109.0, 5.0),
#  (121.0, 785.0, 5.0),
#  (121.0, 644.0, 3.0),
#  (121.0, 644.0, 3.0),
#  (121.0, 872.0, 5.0),
#  (121.0, 372.0, 5.0),
#  (121.0, 221.0, 5.0),
#  (121.0, 104.0, 5.0),
#  (121.0, 274.0, 5.0),
#  (121.0, 129.0, 3.0),
#  (121.0, 49.0, 3.0),
#  (121.0, 603.0, 5.0),
#  (121.0, 49.0, 5.0),
#  (121.0, 58.0, 5.0),
#  (121.0, 762.0, 5.0),
#  (121.0, 221.0, 5.0),
#  (121.0, 826.0, 5.0),
#  (121.0, 854.0, 5.0),
#  (121.0, 820.0, 5.0),
#  (121.0, 6.0, 5.0),
#  (121.0, 127.0, 5.0),
#  (121.0, 601.0, 5.0),
#  (121.0, 130.0, 5.0),
#  (121.0, 28.0, 5.0),
#  (121.0, 227.0, 5.0),
#  (121.0, 385.0, 3.0),
#  (121.0, 360.0, 0.0),
#  (121.0, 586.0, 5.0),
#  (121.0, 627.0, 5.0),
#  (121.0, 234.0, 3.0),
#  (121.0, 38.0, 5.0),
#  (121.0, 257.0, 3.0),
#  (121.0, 169.0, 0.0),
#  (121.0, 584.0, 5.0),
#  (121.0, 55.0, 3.0),
#  (121.0, 385.0, 5.0),
#  (121.0, 283.0, 3.0),
#  (121.0, 562.0, 5.0),
#  (121.0, 279.0, 5.0),
#  (121.0, 562.0, 3.0),
#  (121.0, 290.0, 5.0),
#  (121.0, 425.0, 3.0),
#  (121.0, 479.0, 3.0),
#  (121.0, 210.0, 0.0),
#  (121.0, 471.0, 3.0),
#  (121.0, 279.0, 5.0),
#  (121.0, 826.0, 3.0),
#  (121.0, 279.0, 5.0),
#  (121.0, 248.0, 3.0),
#  (121.0, 788.0, 5.0),
#  (121.0, 463.0, 5.0),
#  (121.0, 559.0, 5.0),
#  (122.0, 766.0, 5.0),
#  (123.0, 284.0, 5.0),
#  (123.0, 357.0, 5.0),
#  (123.0, 49.0, 5.0),
#  (123.0, 656.0, 3.0),
#  (124.0, 318.0, 3.0),
#  (124.0, 284.0, 3.0),
#  (124.0, 183.0, 3.0),
#  (124.0, 712.0, 3.0),
#  (124.0, 629.0, 3.0),
#  (124.0, 440.0, 3.0),
#  (124.0, 357.0, 3.0),
#  (124.0, 656.0, 5.0),
#  (124.0, 848.0, 3.0),
#  (125.0, 561.0, 0.0),
#  (126.0, 215.0, 5.0),
#  (127.0, 176.0, 0.0),
#  (128.0, 261.0, 5.0),
#  (129.0, 166.0, 0.0),
#  (129.0, 319.0, 3.0),
#  (130.0, 138.0, 3.0),
#  (131.0, 425.0, 5.0),
#  (132.0, 633.0, 5.0),
#  (132.0, 779.0, 5.0),
#  (132.0, 439.0, 5.0),
#  (132.0, 249.0, 5.0),
#  (132.0, 845.0, 5.0),
#  (132.0, 403.0, 5.0),
#  (132.0, 569.0, 5.0),
#  (132.0, 282.0, 5.0),
#  (132.0, 38.0, 5.0),
#  (132.0, 407.0, 5.0),
#  (132.0, 635.0, 3.0),
#  (132.0, 656.0, 5.0),
#  (132.0, 858.0, 5.0),
#  (132.0, 779.0, 5.0),
#  (132.0, 656.0, 5.0),
#  (132.0, 486.0, 5.0),
#  (132.0, 435.0, 5.0),
#  (132.0, 825.0, 5.0),
#  (132.0, 644.0, 5.0),
#  (132.0, 788.0, 5.0),
#  (132.0, 575.0, 3.0),
#  (132.0, 385.0, 3.0),
#  (132.0, 708.0, 5.0),
#  (132.0, 213.0, 5.0),
#  (133.0, 278.0, 0.0),
#  (134.0, 597.0, 5.0),
#  (134.0, 210.0, 5.0),
#  (135.0, 840.0, 5.0),
#  (136.0, 138.0, 3.0),
#  (136.0, 794.0, 3.0),
#  (137.0, 325.0, 3.0),
#  (138.0, 204.0, 5.0),
#  (139.0, 279.0, 5.0),
#  (139.0, 443.0, 5.0),
#  (139.0, 289.0, 3.0),
#  (139.0, 532.0, 5.0),
#  (139.0, 866.0, 5.0),
#  (139.0, 115.0, 0.0),
#  (139.0, 290.0, 0.0),
#  (140.0, 319.0, 5.0),
#  (140.0, 575.0, 5.0),
#  (140.0, 635.0, 3.0),
#  (141.0, 334.0, 5.0),
#  (141.0, 557.0, 5.0),
#  (141.0, 278.0, 3.0),
#  (142.0, 147.0, 5.0),
#  (142.0, 357.0, 5.0),
#  (142.0, 869.0, 5.0),
#  (142.0, 81.0, 3.0),
#  (142.0, 382.0, 5.0),
#  (142.0, 109.0, 5.0),
#  (142.0, 357.0, 5.0),
#  (142.0, 109.0, 5.0),
#  (142.0, 712.0, 5.0),
#  (142.0, 779.0, 5.0),
#  (143.0, 41.0, 3.0),
#  (144.0, 385.0, 5.0),
#  (145.0, 383.0, 0.0),
#  (146.0, 462.0, 5.0),
#  (147.0, 805.0, 5.0),
#  (148.0, 576.0, 5.0),
#  (148.0, 644.0, 5.0),
#  (148.0, 339.0, 3.0),
#  (148.0, 458.0, 5.0),
#  (148.0, 440.0, 5.0),
#  (148.0, 384.0, 5.0),
#  (148.0, 779.0, 5.0),
#  (148.0, 779.0, 5.0),
#  (148.0, 117.0, 5.0),
#  (148.0, 49.0, 5.0),
#  (148.0, 601.0, 5.0),
#  (149.0, 844.0, 3.0),
#  (150.0, 383.0, 5.0),
#  (151.0, 138.0, 3.0),
#  (151.0, 145.0, 5.0),
#  (152.0, 279.0, 0.0),
#  (153.0, 278.0, 3.0),
#  (154.0, 357.0, 5.0),
#  (154.0, 269.0, 3.0),
#  (155.0, 584.0, 5.0),
#  (155.0, 576.0, 3.0),
#  (156.0, 864.0, 3.0),
#  (156.0, 844.0, 5.0),
#  (156.0, 635.0, 3.0),
#  (156.0, 409.0, 3.0),
#  (156.0, 820.0, 3.0),
#  (157.0, 712.0, 3.0),
#  (158.0, 357.0, 3.0),
#  (158.0, 308.0, 5.0),
#  (158.0, 832.0, 5.0),
#  (158.0, 610.0, 5.0),
#  (158.0, 832.0, 5.0),
#  (158.0, 280.0, 5.0),
#  (158.0, 425.0, 5.0),
#  (158.0, 230.0, 5.0),
#  (158.0, 425.0, 3.0),
#  (158.0, 147.0, 5.0),
#  (158.0, 225.0, 5.0),
#  (159.0, 230.0, 3.0),
#  (159.0, 761.0, 3.0),
#  (160.0, 452.0, 5.0),
#  (160.0, 560.0, 5.0),
#  (160.0, 345.0, 5.0),
#  (160.0, 261.0, 5.0),
#  (160.0, 210.0, 5.0),
#  (160.0, 398.0, 3.0),
#  (160.0, 662.0, 5.0),
#  (160.0, 483.0, 5.0),
#  (161.0, 147.0, 5.0),
#  (162.0, 644.0, 5.0),
#  (163.0, 584.0, 5.0),
#  (163.0, 142.0, 0.0),
#  (164.0, 227.0, 5.0),
#  (165.0, 49.0, 5.0),
#  (166.0, 278.0, 3.0),
#  (166.0, 173.0, 5.0),
#  (166.0, 598.0, 5.0),
#  (166.0, 4.0, 5.0),
#  (166.0, 161.0, 5.0),
#  (167.0, 182.0, 5.0),
#  (168.0, 356.0, 0.0),
#  (169.0, 220.0, 5.0),
#  (169.0, 147.0, 5.0),
#  (169.0, 234.0, 5.0),
#  (169.0, 844.0, 5.0),
#  (169.0, 388.0, 5.0),
#  (169.0, 629.0, 5.0),
#  (169.0, 31.0, 5.0),
#  (170.0, 425.0, 3.0),
#  (171.0, 175.0, 0.0),
#  (172.0, 45.0, 3.0),
#  (173.0, 826.0, 3.0),
#  (173.0, 147.0, 5.0),
#  (173.0, 562.0, 5.0),
#  (173.0, 656.0, 5.0),
#  (173.0, 145.0, 5.0),
#  (173.0, 656.0, 5.0),
#  (174.0, 230.0, 5.0),
#  (175.0, 355.0, 5.0),
#  (176.0, 832.0, 5.0),
#  (177.0, 341.0, 5.0),
#  (177.0, 532.0, 5.0),
#  (177.0, 388.0, 3.0),
#  (178.0, 228.0, 5.0),
#  (179.0, 845.0, 5.0),
#  (179.0, 712.0, 3.0),
#  (179.0, 779.0, 5.0),
#  (180.0, 820.0, 5.0),
#  (181.0, 445.0, 5.0),
#  (182.0, 79.0, 5.0),
#  (182.0, 79.0, 5.0),
#  (183.0, 220.0, 0.0),
#  (184.0, 629.0, 5.0),
#  (184.0, 758.0, 3.0),
#  (184.0, 147.0, 5.0),
#  (184.0, 832.0, 5.0),
#  (184.0, 563.0, 3.0),
#  (184.0, 273.0, 5.0),
#  (185.0, 710.0, 5.0),
#  (186.0, 766.0, 5.0),
#  (186.0, 302.0, 0.0),
#  (186.0, 465.0, 5.0),
#  (186.0, 65.0, 3.0),
#  (186.0, 58.0, 3.0),
#  (186.0, 609.0, 3.0),
#  (186.0, 210.0, 5.0),
#  (186.0, 209.0, 3.0),
#  (186.0, 795.0, 3.0),
#  (186.0, 387.0, 3.0),
#  (186.0, 286.0, 0.0),
#  (186.0, 81.0, 0.0),
#  (186.0, 311.0, 3.0),
#  (186.0, 414.0, 3.0),
#  (187.0, 532.0, 5.0),
#  (187.0, 363.0, 5.0),
#  (187.0, 94.0, 3.0),
#  (187.0, 425.0, 5.0),
#  (187.0, 278.0, 5.0),
#  (187.0, 319.0, 3.0),
#  (187.0, 38.0, 5.0),
#  (187.0, 442.0, 3.0),
#  (187.0, 357.0, 5.0),
#  (187.0, 220.0, 5.0),
#  (187.0, 433.0, 3.0),
#  (187.0, 747.0, 5.0),
#  (187.0, 225.0, 5.0),
#  (188.0, 49.0, 5.0),
#  (188.0, 717.0, 5.0),
#  (188.0, 357.0, 5.0),
#  (189.0, 254.0, 3.0),
#  (190.0, 410.0, 5.0),
#  (190.0, 654.0, 5.0),
#  (190.0, 784.0, 5.0),
#  (190.0, 584.0, 5.0),
#  (190.0, 92.0, 5.0),
#  (191.0, 635.0, 0.0),
#  (192.0, 425.0, 5.0),
#  (192.0, 130.0, 5.0),
#  (192.0, 557.0, 5.0),
#  (192.0, 768.0, 5.0),
#  (192.0, 561.0, 5.0),
#  (192.0, 121.0, 5.0),
#  (193.0, 210.0, 5.0),
#  (194.0, 869.0, 5.0),
#  (194.0, 383.0, 5.0),
#  (194.0, 515.0, 5.0),
#  (194.0, 425.0, 5.0),
#  (194.0, 355.0, 5.0),
#  (195.0, 273.0, 5.0),
#  (196.0, 656.0, 0.0),
#  (196.0, 656.0, 3.0),
#  (196.0, 264.0, 5.0),
#  (196.0, 532.0, 5.0),
#  (196.0, 425.0, 5.0),
#  (197.0, 632.0, 5.0),
#  (197.0, 500.0, 5.0),
#  (197.0, 668.0, 5.0),
#  (197.0, 757.0, 5.0),
#  (198.0, 44.0, 5.0),
#  (199.0, 538.0, 5.0),
#  (200.0, 310.0, 0.0),
#  (201.0, 357.0, 5.0),
#  (201.0, 656.0, 5.0),
#  (201.0, 240.0, 3.0),
#  (201.0, 183.0, 3.0),
#  (201.0, 279.0, 5.0),
#  (201.0, 712.0, 5.0),
#  (201.0, 609.0, 5.0),
#  (201.0, 384.0, 3.0),
#  (201.0, 257.0, 5.0),
#  (201.0, 646.0, 5.0),
#  (201.0, 221.0, 3.0),
#  (201.0, 693.0, 3.0),
#  (201.0, 345.0, 5.0),
#  (201.0, 560.0, 5.0),
#  (201.0, 385.0, 3.0),
#  (201.0, 50.0, 5.0),
#  (201.0, 561.0, 5.0),
#  (201.0, 440.0, 5.0),
#  (201.0, 557.0, 3.0),
#  (201.0, 79.0, 5.0),
#  (201.0, 451.0, 3.0),
#  (201.0, 712.0, 5.0),
#  (201.0, 92.0, 3.0),
#  (201.0, 430.0, 3.0),
#  (201.0, 786.0, 3.0),
#  (201.0, 430.0, 5.0),
#  (201.0, 199.0, 5.0),
#  (201.0, 43.0, 5.0),
#  (201.0, 357.0, 5.0),
#  (201.0, 79.0, 5.0),
#  (201.0, 629.0, 5.0),
#  (201.0, 385.0, 0.0),
#  (201.0, 115.0, 5.0),
#  (201.0, 837.0, 3.0),
#  (201.0, 603.0, 3.0),
#  (201.0, 364.0, 3.0),
#  (201.0, 635.0, 3.0),
#  (201.0, 821.0, 5.0),
#  (201.0, 228.0, 5.0),
#  (201.0, 810.0, 5.0),
#  (201.0, 609.0, 5.0),
#  (201.0, 93.0, 3.0),
#  (201.0, 8.0, 3.0),
#  (201.0, 810.0, 5.0),
#  (201.0, 532.0, 3.0),
#  (201.0, 656.0, 5.0),
#  (201.0, 632.0, 5.0),
#  (201.0, 656.0, 5.0),
#  (201.0, 463.0, 3.0),
#  (201.0, 96.0, 3.0),
#  (201.0, 765.0, 0.0),
#  (201.0, 575.0, 3.0),
#  (201.0, 293.0, 5.0),
#  (201.0, 302.0, 5.0),
#  (201.0, 584.0, 5.0),
#  (201.0, 350.0, 5.0),
#  (201.0, 847.0, 5.0),
#  (201.0, 656.0, 0.0),
#  (201.0, 370.0, 3.0),
#  (201.0, 575.0, 3.0),
#  (201.0, 563.0, 5.0),
#  (201.0, 239.0, 3.0),
#  (201.0, 144.0, 0.0),
#  (201.0, 584.0, 5.0),
#  (201.0, 104.0, 3.0),
#  (201.0, 561.0, 5.0),
#  (201.0, 357.0, 5.0),
#  (201.0, 398.0, 3.0),
#  (201.0, 663.0, 3.0),
#  (201.0, 768.0, 3.0),
#  (201.0, 28.0, 5.0),
#  (201.0, 283.0, 5.0),
#  (201.0, 273.0, 3.0),
#  (201.0, 845.0, 5.0),
#  (201.0, 182.0, 5.0),
#  (201.0, 779.0, 5.0),
#  (201.0, 758.0, 5.0),
#  (201.0, 530.0, 3.0),
#  (201.0, 609.0, 5.0),
#  (202.0, 5.0, 3.0),
#  (202.0, 820.0, 3.0),
#  (203.0, 138.0, 5.0),
#  (204.0, 643.0, 5.0),
#  (205.0, 356.0, 5.0),
#  (206.0, 576.0, 5.0),
#  (207.0, 363.0, 5.0),
#  (208.0, 624.0, 5.0),
#  (208.0, 576.0, 5.0),
#  (209.0, 440.0, 5.0),
#  (210.0, 45.0, 3.0),
#  (210.0, 435.0, 5.0),
#  (210.0, 762.0, 5.0),
#  (210.0, 279.0, 3.0),
#  (210.0, 41.0, 3.0),
#  (211.0, 397.0, 5.0),
#  (212.0, 629.0, 3.0),
#  (213.0, 386.0, 3.0),
#  (214.0, 854.0, 5.0),
#  (214.0, 854.0, 5.0),
#  (215.0, 832.0, 5.0),
#  (216.0, 431.0, 5.0),
#  (217.0, 359.0, 5.0),
#  (217.0, 269.0, 5.0),
#  (217.0, 869.0, 5.0),
#  (218.0, 435.0, 3.0),
#  (218.0, 184.0, 5.0),
#  (218.0, 718.0, 5.0),
#  (219.0, 433.0, 3.0),
#  (220.0, 187.0, 5.0),
#  (220.0, 38.0, 3.0),
#  (220.0, 79.0, 5.0),
#  (220.0, 584.0, 5.0),
#  (220.0, 79.0, 5.0),
#  (221.0, 601.0, 3.0),
#  (221.0, 425.0, 3.0),
#  (221.0, 385.0, 5.0),
#  (221.0, 772.0, 5.0),
#  (221.0, 586.0, 3.0),
#  (221.0, 611.0, 3.0),
#  (221.0, 278.0, 5.0),
#  (221.0, 689.0, 5.0),
#  (221.0, 584.0, 0.0),
#  (222.0, 138.0, 3.0),
#  (222.0, 656.0, 3.0),
#  (222.0, 49.0, 3.0),
#  (223.0, 350.0, 5.0),
#  (223.0, 810.0, 5.0),
#  (223.0, 264.0, 5.0),
#  (223.0, 251.0, 5.0),
#  (224.0, 206.0, 5.0),
#  (225.0, 378.0, 5.0),
#  (226.0, 810.0, 5.0),
#  (226.0, 532.0, 0.0),
#  (226.0, 147.0, 5.0),
#  (227.0, 261.0, 5.0),
#  (228.0, 271.0, 5.0),
#  (229.0, 804.0, 3.0),
#  (229.0, 856.0, 3.0),
#  (229.0, 847.0, 3.0),
#  (229.0, 429.0, 5.0),
#  (229.0, 210.0, 5.0),
#  (230.0, 351.0, 5.0),
#  (231.0, 826.0, 5.0),
#  (231.0, 724.0, 5.0),
#  (231.0, 656.0, 5.0),
#  (231.0, 382.0, 5.0),
#  (231.0, 385.0, 0.0),
#  (231.0, 847.0, 5.0),
#  (231.0, 440.0, 0.0),
#  (231.0, 847.0, 5.0),
#  (231.0, 656.0, 5.0),
#  (231.0, 469.0, 5.0),
#  (232.0, 109.0, 3.0),
#  (232.0, 257.0, 5.0),
#  (232.0, 531.0, 5.0),
#  (232.0, 109.0, 5.0),
#  (233.0, 271.0, 5.0),
#  (234.0, 225.0, 5.0),
#  ...]

# %%
ncf = cornac.models.recommender.Recommender('NeuMF')
ncf.early_stop
# Out:
# <bound method Recommender.early_stop of <cornac.models.recommender.Recommender object at 0x7f5be2c8df90>>

# %%
# Instantiate evaluation metrics
ndcg = cornac.metrics.NDCG(k=TOP_K)
pre = cornac.metrics.Precision(k=TOP_K)
rec = cornac.metrics.Recall(k=TOP_K)
fm = cornac.metrics.FMeasure(k=TOP_K)

# %%
#Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=data,
    test_size=0.1,
    val_size=0.1,
    rating_threshold=1.0,
    seed=123,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_neg=50,
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

# RandomSearch
rs_neumf = RandomSearch(
    model = neumf,
    space=[
        Discrete("num_epochs", [50, 100, 150, 200]),
        Discrete("num_factors", [4, 8]),
        Discrete("batch_size", [128, 256, 512]),
        Continuous("lr", 0.001, 0.01)
    ],
    metric = fm,
    eval_method = ratio_split
)
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 2295
# Number of items = 818
# Number of ratings = 8372
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 4.0
# ---
# Test data:
# Number of users = 503
# Number of items = 315
# Number of ratings = 942
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Validation data:
# Number of users = 471
# Number of items = 311
# Number of ratings = 927
# ---
# Total users = 2295
# Total items = 818

# %%
# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[rs_neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# [RandomSearch_NeuMF] Training started!
# Evaluating: {'batch_size': 512, 'lr': 0.007416597884709045, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 3, stopped epoch = 8
# - best monitored value = 0.206283 (delta = -0.007895)
# Evaluating: {'batch_size': 512, 'lr': 0.005961832921746022, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.205099 (delta = -0.006336)
# Evaluating: {'batch_size': 256, 'lr': 0.00982687778546154, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.208837 (delta = -0.004169)
# Evaluating: {'batch_size': 512, 'lr': 0.002259556863673461, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 6, stopped epoch = 11
# - best monitored value = 0.209454 (delta = -0.011067)
# Evaluating: {'batch_size': 128, 'lr': 0.0075614473664563754, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 4, stopped epoch = 9
# - best monitored value = 0.211821 (delta = -0.011354)
# Evaluating: {'batch_size': 256, 'lr': 0.007252796594667422, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 2, stopped epoch = 7
# - best monitored value = 0.206469 (delta = -0.003092)
# Evaluating: {'batch_size': 256, 'lr': 0.0026424255740815, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 12, stopped epoch = 17
# - best monitored value = 0.211674 (delta = -0.007302)
# Evaluating: {'batch_size': 512, 'lr': 0.0057864482838717955, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 2, stopped epoch = 7
# - best monitored value = 0.208511 (delta = -0.011225)
# Evaluating: {'batch_size': 128, 'lr': 0.005428762991131081, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 2, stopped epoch = 7
# - best monitored value = 0.203885 (delta = -0.002564)
# Evaluating: {'batch_size': 128, 'lr': 0.007501990443131995, 'num_epochs': 100, 'num_factors': 8}
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 8, stopped epoch = 13
# - best monitored value = 0.210020 (delta = -0.030703)
# Best parameter settings: {'batch_size': 128, 'lr': 0.0075614473664563754, 'num_epochs': 200, 'num_factors': 4}
# F1@5 = 0.0505
#
# [RandomSearch_NeuMF] Evaluation started!
# Ranking:   0%|          | 0/503 [00:00<?, ?it/s]
# Ranking:   0%|          | 0/471 [00:00<?, ?it/s]
# VALIDATION:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Time (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------
# RandomSearch_NeuMF | 0.0505 | 0.0757 |      0.0369 |   0.1049 |   0.7362
#
# TEST:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------- + --------
# RandomSearch_NeuMF | 0.0466 | 0.0828 |      0.0335 |   0.1027 |  815.2979 |   0.8235

# %%
print('Random search: ', rs_neumf.best_params)
# Out:
# Random search:  {'batch_size': 128, 'lr': 0.0075614473664563754, 'num_epochs': 200, 'num_factors': 4}

# %%
ratio_split = RatioSplit(
    data=data,
    test_size=0,
    rating_threshold=1.0,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    num_factors = rs_neumf.best_params['num_factors'],
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_epochs = rs_neumf.best_params['num_epochs'],
    lr=rs_neumf.best_params['lr'],
    num_neg=50,
    batch_size = rs_neumf.best_params['batch_size'],
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 2588
# Number of items = 872
# Number of ratings = 10329
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 4.0
# ---
# Test data:
# Number of users = 2588
# Number of items = 872
# Number of ratings = 10329
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 2588
# Total items = 872
#
# [NeuMF] Training started!
#   0%|          | 0/200 [00:00<?, ?it/s]
# [NeuMF] Evaluation started!
# Ranking:   0%|          | 0/2588 [00:00<?, ?it/s]
# TEST:
# ...
#       |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ----- + ------ + ------ + ----------- + -------- + --------- + --------
# NeuMF | 0.4784 | 0.9779 |      0.4306 |   0.9024 | 1899.4704 |   3.5955

# %%
# import pandas as pd
# pred_user = pd.read_csv('../../common/data/survey_result.csv')
# pred_user = set(pred_user['u_id'])

# %%
all_prediction = pd.DataFrame(columns=['u_id','p_id','ncf_score'])

for u_idx, u_id in tqdm(enumerate(data_df['u_id'].unique())):
  
      tmp = pd.DataFrame(neumf.rank(u_idx)).T
      tmp['u_id'] = u_id
      tmp = pd.DataFrame(tmp,columns=['u_id',0,1])
      tmp.rename(columns={0:'p_id',1:'ncf_score'}, inplace=True)
      all_prediction = all_prediction.append(tmp)
# Out:
# 2588it [01:50, 23.42it/s]

# %%
all_prediction
# Out:
#      u_id   p_id     ncf_score
# 0       0  296.0  9.624095e-01
# 1       0  459.0  9.935983e-01
# 2       0   54.0  1.490116e-06
# 3       0   84.0  9.967474e-01
# 4       0  110.0  7.807910e-04
# ..    ...    ...           ...
# 867  2587  563.0  2.980232e-08
# 868  2587  562.0  0.000000e+00
# 869  2587  560.0  0.000000e+00
# 870  2587  558.0  0.000000e+00
# 871  2587    0.0  0.000000e+00
#
# [2256736 rows x 3 columns]

# %%
len(all_prediction['u_id']==107)
# Out:
# 2256736

# %%
all_prediction.to_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/강남구_cafe_ncf_scores.csv',index=False)

# %%
a = pd.DataFrame(neumf.rank(1)).T
a
# Out:
#          0             1
# 0    110.0  1.128107e-03
# 1     81.0  9.484777e-01
# 2     20.0  8.322597e-03
# 3     31.0  4.461408e-04
# 4    474.0  6.258488e-07
# ..     ...           ...
# 867  556.0  0.000000e+00
# 868  555.0  0.000000e+00
# 869  554.0  2.413988e-06
# 870  551.0  0.000000e+00
# 871  435.0  0.000000e+00
#
# [872 rows x 2 columns]

# %%
len(a.iloc[:,0].unique())
# Out:
# 872

# %%
# a = pd.DataFrame(neumf.rank(2)).T
# a

# %%
len(a.iloc[:,0].unique())
# Out:
# 872

# %%
a.to_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_exxxx2')

# %%
from keras.models import load_model

ncf.save('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_ncf_eat2.h5')
# Out:
# Using TensorFlow backend.
# '/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_ncf_eat2.h5/NeuMF/2022-07-19_16-36-06-301171.pkl'

# %%
a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_exxxx2')

# %%
# neumf = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/data/광진구_restuarant_ncf_eat2.h5/NeuMF/2022-07-19_14-21-04-991292.pkl')
