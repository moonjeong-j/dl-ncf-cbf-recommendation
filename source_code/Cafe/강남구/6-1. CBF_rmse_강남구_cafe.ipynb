# %%
import pandas as pd
import numpy as np
import math
from tqdm import tqdm

# %%
# get size of vector
def mag(x):
    return math.sqrt(sum(i**2 for i in x))

# %%
p_m = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_normalized_item_matrix.csv')
u_m = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_normalized_user_matrix.csv')
group_count = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/강남구_cafe_group_count.csv')

# res_matrix.rename(columns ={'Unnamed: 0':'p_id' }, inplace =True)
p_m.set_index('p_id', inplace =True)
# user_matrix.rename(columns ={'Unnamed: 0':'u_id' }, inplace =True)
u_m.set_index('u_id', inplace =True)
# group_count.rename(columns ={'Unnamed: 0':'group' }, inplace =True)
# group_count.set_index('group', inplace =True)
# res_matrix.set_index('p_id', drop=True, inplace=True)
# user_matrix.set_index('u_id', drop=True, inplace=True)
# group_count.set_index('group', drop=True, inplace=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
group_count
# Out:
#          group  count
# 0     group_21   1110
# 1      group_0     78
# 2      group_1     20
# 3      group_2    158
# 4      group_3    189
# ..         ...    ...
# 115  group_115     53
# 116  group_116     26
# 117  group_117      3
# 118  group_118      4
# 119  group_119      8
#
# [120 rows x 2 columns]

# %%
group_count.set_index('group', inplace =True)

# %%
group_count
# Out:
#            count
# group
# group_21    1110
# group_0       78
# group_1       20
# group_2      158
# group_3      189
# ...          ...
# group_115     53
# group_116     26
# group_117      3
# group_118      4
# group_119      8
#
# [120 rows x 1 columns]

# %%
p_m
# Out:
#              0         1         2         3         4         5         6  \
# p_id
# 0     0.002779  0.005437  0.010603  0.002684  0.001938  0.001205  0.003012
# 1     0.003729  0.005585  0.010891  0.005515  0.001153  0.000000  0.000000
# 2     0.000000  0.022221  0.061902  0.001567  0.000000  0.000000  0.000000
# 3     0.002907  0.008275  0.014343  0.004085  0.003795  0.000000  0.000000
# 4     0.002041  0.002702  0.005269  0.017006  0.001673  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 869   0.003407  0.016163  0.252137  0.007979  0.000000  0.000000  0.000000
# 870   0.001050  0.014939  0.087393  0.007375  0.013872  0.000000  0.000000
# 871   0.004279  0.026792  0.018998  0.004810  0.005026  0.007916  0.000000
# 872   0.001190  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 873   0.002079  0.003998  0.031187  0.003158  0.001980  0.012995  0.000000
#
#              7         8         9  ...       110       111       112  \
# p_id                                ...
# 0     0.003978  0.003969  0.000000  ...  0.019278  0.000000  0.005159
# 1     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.006136
# 2     0.000000  0.014565  0.000000  ...  0.000000  0.000000  0.003487
# 3     0.003415  0.010547  0.000000  ...  0.000000  0.011953  0.001010
# 4     0.000836  0.000000  0.263426  ...  0.000000  0.000000  0.002968
# ...        ...       ...       ...  ...       ...       ...       ...
# 869   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 870   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.008206
# 871   0.006031  0.005588  0.000000  ...  0.000000  0.000000  0.013379
# 872   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 873   0.002970  0.077051  0.000000  ...  0.020792  0.010396  0.008785
#
#            113       114       115       116       117       118       119
# p_id
# 0     0.028457  0.005947  0.002546  0.001483  0.032129  0.009639  0.004819
# 1     0.010373  0.004635  0.016440  0.000000  0.000000  0.000000  0.000000
# 2     0.011791  0.002634  0.004672  0.000000  0.000000  0.000000  0.000000
# 3     0.040981  0.005341  0.004059  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.008407  0.000000  0.004053  0.035123  0.000000  0.006586
# ...        ...       ...       ...       ...       ...       ...       ...
# 869   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 870   0.013872  0.003099  0.005496  0.000000  0.000000  0.000000  0.000000
# 871   0.054280  0.018189  0.017923  0.000000  0.000000  0.000000  0.000000
# 872   0.062914  0.000000  0.000000  0.000000  0.440395  0.000000  0.000000
# 873   0.011881  0.003318  0.010592  0.000000  0.000000  0.000000  0.007797
#
# [874 rows x 120 columns]

# %%
u_m
# Out:
#              0         1         2         3         4         5         6  \
# u_id
# 2182  0.002531  0.013507  0.052677  0.002223  0.001858  0.000000  0.000000
# 1863  0.002523  0.026593  0.041484  0.002626  0.002744  0.021606  0.006482
# 1296  0.000000  0.000000  0.000000  0.019220  0.008034  0.000000  0.000000
# 1185  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1700  0.002504  0.014255  0.000000  0.003519  0.002942  0.005791  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 2011  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2390  0.003134  0.044605  0.000000  0.000000  0.018409  0.000000  0.000000
# 145   0.078073  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 541   0.057132  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 900   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              7         8    9  ...       110       111       112       113  \
# u_id                           ...
# 2182  0.000000  0.020658  0.0  ...  0.117061  0.000000  0.000000  0.000000
# 1863  0.009877  0.003050  0.0  ...  0.034570  0.017285  0.014607  0.004939
# 1296  0.000000  0.000000  0.0  ...  0.000000  0.000000  0.064158  0.000000
# 1185  0.000000  0.000000  0.0  ...  0.000000  0.000000  0.000000  0.102092
# 1700  0.000000  0.024527  0.0  ...  0.000000  0.000000  0.003915  0.079422
# ...        ...       ...  ...  ...       ...       ...       ...       ...
# 2011  0.000000  0.000000  0.0  ...  0.000000  0.000000  0.000000  0.000000
# 2390  0.000000  0.000000  0.0  ...  0.000000  0.000000  0.049003  0.000000
# 145   0.000000  0.000000  0.0  ...  0.000000  0.000000  0.000000  0.000000
# 541   0.000000  0.000000  0.0  ...  0.000000  0.000000  0.000000  0.000000
# 900   0.000000  0.000000  0.0  ...  0.000000  0.000000  0.000000  0.000000
#
#            114       115  116      117  118  119
# u_id
# 2182  0.000000  0.000000  0.0  0.00000  0.0  0.0
# 1863  0.005517  0.005870  0.0  0.03457  0.0  0.0
# 1296  0.016153  0.000000  0.0  0.00000  0.0  0.0
# 1185  0.022808  0.000000  0.0  0.00000  0.0  0.0
# 1700  0.011829  0.015734  0.0  0.00000  0.0  0.0
# ...        ...       ...  ...      ...  ...  ...
# 2011  0.000000  0.000000  0.0  0.00000  0.0  0.0
# 2390  0.000000  0.000000  0.0  0.00000  0.0  0.0
# 145   0.921927  0.000000  0.0  0.00000  0.0  0.0
# 541   0.000000  0.000000  0.0  0.00000  0.0  0.0
# 900   0.000000  0.000000  0.0  0.00000  0.0  0.0
#
# [2588 rows x 120 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

def cos_sim_matrix(a,b):
  cos_sim=cosine_similarity(a,b)
  result_df =pd.DataFrame(data=cos_sim, index=[a.index])

  return result_df

# %%
#similarity df

# %%
cs_u_df = cos_sim_matrix(u_m,u_m)
cs_u_df.head()
# Out:
#           0         1         2         3         4         5     6     \
# u_id
# 2182  1.000000  0.808202  0.222579  0.688226  0.570773  0.523364   0.0
# 1863  0.808202  1.000000  0.262421  0.773165  0.650256  0.729847   0.0
# 1296  0.222579  0.262421  1.000000  0.271322  0.220678  0.186348   0.0
# 1185  0.688226  0.773165  0.271322  1.000000  0.730039  0.607463   0.0
# 1700  0.570773  0.650256  0.220678  0.730039  1.000000  0.608609   0.0
#
#           7         8         9     ...      2578      2579      2580  \
# u_id                                ...
# 2182  0.000465  0.401583  0.655125  ...  0.351394  0.050220  0.010118
# 1863  0.045772  0.444713  0.705447  ...  0.506660  0.024596  0.039376
# 1296  0.000000  0.127703  0.254192  ...  0.209687  0.024776  0.015662
# 1185  0.000000  0.410559  0.749807  ...  0.372541  0.027407  0.023231
# 1700  0.000532  0.403284  0.834284  ...  0.299307  0.038135  0.074028
#
#           2581      2582      2583      2584      2585      2586      2587
# u_id
# 2182  0.492247  0.760738  0.065640  0.300611  0.000692  0.026040  0.008370
# 1863  0.518121  0.794601  0.102643  0.373995  0.026123  0.059172  0.023260
# 1296  0.154612  0.275169  0.000000  0.142549  0.038138  0.096520  0.000000
# 1185  0.574495  0.818512  0.185502  0.330274  0.059043  0.123604  0.013652
# 1700  0.386368  0.665747  0.089956  0.344593  0.044973  0.049677  0.005108
#
# [5 rows x 2588 columns]

# %%
cs_p_df = cos_sim_matrix(p_m,p_m)
cs_p_df.head()
# Out:
#            0         1         2         3         4         5         6    \
# p_id
# 0     1.000000  0.775294  0.754833  0.815228  0.474370  0.863709  0.758359
# 1     0.775294  1.000000  0.749196  0.932573  0.429887  0.897628  0.767250
# 2     0.754833  0.749196  1.000000  0.790202  0.392707  0.794004  0.854527
# 3     0.815228  0.932573  0.790202  1.000000  0.449792  0.945618  0.807280
# 4     0.474370  0.429887  0.392707  0.449792  1.000000  0.462827  0.411020
#
#            7         8         9    ...       864       865       866  \
# p_id                                ...
# 0     0.754135  0.758498  0.835790  ...  0.467567  0.729991  0.580722
# 1     0.776408  0.849683  0.877848  ...  0.528193  0.763016  0.645933
# 2     0.785117  0.777237  0.801547  ...  0.577124  0.718383  0.587454
# 3     0.812313  0.903688  0.932615  ...  0.538784  0.777053  0.645198
# 4     0.412104  0.436688  0.441210  ...  0.262698  0.361291  0.309244
#
#            867       868       869       870       871       872       873
# p_id
# 0     0.614695  0.532533  0.441462  0.254771  0.679264  0.379062  0.468669
# 1     0.665695  0.364268  0.432811  0.092046  0.629412  0.220863  0.427577
# 2     0.663901  0.386833  0.533636  0.529611  0.578142  0.196844  0.493694
# 3     0.711626  0.398963  0.478049  0.079974  0.674291  0.245213  0.367639
# 4     0.359491  0.338351  0.232940  0.146964  0.320281  0.217787  0.223290
#
# [5 rows x 874 columns]

# %%
eat_review =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_restaurant_review.csv')
eat_review
# Out:
#       res_name    user_name  \
# 0         모터시티     Mike Kim
# 1      김북순큰남비집           철준
# 2      김북순큰남비집          돼후니
# 3      김북순큰남비집           호리
# 4      김북순큰남비집          하몽이
# ...        ...          ...
# 17130     깐부치킨       Crisp.
# 17131     깐부치킨  Miriam Park
# 17132     모터시티         호두꽈자
# 17133     모터시티          이영훈
# 17134     모터시티  Tbone213@u!
#
#                                                   review  rating  p_id  u_id
# 0                                  Love motor city pizza       5   243   559
# 1                                                    맛있음       5    88  3735
# 2      #돼훈맛집 #솔직돼훈맛있고, 든든하게 한식을 먹을 수 있는 곳! -맛 : 3.7점 ...       5    88  1961
# 3      [신사/김북순 큰남비집] 5/5오 좋다! 소리가 절로 나온 찌개 맛집이오~개인적으로...       5    88  4100
# 4      누구나 아는 맛 그러나 모두가 즐기는 맛 근처에서 뜨끈한 국물에 흰 쌀밥 생각나면 ...       5    88  3990
# ...                                                  ...     ...   ...   ...
# 17130      깐부 처음가서 그런데 구운마늘치킨 먹음.. 맛은 있대 좀 많이 기름진거 같았어요.       3    95   160
# 17131  We ordered the garlic soy chicken. The chicken...       3    95   570
# 17132  포치즈홀스맨 24900그릴드 치킨 아보카도 샐러드 16900 (발사믹)[공간]생긴 ...       3   243  4095
# 17133  디트로이트 스타일 피자 처음먹어보는데 맛있어요 ㅋㅋ 가격은 좀 나가지만 토마토 소스...       5   243  3341
# 17134  Tasted aaamazing as usual and spot on tangy sa...       3   243   758
#
# [17135 rows x 6 columns]

# %%
eat_review['u_id'].value_counts()
# Out:
# 812     127
# 3066    125
# 2582    123
# 3520    122
# 4        94
#        ...
# 3907      1
# 2674      1
# 1860      1
# 3724      1
# 758       1
# Name: u_id, Length: 4181, dtype: int64

# %%
eat_review['rating'].value_counts()
# Out:
# 5    10576
# 3     4886
# 0     1673
# Name: rating, dtype: int64

# %%
len(eat_review['p_id'].unique())
# Out:
# 771

# %%
eat_review.drop(['review','res_name','user_name'],axis=1, inplace=True)

# %%
eat_review
# Out:
#        rating  p_id  u_id
# 0           5   243   559
# 1           5    88  3735
# 2           5    88  1961
# 3           5    88  4100
# 4           5    88  3990
# ...       ...   ...   ...
# 17130       3    95   160
# 17131       3    95   570
# 17132       3   243  4095
# 17133       5   243  3341
# 17134       3   243   758
#
# [17135 rows x 3 columns]

# %%
eat_review_mean=eat_review.groupby(['u_id','p_id']).mean()
eat_review_mean
# Out:
#            rating
# u_id p_id
# 0    82       3.0
#      114      5.0
#      243      3.0
#      264      5.0
#      306      3.0
# ...           ...
# 4180 264      5.0
#      382      5.0
#      491      3.0
#      619      5.0
#      659      3.0
#
# [16002 rows x 1 columns]

# %%
eat_review_mean.reset_index(level=0, inplace=True)
eat_review_mean.reset_index(level=0, inplace=True)
eat_review_mean
# Out:
#        p_id  u_id  rating
# 0        82     0     3.0
# 1       114     0     5.0
# 2       243     0     3.0
# 3       264     0     5.0
# 4       306     0     3.0
# ...     ...   ...     ...
# 15997   264  4180     5.0
# 15998   382  4180     5.0
# 15999   491  4180     3.0
# 16000   619  4180     5.0
# 16001   659  4180     3.0
#
# [16002 rows x 3 columns]

# %%
eat_review_mean.shape
# Out:
# (16002, 3)

# %%
# eat_review_mean_dropDU=eat_review_mean.drop_duplicates(subset=['u_id','p_id'], keep='first', ignore_index=False)

# %%
# eat_review_mean_dropDU.shape

# %%
import tensorflow as tf

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

train_df, test_df = train_test_split(eat_review_mean, test_size=0.2, random_state=123)

# %%
train_df.shape
# Out:
# (12801, 3)

# %%
test_userids =list(set(test_df['u_id'].values))
len(test_userids)
# Out:
# 1654

# %%
all_userids =list(set(eat_review_mean['u_id'].values))
len(all_userids)
# Out:
# 4181

# %%
user_record_df=eat_review[eat_review['u_id']==1567]

# %%
user_record_df
# Out:
#       rating  p_id  u_id
# 725        3   213  1567
# 4008       0   309  1567
# 4755       5   659  1567

# %%
user_record_df['p_id']
# Out:
# 725     213
# 4008    309
# 4755    659
# Name: p_id, dtype: int64

# %%
cs_u_df.loc[user_record_df['p_id']]
# Out:
#           0         1         2         3         4         5     6     \
# u_id
# 213   0.007721  0.027193  0.006162  0.010565  0.011769  0.006181   0.0
# 309   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.0
# 659   0.439303  0.487073  0.174339  0.480100  0.463465  0.312584   0.0
#
#           7         8         9     ...      2578      2579      2580  \
# u_id                                ...
# 213   0.000000  0.001841  0.000000  ...  0.006365  0.151813  0.000000
# 309   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 659   0.058233  0.299222  0.442437  ...  0.307382  0.018833  0.017278
#
#           2581      2582      2583      2584      2585      2586      2587
# u_id
# 213   0.000000  0.000000  0.007312  0.007727  0.000000  0.020782  0.000000
# 309   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 659   0.389665  0.507419  0.003935  0.205204  0.039257  0.047845  0.013423
#
# [3 rows x 2588 columns]

# %%
#user record df

# %%
user_sim_df= cs_p_df.loc[user_record_df['p_id']]
user_sim_df
# Out:
#            0         1         2         3         4         5         6    \
# p_id
# 213   0.662964  0.652621  0.642635  0.639088  0.346884  0.619820  0.716067
# 309   0.758861  0.624743  0.529779  0.671312  0.381562  0.621647  0.663043
# 659   0.821729  0.898634  0.779876  0.945535  0.457805  0.896711  0.847421
#
#            7         8         9    ...       864       865       866  \
# p_id                                ...
# 213   0.742278  0.618540  0.639018  ...  0.561013  0.703804  0.604392
# 309   0.702437  0.691013  0.645347  ...  0.350232  0.707645  0.535173
# 659   0.864230  0.892732  0.890243  ...  0.559956  0.789254  0.677153
#
#            867       868       869       870       871       872       873
# p_id
# 213   0.569637  0.689714  0.547085  0.291587  0.587966  0.606884  0.544669
# 309   0.510722  0.647181  0.358961  0.162139  0.745924  0.460409  0.445040
# 659   0.734480  0.419331  0.550120  0.195701  0.656250  0.239782  0.421545
#
# [3 rows x 874 columns]

# %%
 user_record_df=train_df.loc[train_df['u_id']==int(1567),:]
 user_record_df
# Out:
#       p_id  u_id  rating
# 6037   213  1567     3.0
# 6039   659  1567     5.0
# 6038   309  1567     0.0

# %%
user_sim_df= cs_u_df.loc[user_record_df['p_id']]
user_sim_df
# Out:
#           0         1         2         3         4         5     6     \
# u_id
# 213   0.007721  0.027193  0.006162  0.010565  0.011769  0.006181   0.0
# 659   0.439303  0.487073  0.174339  0.480100  0.463465  0.312584   0.0
# 309   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.0
#
#           7         8         9     ...      2578      2579      2580  \
# u_id                                ...
# 213   0.000000  0.001841  0.000000  ...  0.006365  0.151813  0.000000
# 659   0.058233  0.299222  0.442437  ...  0.307382  0.018833  0.017278
# 309   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
#           2581      2582      2583      2584      2585      2586      2587
# u_id
# 213   0.000000  0.000000  0.007312  0.007727  0.000000  0.020782  0.000000
# 659   0.389665  0.507419  0.003935  0.205204  0.039257  0.047845  0.013423
# 309   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [3 rows x 2588 columns]

# %%
user_rating_df = user_record_df[['rating']] 
user_rating_df
# Out:
#       rating
# 6037     3.0
# 6039     5.0
# 6038     0.0

# %%
#prediction

# %%
 prediction =np.matmul(user_sim_df.T.to_numpy() , user_rating_df.to_numpy()).flatten()
 prediction
# Out:
# array([2.21967987, 2.5169415 , 0.89018451, ..., 0.1962872 , 0.30156926,
#        0.06711473])

# %%
result_df =pd.DataFrame()

for user_id in tqdm(all_userids):
  user_record_df = eat_review_mean.loc[eat_review_mean['u_id']==int(user_id),:] # (n,3) 

  user_sim_df= cs_p_df.loc[user_record_df['p_id']] #(n,1730). #1730개......##A
  user_rating_df = user_record_df[['rating']] #(n,1)##B
  sim_sum = np.sum(user_sim_df.T.to_numpy(),-1)


  prediction =np.matmul(user_sim_df.T.to_numpy() , user_rating_df.to_numpy()).flatten() /(sim_sum+1)##AB
  
  prediction_df = pd.DataFrame(prediction , index = cs_p_df.index).reset_index()
  prediction_df.columns=['p_id', 'pred_rating']
  prediction_df = prediction_df[['p_id', 'pred_rating']][prediction_df['p_id'].isin(test_df[test_df['u_id'] == user_id]['p_id'].values)]

  temp_df = prediction_df.merge(test_df[test_df['u_id'] == user_id], on='p_id')
  result_df = pd.concat([result_df, temp_df], axis=0)
# Out:
# 100%|██████████| 4181/4181 [01:01<00:00, 68.19it/s]

# %%
len(userids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-738a47737e6c> in <module>()
# ----> 1 len(userids)
#
# NameError: name 'userids' is not defined

# %%
result_df.head(10)
# Out:
#    p_id  pred_rating  u_id  rating
# 0   435     2.758613     0     3.5
# 1   472     2.602275     0     3.0
# 2   551     2.499001     0     3.0
# 3   633     1.392259     0     0.0
# 4   713     2.745552     0     3.0
# 0   315     1.821941     1     3.0
# 1   598     1.821941     1     3.0
# 0    95     3.779017     4     3.0
# 1    98     3.787123     4     5.0
# 2   238     3.592384     4     5.0

# %%
result_df.shape
# Out:
# (3201, 4)

# %%
result_df['pred_rating'].mean()
# Out:
# 2.979559894013296

# %%
result_df['rating'].mean()
# Out:
# 3.878142247214412

# %%
mse = mean_squared_error(y_true=result_df['rating'].values, y_pred=result_df['pred_rating'].values)
rmse = np.sqrt(mse)

print(mse, rmse)
# Out:
# 2.6033264590130893 1.6134827110982903
