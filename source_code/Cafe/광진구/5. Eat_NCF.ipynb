# %%
pip uninstall scikit-learn -y
# Out:
# Found existing installation: scikit-learn 1.0.2
# Uninstalling scikit-learn-1.0.2:
#   Successfully uninstalled scikit-learn-1.0.2

# %%
pip uninstall cornac -y
# Out:
# Found existing installation: cornac 1.14.2
# Uninstalling cornac-1.14.2:
#   Successfully uninstalled cornac-1.14.2

# %%
pip uninstall tensorflow==2.9.1 -y
# Out:
# Found existing installation: tensorflow 1.15.2
# Uninstalling tensorflow-1.15.2:
#   Successfully uninstalled tensorflow-1.15.2

# %%
pip install scikit-learn==0.22.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 9.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.1.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.1) (1.4.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.22.1 which is incompatible.
# Successfully installed scikit-learn-0.22.1

# %%
pip install cornac==1.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cornac==1.6.1
#   Downloading cornac-1.6.1-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 4.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.21.6)
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (4.64.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from cornac==1.6.1) (1.7.3)
# Installing collected packages: cornac
# Successfully installed cornac-1.6.1

# %%
pip install tensorflow==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.15.2
#   Downloading tensorflow-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (110.5 MB)
#      |████████████████████████████████| 110.5 MB 40 kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.47.0)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 62.2 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.8.1)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.4 MB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 25.2 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.14.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (0.37.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.1.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.2) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=ee121355b55a0a8cc32a1cf4cf948a907153cb13cd157d9bfd1a87d27db4b1ef
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
#     Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.2 tensorflow-estimator-1.15.1

# %%
# pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 33 kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.46.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.15.2

# %%
pip install --upgrade tensorflow-gpu==1.15.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.15.2
#   Downloading tensorflow_gpu-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (410.9 MB)
#      |████████████████████████████████| 410.9 MB 33 kB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 62.0 MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.3.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (3.17.3)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 56.9 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.46.3)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.4 MB/s
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (0.37.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.14.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (3.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=1ce8869b9cc690c867f6e20ccd5ab10a1ceeb6491a80235962d0e4428048990a
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorboard<2.9,>=2.8, but you have tensorboard 1.15.0 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220527125636 requires tensorflow-estimator<2.9,>=2.8, but you have tensorflow-estimator 1.15.1 which is incompatible.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.2

# %%
# %tensorflow_version 1.15
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# WARNING: Tensorflow 1 is deprecated, and support will be removed on August 1, 2022.
# After that, `%tensorflow_version 1.x` will throw an error.
#
# Your notebook should be updated to use Tensorflow 2.
# See the guide at https://www.tensorflow.org/guide/migrate#migrate-from-tensorflow-1x-to-tensorflow-2.
#
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cornac
import cornac.eval_methods
from cornac.eval_methods import RatioSplit, base_method
from cornac.hyperopt import Continuous, Discrete, RandomSearch
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# 추천할 top k개의 장소
TOP_K = 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_cafe_score_board.csv', index_col =0)

# %%
data_df['rating'] =data_df['rating'].astype('float')
data_df = data_df.rename({'u_id':'userID','p_id':'itemID'},axis=1)
#data_df = data_df.groupby('userID').filter(lambda x : len(x)>= 10).copy()
data_df = data_df.fillna(5)

# %%
data_df
# Out:
#       itemID  rating
# u_id
# 0         15     3.0
# 1         63     3.0
# 1         63     3.0
# 1         57     5.0
# 1         63     3.0
# ...      ...     ...
# 598        7     5.0
# 598       99     5.0
# 598      120     3.0
# 599      106     5.0
# 599       66     5.0
#
# [1199 rows x 2 columns]

# %%
data_df.reset_index(inplace=True)
data_df
# Out:
#       u_id  itemID  rating
# 0        0      15     3.0
# 1        1      63     3.0
# 2        1      63     3.0
# 3        1      57     5.0
# 4        1      63     3.0
# ...    ...     ...     ...
# 1194   598       7     5.0
# 1195   598      99     5.0
# 1196   598     120     3.0
# 1197   599     106     5.0
# 1198   599      66     5.0
#
# [1199 rows x 3 columns]

# %%
data = [tuple(x) for x in data_df.values]
data
# Out:
# [(0.0, 15.0, 3.0),
#  (1.0, 63.0, 3.0),
#  (1.0, 63.0, 3.0),
#  (1.0, 57.0, 5.0),
#  (1.0, 63.0, 3.0),
#  (1.0, 57.0, 0.0),
#  (1.0, 57.0, 3.0),
#  (1.0, 57.0, 3.0),
#  (2.0, 119.0, 3.0),
#  (3.0, 149.0, 5.0),
#  (4.0, 7.0, 0.0),
#  (5.0, 41.0, 5.0),
#  (6.0, 2.0, 5.0),
#  (7.0, 63.0, 5.0),
#  (7.0, 57.0, 3.0),
#  (7.0, 63.0, 3.0),
#  (8.0, 54.0, 5.0),
#  (9.0, 96.0, 5.0),
#  (9.0, 146.0, 5.0),
#  (10.0, 63.0, 5.0),
#  (11.0, 56.0, 5.0),
#  (12.0, 145.0, 3.0),
#  (13.0, 36.0, 5.0),
#  (14.0, 57.0, 3.0),
#  (15.0, 63.0, 3.0),
#  (15.0, 46.0, 3.0),
#  (15.0, 37.0, 5.0),
#  (15.0, 37.0, 5.0),
#  (15.0, 66.0, 5.0),
#  (15.0, 61.0, 5.0),
#  (16.0, 126.0, 5.0),
#  (17.0, 111.0, 5.0),
#  (18.0, 119.0, 5.0),
#  (19.0, 27.0, 5.0),
#  (20.0, 144.0, 3.0),
#  (20.0, 15.0, 5.0),
#  (20.0, 115.0, 3.0),
#  (21.0, 20.0, 5.0),
#  (21.0, 21.0, 5.0),
#  (22.0, 19.0, 5.0),
#  (22.0, 79.0, 5.0),
#  (23.0, 57.0, 5.0),
#  (24.0, 21.0, 3.0),
#  (24.0, 29.0, 5.0),
#  (24.0, 143.0, 5.0),
#  (24.0, 22.0, 0.0),
#  (24.0, 22.0, 3.0),
#  (24.0, 146.0, 5.0),
#  (25.0, 57.0, 5.0),
#  (25.0, 57.0, 5.0),
#  (26.0, 63.0, 3.0),
#  (27.0, 63.0, 5.0),
#  (27.0, 122.0, 5.0),
#  (28.0, 3.0, 5.0),
#  (29.0, 63.0, 5.0),
#  (30.0, 27.0, 0.0),
#  (31.0, 20.0, 5.0),
#  (32.0, 2.0, 3.0),
#  (33.0, 5.0, 5.0),
#  (34.0, 19.0, 0.0),
#  (34.0, 21.0, 3.0),
#  (35.0, 66.0, 5.0),
#  (36.0, 36.0, 5.0),
#  (37.0, 96.0, 5.0),
#  (38.0, 19.0, 0.0),
#  (39.0, 19.0, 5.0),
#  (40.0, 74.0, 5.0),
#  (40.0, 66.0, 5.0),
#  (41.0, 27.0, 0.0),
#  (41.0, 19.0, 5.0),
#  (41.0, 15.0, 5.0),
#  (41.0, 21.0, 5.0),
#  (41.0, 22.0, 5.0),
#  (41.0, 133.0, 3.0),
#  (42.0, 7.0, 5.0),
#  (43.0, 71.0, 0.0),
#  (44.0, 19.0, 5.0),
#  (44.0, 63.0, 5.0),
#  (44.0, 19.0, 5.0),
#  (45.0, 19.0, 5.0),
#  (46.0, 19.0, 5.0),
#  (46.0, 96.0, 5.0),
#  (47.0, 48.0, 5.0),
#  (48.0, 80.0, 5.0),
#  (48.0, 101.0, 3.0),
#  (48.0, 12.0, 5.0),
#  (48.0, 15.0, 5.0),
#  (49.0, 2.0, 5.0),
#  (50.0, 63.0, 0.0),
#  (51.0, 71.0, 5.0),
#  (52.0, 63.0, 3.0),
#  (52.0, 15.0, 5.0),
#  (53.0, 132.0, 5.0),
#  (53.0, 114.0, 5.0),
#  (54.0, 91.0, 5.0),
#  (55.0, 27.0, 5.0),
#  (56.0, 18.0, 5.0),
#  (56.0, 39.0, 5.0),
#  (56.0, 120.0, 5.0),
#  (57.0, 18.0, 5.0),
#  (58.0, 48.0, 5.0),
#  (59.0, 19.0, 5.0),
#  (59.0, 57.0, 5.0),
#  (60.0, 19.0, 3.0),
#  (60.0, 15.0, 5.0),
#  (60.0, 39.0, 5.0),
#  (60.0, 2.0, 3.0),
#  (60.0, 44.0, 3.0),
#  (61.0, 106.0, 3.0),
#  (62.0, 57.0, 0.0),
#  (63.0, 7.0, 5.0),
#  (64.0, 97.0, 3.0),
#  (65.0, 2.0, 3.0),
#  (66.0, 120.0, 5.0),
#  (67.0, 45.0, 5.0),
#  (67.0, 15.0, 5.0),
#  (68.0, 19.0, 5.0),
#  (69.0, 99.0, 5.0),
#  (69.0, 69.0, 5.0),
#  (70.0, 63.0, 3.0),
#  (71.0, 7.0, 5.0),
#  (71.0, 19.0, 5.0),
#  (72.0, 28.0, 5.0),
#  (73.0, 11.0, 0.0),
#  (74.0, 132.0, 3.0),
#  (75.0, 120.0, 5.0),
#  (76.0, 11.0, 5.0),
#  (77.0, 14.0, 5.0),
#  (78.0, 63.0, 3.0),
#  (78.0, 48.0, 3.0),
#  (78.0, 54.0, 3.0),
#  (78.0, 63.0, 3.0),
#  (78.0, 63.0, 3.0),
#  (78.0, 63.0, 0.0),
#  (78.0, 132.0, 5.0),
#  (78.0, 63.0, 5.0),
#  (78.0, 114.0, 3.0),
#  (78.0, 63.0, 5.0),
#  (78.0, 63.0, 3.0),
#  (78.0, 7.0, 3.0),
#  (78.0, 15.0, 3.0),
#  (78.0, 63.0, 5.0),
#  (78.0, 18.0, 3.0),
#  (78.0, 20.0, 5.0),
#  (78.0, 63.0, 3.0),
#  (78.0, 63.0, 3.0),
#  (78.0, 97.0, 0.0),
#  (79.0, 63.0, 3.0),
#  (80.0, 21.0, 5.0),
#  (81.0, 19.0, 5.0),
#  (82.0, 51.0, 5.0),
#  (83.0, 63.0, 5.0),
#  (83.0, 63.0, 5.0),
#  (84.0, 149.0, 3.0),
#  (85.0, 19.0, 5.0),
#  (86.0, 42.0, 5.0),
#  (87.0, 63.0, 3.0),
#  (88.0, 36.0, 3.0),
#  (89.0, 145.0, 5.0),
#  (90.0, 97.0, 3.0),
#  (91.0, 63.0, 3.0),
#  (92.0, 63.0, 0.0),
#  (93.0, 101.0, 3.0),
#  (93.0, 97.0, 3.0),
#  (94.0, 57.0, 3.0),
#  (94.0, 57.0, 3.0),
#  (94.0, 63.0, 3.0),
#  (95.0, 149.0, 5.0),
#  (96.0, 120.0, 5.0),
#  (97.0, 57.0, 3.0),
#  (98.0, 39.0, 5.0),
#  (99.0, 19.0, 5.0),
#  (100.0, 21.0, 5.0),
#  (100.0, 25.0, 3.0),
#  (100.0, 120.0, 3.0),
#  (100.0, 20.0, 5.0),
#  (100.0, 145.0, 0.0),
#  (101.0, 27.0, 3.0),
#  (101.0, 27.0, 3.0),
#  (102.0, 44.0, 0.0),
#  (102.0, 14.0, 0.0),
#  (103.0, 10.0, 0.0),
#  (103.0, 48.0, 5.0),
#  (103.0, 95.0, 3.0),
#  (104.0, 7.0, 5.0),
#  (104.0, 95.0, 5.0),
#  (104.0, 15.0, 5.0),
#  (104.0, 50.0, 5.0),
#  (104.0, 71.0, 5.0),
#  (105.0, 19.0, 0.0),
#  (106.0, 19.0, 0.0),
#  (106.0, 7.0, 5.0),
#  (106.0, 120.0, 3.0),
#  (106.0, 106.0, 3.0),
#  (106.0, 16.0, 0.0),
#  (106.0, 35.0, 0.0),
#  (107.0, 114.0, 5.0),
#  (108.0, 1.0, 3.0),
#  (109.0, 19.0, 5.0),
#  (109.0, 19.0, 0.0),
#  (110.0, 19.0, 5.0),
#  (111.0, 63.0, 5.0),
#  (111.0, 63.0, 5.0),
#  (112.0, 27.0, 3.0),
#  (113.0, 15.0, 5.0),
#  (114.0, 125.0, 3.0),
#  (115.0, 40.0, 5.0),
#  (116.0, 97.0, 3.0),
#  (117.0, 78.0, 3.0),
#  (117.0, 15.0, 3.0),
#  (118.0, 44.0, 0.0),
#  (119.0, 120.0, 5.0),
#  (120.0, 44.0, 5.0),
#  (121.0, 19.0, 5.0),
#  (122.0, 63.0, 0.0),
#  (122.0, 31.0, 5.0),
#  (122.0, 63.0, 0.0),
#  (122.0, 96.0, 0.0),
#  (122.0, 11.0, 5.0),
#  (122.0, 63.0, 3.0),
#  (122.0, 53.0, 5.0),
#  (122.0, 120.0, 5.0),
#  (122.0, 63.0, 3.0),
#  (122.0, 39.0, 3.0),
#  (122.0, 63.0, 3.0),
#  (122.0, 63.0, 0.0),
#  (122.0, 11.0, 5.0),
#  (122.0, 62.0, 5.0),
#  (123.0, 15.0, 5.0),
#  (123.0, 97.0, 3.0),
#  (124.0, 18.0, 5.0),
#  (125.0, 21.0, 5.0),
#  (126.0, 7.0, 5.0),
#  (127.0, 121.0, 3.0),
#  (128.0, 19.0, 5.0),
#  (129.0, 19.0, 5.0),
#  (130.0, 57.0, 3.0),
#  (131.0, 117.0, 5.0),
#  (132.0, 19.0, 5.0),
#  (133.0, 19.0, 5.0),
#  (134.0, 149.0, 5.0),
#  (135.0, 83.0, 5.0),
#  (136.0, 20.0, 5.0),
#  (137.0, 101.0, 5.0),
#  (138.0, 3.0, 5.0),
#  (138.0, 2.0, 5.0),
#  (138.0, 62.0, 3.0),
#  (138.0, 76.0, 3.0),
#  (139.0, 114.0, 5.0),
#  (140.0, 19.0, 3.0),
#  (141.0, 19.0, 5.0),
#  (142.0, 42.0, 5.0),
#  (142.0, 46.0, 0.0),
#  (143.0, 136.0, 5.0),
#  (144.0, 120.0, 5.0),
#  (145.0, 79.0, 5.0),
#  (146.0, 122.0, 3.0),
#  (147.0, 122.0, 0.0),
#  (148.0, 132.0, 3.0),
#  (148.0, 63.0, 3.0),
#  (148.0, 132.0, 3.0),
#  (148.0, 57.0, 5.0),
#  (148.0, 63.0, 3.0),
#  (148.0, 63.0, 3.0),
#  (148.0, 63.0, 5.0),
#  (148.0, 63.0, 5.0),
#  (148.0, 132.0, 3.0),
#  (148.0, 132.0, 5.0),
#  (148.0, 63.0, 3.0),
#  (148.0, 63.0, 3.0),
#  (148.0, 132.0, 3.0),
#  (148.0, 19.0, 3.0),
#  (148.0, 57.0, 3.0),
#  (148.0, 63.0, 3.0),
#  (148.0, 63.0, 3.0),
#  (149.0, 41.0, 5.0),
#  (150.0, 67.0, 5.0),
#  (151.0, 106.0, 0.0),
#  (152.0, 86.0, 5.0),
#  (152.0, 52.0, 5.0),
#  (152.0, 147.0, 5.0),
#  (153.0, 38.0, 3.0),
#  (154.0, 95.0, 5.0),
#  (155.0, 7.0, 5.0),
#  (156.0, 107.0, 5.0),
#  (157.0, 27.0, 3.0),
#  (158.0, 15.0, 5.0),
#  (158.0, 45.0, 5.0),
#  (159.0, 15.0, 5.0),
#  (160.0, 94.0, 5.0),
#  (160.0, 33.0, 5.0),
#  (161.0, 27.0, 0.0),
#  (162.0, 114.0, 3.0),
#  (163.0, 91.0, 5.0),
#  (164.0, 19.0, 5.0),
#  (165.0, 45.0, 3.0),
#  (165.0, 19.0, 3.0),
#  (165.0, 32.0, 3.0),
#  (165.0, 56.0, 5.0),
#  (165.0, 131.0, 5.0),
#  (166.0, 39.0, 5.0),
#  (167.0, 15.0, 5.0),
#  (167.0, 120.0, 5.0),
#  (167.0, 36.0, 3.0),
#  (167.0, 90.0, 5.0),
#  (167.0, 144.0, 5.0),
#  (167.0, 36.0, 5.0),
#  (168.0, 139.0, 3.0),
#  (169.0, 120.0, 5.0),
#  (169.0, 17.0, 5.0),
#  (170.0, 21.0, 3.0),
#  (170.0, 115.0, 3.0),
#  (170.0, 96.0, 5.0),
#  (170.0, 64.0, 5.0),
#  (170.0, 141.0, 5.0),
#  (171.0, 66.0, 5.0),
#  (171.0, 42.0, 5.0),
#  (172.0, 15.0, 5.0),
#  (173.0, 19.0, 5.0),
#  (174.0, 43.0, 5.0),
#  (175.0, 106.0, 0.0),
#  (176.0, 1.0, 3.0),
#  (177.0, 74.0, 5.0),
#  (177.0, 49.0, 5.0),
#  (178.0, 61.0, 5.0),
#  (178.0, 19.0, 3.0),
#  (179.0, 15.0, 3.0),
#  (180.0, 19.0, 5.0),
#  (181.0, 27.0, 3.0),
#  (182.0, 114.0, 3.0),
#  (183.0, 39.0, 5.0),
#  (183.0, 45.0, 3.0),
#  (183.0, 35.0, 3.0),
#  (183.0, 39.0, 5.0),
#  (183.0, 63.0, 3.0),
#  (184.0, 81.0, 5.0),
#  (185.0, 44.0, 0.0),
#  (186.0, 114.0, 0.0),
#  (187.0, 120.0, 5.0),
#  (188.0, 63.0, 5.0),
#  (189.0, 97.0, 3.0),
#  (190.0, 150.0, 5.0),
#  (191.0, 27.0, 5.0),
#  (192.0, 63.0, 3.0),
#  (192.0, 63.0, 3.0),
#  (193.0, 120.0, 3.0),
#  (194.0, 27.0, 3.0),
#  (194.0, 97.0, 5.0),
#  (195.0, 63.0, 5.0),
#  (196.0, 27.0, 5.0),
#  (197.0, 19.0, 5.0),
#  (198.0, 7.0, 5.0),
#  (199.0, 27.0, 5.0),
#  (200.0, 145.0, 5.0),
#  (200.0, 63.0, 5.0),
#  (201.0, 32.0, 3.0),
#  (201.0, 45.0, 5.0),
#  (201.0, 68.0, 3.0),
#  (201.0, 148.0, 5.0),
#  (202.0, 57.0, 5.0),
#  (203.0, 1.0, 5.0),
#  (204.0, 19.0, 5.0),
#  (205.0, 63.0, 5.0),
#  (205.0, 114.0, 3.0),
#  (205.0, 21.0, 5.0),
#  (206.0, 21.0, 5.0),
#  (207.0, 28.0, 5.0),
#  (208.0, 121.0, 5.0),
#  (209.0, 112.0, 5.0),
#  (210.0, 55.0, 5.0),
#  (211.0, 15.0, 5.0),
#  (212.0, 143.0, 0.0),
#  (213.0, 101.0, 5.0),
#  (214.0, 63.0, 3.0),
#  (214.0, 63.0, 3.0),
#  (214.0, 63.0, 3.0),
#  (215.0, 7.0, 3.0),
#  (216.0, 7.0, 5.0),
#  (217.0, 66.0, 5.0),
#  (218.0, 140.0, 3.0),
#  (219.0, 19.0, 0.0),
#  (219.0, 63.0, 5.0),
#  (220.0, 57.0, 5.0),
#  (221.0, 2.0, 3.0),
#  (222.0, 68.0, 5.0),
#  (223.0, 56.0, 5.0),
#  (223.0, 56.0, 5.0),
#  (223.0, 39.0, 5.0),
#  (224.0, 114.0, 5.0),
#  (225.0, 39.0, 5.0),
#  (225.0, 19.0, 5.0),
#  (226.0, 20.0, 5.0),
#  (227.0, 15.0, 5.0),
#  (228.0, 77.0, 5.0),
#  (229.0, 10.0, 5.0),
#  (230.0, 20.0, 3.0),
#  (231.0, 74.0, 0.0),
#  (231.0, 139.0, 5.0),
#  (232.0, 39.0, 5.0),
#  (233.0, 21.0, 5.0),
#  (234.0, 63.0, 3.0),
#  (235.0, 142.0, 5.0),
#  (236.0, 114.0, 3.0),
#  (237.0, 70.0, 5.0),
#  (238.0, 27.0, 5.0),
#  (239.0, 124.0, 3.0),
#  (240.0, 57.0, 5.0),
#  (241.0, 19.0, 5.0),
#  (242.0, 139.0, 5.0),
#  (242.0, 46.0, 3.0),
#  (242.0, 146.0, 3.0),
#  (242.0, 146.0, 5.0),
#  (242.0, 21.0, 5.0),
#  (242.0, 98.0, 3.0),
#  (242.0, 19.0, 5.0),
#  (242.0, 71.0, 3.0),
#  (242.0, 109.0, 3.0),
#  (242.0, 5.0, 5.0),
#  (242.0, 91.0, 3.0),
#  (242.0, 39.0, 3.0),
#  (243.0, 63.0, 5.0),
#  (244.0, 39.0, 5.0),
#  (245.0, 2.0, 0.0),
#  (246.0, 21.0, 5.0),
#  (247.0, 18.0, 3.0),
#  (247.0, 114.0, 5.0),
#  (248.0, 48.0, 5.0),
#  (249.0, 38.0, 0.0),
#  (250.0, 20.0, 5.0),
#  (250.0, 46.0, 5.0),
#  (250.0, 63.0, 3.0),
#  (250.0, 66.0, 5.0),
#  (251.0, 19.0, 5.0),
#  (252.0, 68.0, 5.0),
#  (252.0, 130.0, 5.0),
#  (252.0, 110.0, 5.0),
#  (252.0, 110.0, 5.0),
#  (252.0, 55.0, 5.0),
#  (252.0, 15.0, 3.0),
#  (252.0, 11.0, 5.0),
#  (252.0, 19.0, 3.0),
#  (252.0, 91.0, 5.0),
#  (252.0, 133.0, 3.0),
#  (252.0, 14.0, 3.0),
#  (252.0, 12.0, 3.0),
#  (252.0, 32.0, 5.0),
#  (252.0, 104.0, 5.0),
#  (252.0, 2.0, 3.0),
#  (252.0, 80.0, 3.0),
#  (252.0, 130.0, 5.0),
#  (252.0, 58.0, 5.0),
#  (252.0, 81.0, 3.0),
#  (252.0, 105.0, 3.0),
#  (252.0, 27.0, 3.0),
#  (252.0, 28.0, 3.0),
#  (253.0, 57.0, 0.0),
#  (253.0, 57.0, 3.0),
#  (254.0, 20.0, 5.0),
#  (255.0, 119.0, 5.0),
#  (256.0, 20.0, 5.0),
#  (257.0, 68.0, 5.0),
#  (258.0, 105.0, 5.0),
#  (259.0, 129.0, 5.0),
#  (259.0, 114.0, 3.0),
#  (259.0, 56.0, 3.0),
#  (259.0, 57.0, 3.0),
#  (260.0, 132.0, 5.0),
#  (261.0, 107.0, 5.0),
#  (262.0, 132.0, 3.0),
#  (262.0, 35.0, 5.0),
#  (262.0, 80.0, 3.0),
#  (263.0, 7.0, 5.0),
#  (264.0, 20.0, 5.0),
#  (265.0, 131.0, 5.0),
#  (266.0, 63.0, 5.0),
#  (266.0, 132.0, 3.0),
#  (266.0, 63.0, 5.0),
#  (267.0, 107.0, 5.0),
#  (267.0, 34.0, 5.0),
#  (268.0, 51.0, 5.0),
#  (268.0, 5.0, 5.0),
#  (269.0, 45.0, 5.0),
#  (270.0, 7.0, 5.0),
#  (270.0, 69.0, 5.0),
#  (271.0, 19.0, 5.0),
#  (272.0, 58.0, 5.0),
#  (273.0, 20.0, 5.0),
#  (273.0, 121.0, 3.0),
#  (273.0, 72.0, 3.0),
#  (274.0, 37.0, 5.0),
#  (275.0, 27.0, 3.0),
#  (276.0, 63.0, 0.0),
#  (277.0, 95.0, 5.0),
#  (278.0, 119.0, 5.0),
#  (279.0, 137.0, 5.0),
#  (280.0, 43.0, 5.0),
#  (281.0, 36.0, 5.0),
#  (282.0, 94.0, 5.0),
#  (282.0, 120.0, 5.0),
#  (283.0, 6.0, 3.0),
#  (284.0, 56.0, 3.0),
#  (285.0, 149.0, 5.0),
#  (286.0, 19.0, 5.0),
#  (287.0, 4.0, 5.0),
#  (288.0, 132.0, 5.0),
#  (288.0, 84.0, 5.0),
#  (288.0, 63.0, 5.0),
#  (288.0, 132.0, 0.0),
#  (288.0, 63.0, 5.0),
#  (288.0, 132.0, 5.0),
#  (288.0, 63.0, 5.0),
#  (288.0, 63.0, 5.0),
#  (288.0, 20.0, 5.0),
#  (288.0, 63.0, 5.0),
#  (288.0, 44.0, 3.0),
#  (288.0, 63.0, 5.0),
#  (288.0, 132.0, 3.0),
#  (288.0, 61.0, 5.0),
#  (289.0, 96.0, 5.0),
#  (290.0, 63.0, 5.0),
#  (291.0, 27.0, 3.0),
#  (292.0, 11.0, 5.0),
#  (293.0, 42.0, 3.0),
#  (293.0, 16.0, 0.0),
#  (293.0, 24.0, 3.0),
#  (293.0, 106.0, 5.0),
#  (293.0, 20.0, 5.0),
#  (293.0, 7.0, 5.0),
#  (293.0, 114.0, 5.0),
#  (293.0, 2.0, 5.0),
#  (293.0, 97.0, 5.0),
#  (293.0, 75.0, 3.0),
#  (293.0, 49.0, 3.0),
#  (293.0, 145.0, 3.0),
#  (294.0, 101.0, 5.0),
#  (295.0, 3.0, 5.0),
#  (296.0, 96.0, 3.0),
#  (297.0, 42.0, 5.0),
#  (298.0, 101.0, 5.0),
#  (298.0, 120.0, 5.0),
#  (299.0, 113.0, 5.0),
#  (299.0, 120.0, 5.0),
#  (300.0, 63.0, 5.0),
#  (301.0, 15.0, 3.0),
#  (302.0, 72.0, 5.0),
#  (303.0, 57.0, 3.0),
#  (304.0, 7.0, 5.0),
#  (305.0, 27.0, 3.0),
#  (306.0, 93.0, 5.0),
#  (307.0, 19.0, 5.0),
#  (308.0, 61.0, 5.0),
#  (308.0, 9.0, 5.0),
#  (308.0, 30.0, 5.0),
#  (309.0, 77.0, 5.0),
#  (310.0, 101.0, 5.0),
#  (311.0, 36.0, 3.0),
#  (312.0, 63.0, 0.0),
#  (313.0, 5.0, 5.0),
#  (313.0, 66.0, 3.0),
#  (314.0, 35.0, 5.0),
#  (315.0, 68.0, 0.0),
#  (316.0, 2.0, 3.0),
#  (317.0, 132.0, 3.0),
#  (317.0, 1.0, 3.0),
#  (317.0, 148.0, 3.0),
#  (317.0, 15.0, 5.0),
#  (317.0, 40.0, 5.0),
#  (317.0, 145.0, 5.0),
#  (317.0, 7.0, 5.0),
#  (317.0, 101.0, 3.0),
#  (317.0, 57.0, 5.0),
#  (317.0, 15.0, 5.0),
#  (317.0, 77.0, 5.0),
#  (317.0, 7.0, 5.0),
#  (317.0, 148.0, 5.0),
#  (317.0, 15.0, 5.0),
#  (318.0, 97.0, 5.0),
#  (319.0, 128.0, 3.0),
#  (319.0, 45.0, 3.0),
#  (319.0, 32.0, 5.0),
#  (319.0, 63.0, 5.0),
#  (319.0, 21.0, 3.0),
#  (319.0, 63.0, 5.0),
#  (320.0, 114.0, 5.0),
#  (321.0, 15.0, 5.0),
#  (321.0, 45.0, 5.0),
#  (321.0, 75.0, 5.0),
#  (322.0, 57.0, 3.0),
#  (323.0, 19.0, 5.0),
#  (324.0, 122.0, 0.0),
#  (324.0, 73.0, 3.0),
#  (325.0, 54.0, 3.0),
#  (325.0, 63.0, 5.0),
#  (326.0, 139.0, 5.0),
#  (327.0, 145.0, 3.0),
#  (327.0, 35.0, 0.0),
#  (328.0, 60.0, 3.0),
#  (328.0, 8.0, 5.0),
#  (329.0, 120.0, 5.0),
#  (330.0, 63.0, 5.0),
#  (331.0, 66.0, 5.0),
#  (332.0, 63.0, 5.0),
#  (332.0, 19.0, 3.0),
#  (333.0, 45.0, 5.0),
#  (334.0, 19.0, 5.0),
#  (335.0, 6.0, 5.0),
#  (336.0, 19.0, 5.0),
#  (337.0, 27.0, 3.0),
#  (337.0, 63.0, 5.0),
#  (337.0, 115.0, 5.0),
#  (337.0, 15.0, 5.0),
#  (337.0, 3.0, 5.0),
#  (337.0, 99.0, 5.0),
#  (337.0, 72.0, 5.0),
#  (337.0, 134.0, 5.0),
#  (337.0, 114.0, 3.0),
#  (338.0, 27.0, 3.0),
#  (339.0, 19.0, 5.0),
#  (340.0, 114.0, 5.0),
#  (341.0, 27.0, 5.0),
#  (341.0, 27.0, 5.0),
#  (342.0, 78.0, 5.0),
#  (343.0, 139.0, 3.0),
#  (344.0, 67.0, 5.0),
#  (345.0, 44.0, 5.0),
#  (346.0, 44.0, 5.0),
#  (346.0, 97.0, 3.0),
#  (347.0, 100.0, 5.0),
#  (348.0, 19.0, 5.0),
#  (349.0, 2.0, 5.0),
#  (349.0, 36.0, 5.0),
#  (350.0, 120.0, 3.0),
#  (351.0, 101.0, 3.0),
#  (351.0, 70.0, 5.0),
#  (351.0, 3.0, 5.0),
#  (351.0, 2.0, 3.0),
#  (352.0, 19.0, 3.0),
#  (353.0, 63.0, 5.0),
#  (354.0, 6.0, 5.0),
#  (355.0, 19.0, 3.0),
#  (356.0, 107.0, 5.0),
#  (357.0, 101.0, 5.0),
#  (358.0, 22.0, 3.0),
#  (359.0, 57.0, 3.0),
#  (359.0, 39.0, 5.0),
#  (359.0, 20.0, 5.0),
#  (360.0, 66.0, 0.0),
#  (361.0, 139.0, 5.0),
#  (362.0, 19.0, 5.0),
#  (363.0, 27.0, 5.0),
#  (363.0, 101.0, 5.0),
#  (363.0, 107.0, 5.0),
#  (364.0, 19.0, 5.0),
#  (365.0, 97.0, 3.0),
#  (366.0, 71.0, 3.0),
#  (366.0, 147.0, 5.0),
#  (367.0, 63.0, 0.0),
#  (368.0, 15.0, 5.0),
#  (369.0, 149.0, 5.0),
#  (370.0, 63.0, 5.0),
#  (371.0, 19.0, 3.0),
#  (372.0, 78.0, 5.0),
#  (373.0, 124.0, 5.0),
#  (374.0, 44.0, 3.0),
#  (375.0, 74.0, 5.0),
#  (376.0, 3.0, 5.0),
#  (377.0, 101.0, 5.0),
#  (378.0, 10.0, 5.0),
#  (378.0, 132.0, 5.0),
#  (378.0, 15.0, 3.0),
#  (378.0, 57.0, 5.0),
#  (379.0, 107.0, 5.0),
#  (379.0, 131.0, 5.0),
#  (380.0, 19.0, 5.0),
#  (380.0, 15.0, 5.0),
#  (380.0, 26.0, 5.0),
#  (381.0, 3.0, 5.0),
#  (381.0, 19.0, 3.0),
#  (382.0, 114.0, 3.0),
#  (382.0, 66.0, 3.0),
#  (383.0, 57.0, 5.0),
#  (384.0, 126.0, 5.0),
#  (384.0, 5.0, 5.0),
#  (385.0, 25.0, 5.0),
#  (386.0, 15.0, 5.0),
#  (386.0, 57.0, 5.0),
#  (387.0, 79.0, 0.0),
#  (388.0, 15.0, 5.0),
#  (389.0, 97.0, 5.0),
#  (390.0, 57.0, 3.0),
#  (390.0, 57.0, 5.0),
#  (390.0, 19.0, 5.0),
#  (390.0, 71.0, 5.0),
#  (390.0, 23.0, 5.0),
#  (390.0, 129.0, 5.0),
#  (390.0, 57.0, 5.0),
#  (391.0, 57.0, 3.0),
#  (392.0, 114.0, 3.0),
#  (392.0, 139.0, 0.0),
#  (392.0, 101.0, 3.0),
#  (392.0, 119.0, 3.0),
#  (393.0, 7.0, 3.0),
#  (394.0, 120.0, 3.0),
#  (394.0, 104.0, 0.0),
#  (394.0, 15.0, 3.0),
#  (394.0, 33.0, 3.0),
#  (394.0, 7.0, 5.0),
#  (394.0, 63.0, 3.0),
#  (394.0, 144.0, 3.0),
#  (394.0, 48.0, 3.0),
#  (394.0, 94.0, 0.0),
#  (394.0, 13.0, 3.0),
#  (394.0, 63.0, 5.0),
#  (394.0, 21.0, 3.0),
#  (394.0, 95.0, 3.0),
#  (394.0, 45.0, 0.0),
#  (394.0, 109.0, 3.0),
#  (394.0, 57.0, 5.0),
#  (394.0, 57.0, 0.0),
#  (394.0, 132.0, 5.0),
#  (394.0, 57.0, 0.0),
#  (394.0, 87.0, 3.0),
#  (394.0, 63.0, 3.0),
#  (394.0, 20.0, 5.0),
#  (394.0, 20.0, 3.0),
#  (394.0, 71.0, 0.0),
#  (394.0, 89.0, 3.0),
#  (394.0, 98.0, 3.0),
#  (394.0, 20.0, 5.0),
#  (395.0, 19.0, 5.0),
#  (396.0, 114.0, 0.0),
#  (397.0, 18.0, 3.0),
#  (398.0, 20.0, 5.0),
#  (399.0, 120.0, 3.0),
#  (400.0, 20.0, 5.0),
#  (401.0, 63.0, 5.0),
#  (402.0, 39.0, 5.0),
#  (403.0, 19.0, 5.0),
#  (404.0, 114.0, 5.0),
#  (405.0, 57.0, 5.0),
#  (405.0, 54.0, 3.0),
#  (406.0, 103.0, 5.0),
#  (407.0, 39.0, 3.0),
#  (408.0, 7.0, 5.0),
#  (408.0, 120.0, 5.0),
#  (409.0, 14.0, 5.0),
#  (409.0, 63.0, 5.0),
#  (409.0, 44.0, 5.0),
#  (410.0, 22.0, 0.0),
#  (410.0, 99.0, 5.0),
#  (411.0, 63.0, 5.0),
#  (411.0, 63.0, 3.0),
#  (411.0, 132.0, 3.0),
#  (412.0, 19.0, 5.0),
#  (413.0, 45.0, 3.0),
#  (413.0, 88.0, 5.0),
#  (413.0, 120.0, 5.0),
#  (413.0, 97.0, 5.0),
#  (413.0, 36.0, 3.0),
#  (413.0, 15.0, 5.0),
#  (413.0, 107.0, 3.0),
#  (413.0, 82.0, 5.0),
#  (413.0, 97.0, 5.0),
#  (413.0, 131.0, 3.0),
#  (413.0, 32.0, 3.0),
#  (413.0, 80.0, 5.0),
#  (413.0, 7.0, 5.0),
#  (413.0, 115.0, 3.0),
#  (414.0, 71.0, 0.0),
#  (415.0, 70.0, 5.0),
#  (415.0, 27.0, 5.0),
#  (416.0, 63.0, 3.0),
#  (416.0, 27.0, 3.0),
#  (417.0, 19.0, 5.0),
#  (418.0, 57.0, 3.0),
#  (418.0, 132.0, 5.0),
#  (418.0, 63.0, 3.0),
#  (418.0, 19.0, 3.0),
#  (419.0, 15.0, 5.0),
#  (420.0, 66.0, 5.0),
#  (420.0, 20.0, 5.0),
#  (420.0, 27.0, 3.0),
#  (420.0, 7.0, 5.0),
#  (420.0, 63.0, 5.0),
#  (420.0, 66.0, 5.0),
#  (421.0, 66.0, 5.0),
#  (421.0, 48.0, 5.0),
#  (421.0, 5.0, 5.0),
#  (421.0, 21.0, 5.0),
#  (421.0, 7.0, 5.0),
#  (421.0, 7.0, 5.0),
#  (421.0, 2.0, 3.0),
#  (421.0, 114.0, 3.0),
#  (421.0, 12.0, 3.0),
#  (421.0, 51.0, 5.0),
#  (421.0, 145.0, 5.0),
#  (421.0, 19.0, 3.0),
#  (421.0, 51.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 21.0, 5.0),
#  (421.0, 27.0, 3.0),
#  (421.0, 98.0, 0.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 17.0, 5.0),
#  (421.0, 63.0, 3.0),
#  (421.0, 103.0, 5.0),
#  (421.0, 100.0, 5.0),
#  (421.0, 120.0, 3.0),
#  (421.0, 106.0, 5.0),
#  (421.0, 132.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 57.0, 5.0),
#  (421.0, 140.0, 5.0),
#  (421.0, 113.0, 5.0),
#  (421.0, 113.0, 5.0),
#  (421.0, 7.0, 5.0),
#  (421.0, 49.0, 5.0),
#  (421.0, 7.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 33.0, 3.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 132.0, 5.0),
#  (421.0, 132.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 40.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 121.0, 3.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 48.0, 5.0),
#  (421.0, 18.0, 3.0),
#  (421.0, 101.0, 5.0),
#  (421.0, 132.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 48.0, 5.0),
#  (421.0, 48.0, 5.0),
#  (421.0, 38.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 76.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (421.0, 101.0, 5.0),
#  (421.0, 63.0, 5.0),
#  (422.0, 63.0, 5.0),
#  (422.0, 98.0, 5.0),
#  (422.0, 114.0, 3.0),
#  (422.0, 19.0, 5.0),
#  (423.0, 19.0, 5.0),
#  (424.0, 63.0, 5.0),
#  (425.0, 76.0, 5.0),
#  (426.0, 107.0, 5.0),
#  (427.0, 11.0, 5.0),
#  (428.0, 57.0, 5.0),
#  (429.0, 0.0, 5.0),
#  (430.0, 39.0, 5.0),
#  (431.0, 44.0, 3.0),
#  (432.0, 120.0, 5.0),
#  (432.0, 147.0, 3.0),
#  (432.0, 97.0, 5.0),
#  (432.0, 107.0, 3.0),
#  (432.0, 63.0, 3.0),
#  (433.0, 36.0, 3.0),
#  (433.0, 21.0, 3.0),
#  (434.0, 63.0, 5.0),
#  (434.0, 132.0, 5.0),
#  (435.0, 118.0, 3.0),
#  (435.0, 42.0, 5.0),
#  (435.0, 42.0, 5.0),
#  (436.0, 149.0, 5.0),
#  (437.0, 120.0, 5.0),
#  (438.0, 76.0, 5.0),
#  (438.0, 20.0, 5.0),
#  (439.0, 92.0, 5.0),
#  (440.0, 19.0, 0.0),
#  (441.0, 137.0, 5.0),
#  (441.0, 57.0, 5.0),
#  (441.0, 57.0, 5.0),
#  (442.0, 59.0, 5.0),
#  (443.0, 123.0, 3.0),
#  (443.0, 36.0, 3.0),
#  (443.0, 44.0, 3.0),
#  (444.0, 61.0, 5.0),
#  (445.0, 101.0, 5.0),
#  (446.0, 97.0, 5.0),
#  (446.0, 27.0, 3.0),
#  (447.0, 136.0, 5.0),
#  (448.0, 88.0, 5.0),
#  (448.0, 106.0, 5.0),
#  (448.0, 122.0, 3.0),
#  (448.0, 63.0, 5.0),
#  (448.0, 36.0, 5.0),
#  (448.0, 120.0, 5.0),
#  (449.0, 106.0, 5.0),
#  (449.0, 106.0, 5.0),
#  (450.0, 114.0, 5.0),
#  (451.0, 139.0, 5.0),
#  (451.0, 96.0, 0.0),
#  (452.0, 145.0, 0.0),
#  (453.0, 36.0, 5.0),
#  (454.0, 22.0, 0.0),
#  (455.0, 41.0, 5.0),
#  (456.0, 10.0, 5.0),
#  (457.0, 10.0, 5.0),
#  (458.0, 39.0, 5.0),
#  (458.0, 50.0, 5.0),
#  (458.0, 120.0, 3.0),
#  (458.0, 15.0, 5.0),
#  (459.0, 57.0, 0.0),
#  (460.0, 19.0, 5.0),
#  (460.0, 21.0, 3.0),
#  (461.0, 66.0, 5.0),
#  (462.0, 79.0, 5.0),
#  (463.0, 10.0, 5.0),
#  (463.0, 98.0, 0.0),
#  (464.0, 45.0, 3.0),
#  (465.0, 43.0, 3.0),
#  (466.0, 22.0, 5.0),
#  (467.0, 79.0, 3.0),
#  (468.0, 148.0, 5.0),
#  (468.0, 145.0, 5.0),
#  (469.0, 19.0, 5.0),
#  (470.0, 3.0, 5.0),
#  (471.0, 19.0, 5.0),
#  (472.0, 114.0, 5.0),
#  (473.0, 21.0, 5.0),
#  (474.0, 19.0, 5.0),
#  (475.0, 71.0, 5.0),
#  (476.0, 21.0, 0.0),
#  (477.0, 64.0, 5.0),
#  (477.0, 143.0, 3.0),
#  (477.0, 102.0, 5.0),
#  (477.0, 36.0, 3.0),
#  (477.0, 135.0, 5.0),
#  (477.0, 140.0, 5.0),
#  (477.0, 116.0, 5.0),
#  (477.0, 90.0, 5.0),
#  (478.0, 11.0, 3.0),
#  (479.0, 54.0, 5.0),
#  (480.0, 18.0, 5.0),
#  (481.0, 27.0, 5.0),
#  (482.0, 41.0, 5.0),
#  (483.0, 99.0, 5.0),
#  (484.0, 17.0, 5.0),
#  (485.0, 146.0, 5.0),
#  (485.0, 120.0, 5.0),
#  (485.0, 106.0, 0.0),
#  (485.0, 145.0, 5.0),
#  (486.0, 15.0, 5.0),
#  (487.0, 63.0, 3.0),
#  (487.0, 132.0, 3.0),
#  (488.0, 20.0, 3.0),
#  (489.0, 44.0, 3.0),
#  (490.0, 52.0, 5.0),
#  (490.0, 7.0, 5.0),
#  (491.0, 68.0, 0.0),
#  (491.0, 20.0, 5.0),
#  (491.0, 2.0, 3.0),
#  (492.0, 43.0, 3.0),
#  (493.0, 80.0, 3.0),
#  (493.0, 5.0, 3.0),
#  (493.0, 63.0, 3.0),
#  (494.0, 79.0, 5.0),
#  (494.0, 21.0, 5.0),
#  (495.0, 15.0, 5.0),
#  (496.0, 39.0, 5.0),
#  (497.0, 30.0, 5.0),
#  (497.0, 120.0, 3.0),
#  (498.0, 7.0, 5.0),
#  (499.0, 36.0, 3.0),
#  (499.0, 22.0, 3.0),
#  (500.0, 75.0, 3.0),
#  (500.0, 19.0, 5.0),
#  (500.0, 19.0, 5.0),
#  (500.0, 35.0, 5.0),
#  (500.0, 32.0, 5.0),
#  (501.0, 18.0, 3.0),
#  (502.0, 19.0, 5.0),
#  (503.0, 63.0, 5.0),
#  (503.0, 63.0, 3.0),
#  (503.0, 57.0, 5.0),
#  (503.0, 63.0, 3.0),
#  (503.0, 25.0, 3.0),
#  (504.0, 45.0, 5.0),
#  (505.0, 18.0, 3.0),
#  (505.0, 15.0, 5.0),
#  (505.0, 99.0, 5.0),
#  (506.0, 127.0, 5.0),
#  (507.0, 19.0, 0.0),
#  (508.0, 132.0, 5.0),
#  (509.0, 79.0, 5.0),
#  (510.0, 114.0, 0.0),
#  (511.0, 7.0, 5.0),
#  (511.0, 99.0, 5.0),
#  (511.0, 43.0, 3.0),
#  (511.0, 15.0, 5.0),
#  (511.0, 97.0, 5.0),
#  (511.0, 20.0, 5.0),
#  ...]

# %%
ncf = cornac.models.recommender.Recommender('NeuMF')
ncf.early_stop
# Out:
# <bound method Recommender.early_stop of <cornac.models.recommender.Recommender object at 0x7f2a7aeb1b90>>

# %%
# Instantiate evaluation metrics
ndcg = cornac.metrics.NDCG(k=TOP_K)
pre = cornac.metrics.Precision(k=TOP_K)
rec = cornac.metrics.Recall(k=TOP_K)
fm = cornac.metrics.FMeasure(k=TOP_K)

# %%
#Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=data,
    test_size=0.1,
    val_size=0.1,
    rating_threshold=1.0,
    seed=123,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_neg=50,
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

# RandomSearch
rs_neumf = RandomSearch(
    model = neumf,
    space=[
        Discrete("num_epochs", [50, 100, 150, 200]),
        Discrete("num_factors", [4, 8]),
        Discrete("batch_size", [128, 256, 512]),
        Continuous("lr", 0.001, 0.01)
    ],
    metric = fm,
    eval_method = ratio_split
)
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 512
# Number of items = 144
# Number of ratings = 878
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 4.0
# ---
# Test data:
# Number of users = 52
# Number of items = 36
# Number of ratings = 71
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Validation data:
# Number of users = 44
# Number of items = 38
# Number of ratings = 64
# ---
# Total users = 512
# Total items = 144

# %%
# Put everything together into an experiment and run it
cornac.Experiment(
    eval_method=ratio_split,
    models=[rs_neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# [RandomSearch_NeuMF] Training started!
# Evaluating: {'batch_size': 512, 'lr': 0.007416597884709045, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 24, stopped epoch = 29
# - best monitored value = 0.398567 (delta = -0.001529)
# Evaluating: {'batch_size': 512, 'lr': 0.005961832921746022, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 31, stopped epoch = 36
# - best monitored value = 0.398088 (delta = -0.001490)
# Evaluating: {'batch_size': 256, 'lr': 0.00982687778546154, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 10, stopped epoch = 15
# - best monitored value = 0.399233 (delta = -0.028312)
# Evaluating: {'batch_size': 512, 'lr': 0.002259556863673461, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 23, stopped epoch = 28
# - best monitored value = 0.375299 (delta = -0.020451)
# Evaluating: {'batch_size': 128, 'lr': 0.0075614473664563754, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 7, stopped epoch = 12
# - best monitored value = 0.393194 (delta = -0.002268)
# Evaluating: {'batch_size': 256, 'lr': 0.007252796594667422, 'num_epochs': 50, 'num_factors': 4}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 18, stopped epoch = 23
# - best monitored value = 0.398074 (delta = -0.025760)
# Evaluating: {'batch_size': 256, 'lr': 0.0026424255740815, 'num_epochs': 150, 'num_factors': 4}
#   0%|          | 0/150 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 19, stopped epoch = 24
# - best monitored value = 0.346058 (delta = -0.000846)
# Evaluating: {'batch_size': 512, 'lr': 0.0057864482838717955, 'num_epochs': 50, 'num_factors': 8}
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 26, stopped epoch = 31
# - best monitored value = 0.399326 (delta = -0.001558)
# Evaluating: {'batch_size': 128, 'lr': 0.005428762991131081, 'num_epochs': 200, 'num_factors': 4}
#   0%|          | 0/200 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 12, stopped epoch = 17
# - best monitored value = 0.395072 (delta = -0.043144)
# Evaluating: {'batch_size': 128, 'lr': 0.007501990443131995, 'num_epochs': 100, 'num_factors': 8}
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early stopping:
# - best epoch = 6, stopped epoch = 11
# - best monitored value = 0.393519 (delta = -0.030852)
# Best parameter settings: {'batch_size': 512, 'lr': 0.007416597884709045, 'num_epochs': 150, 'num_factors': 4}
# F1@5 = 0.1120
#
# [RandomSearch_NeuMF] Evaluation started!
# Ranking:   0%|          | 0/52 [00:00<?, ?it/s]
# Ranking:   0%|          | 0/44 [00:00<?, ?it/s]
# VALIDATION:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Time (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------
# RandomSearch_NeuMF | 0.1120 | 0.2381 |      0.0732 |   0.2813 |   0.1168
#
# TEST:
# ...
#                    |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ------------------ + ------ + ------ + ----------- + -------- + --------- + --------
# RandomSearch_NeuMF | 0.1574 | 0.3148 |      0.1020 |   0.4020 |  217.4383 |   0.1306

# %%
print('Random search: ', rs_neumf.best_params)
# Out:
# Random search:  {'batch_size': 512, 'lr': 0.007416597884709045, 'num_epochs': 150, 'num_factors': 4}

# %%
ratio_split = RatioSplit(
    data=data,
    test_size=0,
    rating_threshold=1.0,
    verbose=True,
)

neumf = cornac.models.NeuMF(
    num_factors = rs_neumf.best_params['num_factors'],
    layers=[64, 32, 16, 8],
    act_fn="tanh",
    learner="adam",
    num_epochs = rs_neumf.best_params['num_epochs'],
    lr=rs_neumf.best_params['lr'],
    num_neg=50,
    batch_size = rs_neumf.best_params['batch_size'],
    seed=123,
    early_stopping = {'min_delta':0.0, 'patience':5}
)

cornac.Experiment(
    eval_method=ratio_split,
    models=[neumf],
    metrics=[ndcg, pre, rec, fm],
).run()
# Out:
# rating_threshold = 1.0
# exclude_unknowns = True
# ---
# Training data:
# Number of users = 600
# Number of items = 151
# Number of ratings = 1076
# Max rating = 5.0
# Min rating = 0.0
# Global mean = 4.0
# ---
# Test data:
# Number of users = 600
# Number of items = 151
# Number of ratings = 1076
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 600
# Total items = 151
#
# [NeuMF] Training started!
#   0%|          | 0/150 [00:00<?, ?it/s]
# [NeuMF] Evaluation started!
# Ranking:   0%|          | 0/600 [00:00<?, ?it/s]
# TEST:
# ...
#       |   F1@5 | NDCG@5 | Precision@5 | Recall@5 | Train (s) | Test (s)
# ----- + ------ + ------ + ----------- + -------- + --------- + --------
# NeuMF | 0.3264 | 0.6852 |      0.2233 |   0.8207 |  169.4952 |   0.9067

# %%
# import pandas as pd
# pred_user = pd.read_csv('../../common/data/survey_result.csv')
# pred_user = set(pred_user['u_id'])

# %%
all_prediction = pd.DataFrame(columns=['u_id','p_id','ncf_score'])

for u_idx, u_id in tqdm(enumerate(data_df['u_id'].unique())):
  
      tmp = pd.DataFrame(neumf.rank(u_idx)).T
      tmp['u_id'] = u_id
      tmp = pd.DataFrame(tmp,columns=['u_id',0,1])
      tmp.rename(columns={0:'p_id',1:'ncf_score'}, inplace=True)
      all_prediction = all_prediction.append(tmp)
# Out:
# 600it [00:05, 115.57it/s]

# %%
all_prediction
# Out:
#     u_id   p_id  ncf_score
# 0      0    0.0   0.841922
# 1      0    3.0   0.096870
# 2      0   24.0   0.000529
# 3      0   20.0   0.774802
# 4      0   19.0   0.000003
# ..   ...    ...        ...
# 146  599   77.0   0.010165
# 147  599   87.0   0.000089
# 148  599   86.0   0.000352
# 149  599  100.0   0.000021
# 150  599  107.0   0.000391
#
# [90600 rows x 3 columns]

# %%
len(all_prediction['u_id']==107)
# Out:
# 90600

# %%
all_prediction.to_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/광진구_cafe_ncf_scores.csv',index=False)

# %%
a = pd.DataFrame(neumf.rank(1)).T
a
# Out:
#          0             1
# 0      0.0  6.597291e-01
# 1      3.0  2.389422e-02
# 2     24.0  2.823949e-03
# 3     25.0  2.843435e-01
# 4     10.0  4.538894e-05
# ..     ...           ...
# 146  101.0  3.650784e-05
# 147  100.0  8.940697e-08
# 148   66.0  4.466616e-05
# 149  132.0  2.462643e-08
# 150  122.0  3.126443e-06
#
# [151 rows x 2 columns]

# %%
len(a.iloc[:,0].unique())
# Out:
# 151

# %%
# a = pd.DataFrame(neumf.rank(2)).T
# a

# %%
len(a.iloc[:,0].unique())
# Out:
# 151

# %%
a.to_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_cafe_exxxx2')

# %%
from keras.models import load_model

ncf.save('/content/drive/MyDrive/Colab Notebooks/data/광진구_cafe_ncf_eat2.h5')
# Out:
# Using TensorFlow backend.
# '/content/drive/MyDrive/Colab Notebooks/data/광진구_cafe_ncf_eat2.h5/NeuMF/2022-07-19_12-23-01-610330.pkl'
