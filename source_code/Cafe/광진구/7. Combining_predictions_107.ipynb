# %%
import pandas as pd
import numpy as np

# %%
user_id = int(input('user id : '))
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# Out:
# user id : 107

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
eat_info =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/광진구_cafe_info.csv')
cbf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/광진구_cafe_'+str(user_id)+'_cbf.csv')
ncf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/광진구_cafe_ncf_scores.csv')

# %%
eat_info
# Out:
#      Unnamed: 0      name                           address  category  price  \
# 0             0  뚝방길 홍차가게               서울특별시 광진구 자양강변길 277  카페 / 디저트   5000
# 1             1       스미다          서울특별시 광진구 천호대로109길 18 1F  카페 / 디저트   5000
# 2             2  Daughter              서울특별시 광진구 아차산로31길 40  카페 / 디저트   5000
# 3             3    최가커피회관            서울특별시 광진구 능동로13길 30 B1  카페 / 디저트   5000
# 4             4     Index             서울특별시 광진구 아차산로 200 3F  카페 / 디저트   5000
# ..          ...       ...                               ...       ...    ...
# 146         146   메종드쁘띠푸르                서울특별시 광진구 아차산로 200  카페 / 디저트   5000
# 147         147     더파빌리온  서울특별시 광진구 워커힐로 177 그랜드 워커힐 본관 1F  카페 / 디저트  15000
# 148         148     줄리앤몰리            서울특별시 광진구 뚝섬로59길 67 1F  카페 / 디저트  15000
# 149         149   케이크를부탁해                 서울특별시 광진구 능동로 137  카페 / 디저트  15000
# 150         150      팬더스윗           서울특별시 광진구 동일로22길 117-17  카페 / 디저트  15000
#
# ...

# %%
 eat_info=eat_info[['p_id','name','address','category','price','rating']]

# %%
eat_info
# Out:
#      p_id      name                           address  category  price  \
# 0      20  뚝방길 홍차가게               서울특별시 광진구 자양강변길 277  카페 / 디저트   5000
# 1      61       스미다          서울특별시 광진구 천호대로109길 18 1F  카페 / 디저트   5000
# 2       3  Daughter              서울특별시 광진구 아차산로31길 40  카페 / 디저트   5000
# 3      99    최가커피회관            서울특별시 광진구 능동로13길 30 B1  카페 / 디저트   5000
# 4       7     Index             서울특별시 광진구 아차산로 200 3F  카페 / 디저트   5000
# ..    ...       ...                               ...       ...    ...
# 146    38   메종드쁘띠푸르                서울특별시 광진구 아차산로 200  카페 / 디저트   5000
# 147    18     더파빌리온  서울특별시 광진구 워커힐로 177 그랜드 워커힐 본관 1F  카페 / 디저트  15000
# 148    91     줄리앤몰리            서울특별시 광진구 뚝섬로59길 67 1F  카페 / 디저트  15000
# 149   125   케이크를부탁해                 서울특별시 광진구 능동로 137  카페 / 디저트  15000
# 150   137      팬더스윗           서울특별시 광진구 동일로22길 117-17  카페 / 디저트  15000
#
#       rating
# 0   4.500000
# 1   4.200000
# 2   4.200000
# 3   4.200000
# 4   4.100000
# ..       ...
# ...

# %%
cbf=cbf[['p_id','cbf_score']]
cbf
# Out:
#      p_id  cbf_score
# 0       0   0.015335
# 1       1   0.000055
# 2       2   0.000187
# 3       3   0.000034
# 4       4   0.000000
# ..    ...        ...
# 146   146   0.000000
# 147   147   0.000006
# 148   148   0.000000
# 149   149   0.000000
# 150   150   0.000000
#
# [151 rows x 2 columns]

# %%
ncf
# Out:
#        u_id       p_id  ncf_score
# 0         0   0.000000   0.841922
# 1         0   3.000000   0.096870
# 2         0  24.000000   0.000529
# 3         0  20.000000   0.774802
# 4         0  19.000000   0.000003
# ...     ...        ...        ...
# 90595   599  77.000000   0.010165
# 90596   599  87.000000   0.000089
# 90597   599  86.000000   0.000352
# 90598   599 100.000000   0.000021
# 90599   599 107.000000   0.000391
#
# [90600 rows x 3 columns]

# %%
ncf=ncf[ncf['u_id']==107]

# %%
ncf
# Out:
#        u_id       p_id  ncf_score
# 16157   107  80.000000   0.009198
# 16158   107   5.000000   0.003432
# 16159   107  72.000000   0.047119
# 16160   107  11.000000   0.020400
# 16161   107  41.000000   0.014471
# ...     ...        ...        ...
# 16303   107 117.000000   0.000242
# 16304   107 106.000000   0.000214
# 16305   107 110.000000   0.006066
# 16306   107  66.000000   0.000457
# 16307   107 125.000000   0.001770
#
# [151 rows x 3 columns]

# %%
df=pd.merge(eat_info, cbf, left_on='p_id', right_on ='p_id',how ='left')
df=pd.merge(df, ncf, left_on='p_id', right_on ='p_id',how ='left')
df
# Out:
#      p_id      name                           address  category  price  \
# 0      20  뚝방길 홍차가게               서울특별시 광진구 자양강변길 277  카페 / 디저트   5000
# 1      61       스미다          서울특별시 광진구 천호대로109길 18 1F  카페 / 디저트   5000
# 2       3  Daughter              서울특별시 광진구 아차산로31길 40  카페 / 디저트   5000
# 3      99    최가커피회관            서울특별시 광진구 능동로13길 30 B1  카페 / 디저트   5000
# 4       7     Index             서울특별시 광진구 아차산로 200 3F  카페 / 디저트   5000
# ..    ...       ...                               ...       ...    ...
# 146    38   메종드쁘띠푸르                서울특별시 광진구 아차산로 200  카페 / 디저트   5000
# 147    18     더파빌리온  서울특별시 광진구 워커힐로 177 그랜드 워커힐 본관 1F  카페 / 디저트  15000
# 148    91     줄리앤몰리            서울특별시 광진구 뚝섬로59길 67 1F  카페 / 디저트  15000
# 149   125   케이크를부탁해                 서울특별시 광진구 능동로 137  카페 / 디저트  15000
# 150   137      팬더스윗           서울특별시 광진구 동일로22길 117-17  카페 / 디저트  15000
#
#       rating  cbf_score  u_id  ncf_score
# 0   4.500000   0.000058   107   0.000938
# ...

# %%
df['result'] = df['cbf_score'] * df['ncf_score']

# %%
df.sort_values('result',ascending = False).head(10)
# Out:
#      p_id       name                       address  category  price   rating  \
# 128     0  180커피로스터스            서울특별시 광진구 아차산로 200  카페 / 디저트   5000      NaN
# 59     28     레스트인무드      서울특별시 광진구 천호대로134길 31 1F  카페 / 디저트   5000      NaN
# 27     25      라이트레인  서울특별시 광진구 아차산로 200 커먼그라운드 3F  카페 / 디저트   5000 3.300000
# 9      21       띵똥와플           서울특별시 광진구 능동로13길 10  카페 / 디저트   5000 3.900000
# 11     11        고망고        서울특별시 광진구 아차산로30길 8 1F  카페 / 디저트   5000 3.900000
# 65      6     Ffanci             서울특별시 광진구 동일로 411  카페 / 디저트   5000      NaN
# 13     97       체리커피             서울특별시 광진구 능동로 284  카페 / 디저트   5000 3.800000
# 37     67    아비앙또플라워        서울특별시 광진구 뚝섬로44길 56 1F  카페 / 디저트   5000      NaN
# 97     42        무궁화            서울특별시 광진구 동일로20길 8  카페 / 디저트   5000      NaN
# 106    27       랑데자뷰           서울특별시 광진구 아차산로31길 3  카페 / 디저트   5000      NaN
#
#      cbf_score  u_id  ncf_score   result
# 128   0.015335   107   0.018503 0.000284
# ...
