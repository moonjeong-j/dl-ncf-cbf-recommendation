# %%
import pandas as pd
import numpy as np

# %%
user_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/normalized_user_matrix.csv')
place_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/normalized_item_matrix.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
user_df
# Out:
#       u_id         0    1         2         3         4         5         6  \
# 0      715  0.003708  0.0  0.000000  0.000000  0.000000  0.006593  0.000000
# 1      453  0.000399  0.0  0.007130  0.005306  0.003291  0.002840  0.046403
# 2     1080  0.001781  0.0  0.000000  0.003944  0.000000  0.002111  0.043114
# 3     1479  0.002209  0.0  0.000000  0.009783  0.000000  0.000000  0.010694
# 4      954  0.001906  0.0  0.010748  0.002000  0.002480  0.002141  0.032061
# ...    ...       ...  ...       ...       ...       ...       ...       ...
# 1725   537  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.366549
# 1726  1597  0.006059  0.0  0.000000  0.000000  0.000000  0.010774  0.088014
# 1727   603  0.003497  0.0  0.000000  0.000000  0.000000  0.000000  0.050797
# 1728   655  0.007016  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1729    58  0.004087  0.0  0.000000  0.000000  0.000000  0.000000  0.059367
#
# ...

# %%
del user_df['u_id']

del place_df['p_id']

# %%
user_df.reset_index(inplace=True, drop =True)
user_df
# Out:
#              0    1         2         3         4         5         6  \
# 0     0.003708  0.0  0.000000  0.000000  0.000000  0.006593  0.000000
# 1     0.000399  0.0  0.007130  0.005306  0.003291  0.002840  0.046403
# 2     0.001781  0.0  0.000000  0.003944  0.000000  0.002111  0.043114
# 3     0.002209  0.0  0.000000  0.009783  0.000000  0.000000  0.010694
# 4     0.001906  0.0  0.010748  0.002000  0.002480  0.002141  0.032061
# ...        ...  ...       ...       ...       ...       ...       ...
# 1725  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.366549
# 1726  0.006059  0.0  0.000000  0.000000  0.000000  0.010774  0.088014
# 1727  0.003497  0.0  0.000000  0.000000  0.000000  0.000000  0.050797
# 1728  0.007016  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1729  0.004087  0.0  0.000000  0.000000  0.000000  0.000000  0.059367
#
#              7         8    9  ...       110       111       112  113  \
# ...

# %%
user_1 = user_df[107:108].T

# %%
user_1
# Out:
#           107
# 0    0.009164
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.037757
# ..        ...
# 115  0.000000
# 116  0.000000
# 117  0.000000
# 118  0.000000
# 119  0.000000
#
# [120 rows x 1 columns]

# %%
place_df
# Out:
#             0    1         2         3         4         5         6  \
# 0    0.004189  0.0  0.001046  0.014595  0.004586  0.003021  0.002978
# 1    0.003020  0.0  0.006805  0.002143  0.006040  0.001147  0.033644
# 2    0.002676  0.0  0.010387  0.002319  0.003835  0.002069  0.055770
# 3    0.002010  0.0  0.002393  0.002226  0.001657  0.001668  0.064242
# 4    0.002587  0.0  0.000000  0.010312  0.000000  0.003680  0.000000
# ..        ...  ...       ...       ...       ...       ...       ...
# 841  0.002642  0.0  0.000000  0.001950  0.019353  0.003132  0.089549
# 842  0.002224  0.0  0.006618  0.007388  0.006109  0.003954  0.172296
# 843  0.002088  0.0  0.000000  0.006935  0.008602  0.000000  0.015163
# 844  0.017691  0.0  0.000000  0.000000  0.000000  0.000000  0.085657
# 845  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.130582
#
#             7         8         9  ...       110       111       112  113  \
# ...

# %%
result = np.dot(place_df, user_1) #user_1

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)
result
# Out:
# array([[1.96029327e-02],
#        [6.17755764e-02],
#        [2.17210036e-02],
#        [1.00872617e-02],
#        [3.59227125e-02],
#        [2.16175215e-02],
#        [2.76769959e-02],
#        [8.83035176e-03],
#        [1.61646788e-02],
#        [3.00888856e-02],
#        [5.43158530e-02],
#        [2.22177915e-02],
#        [1.31905661e-02],
#        [9.38521616e-02],
#        [8.45318603e-02],
#        [3.40667765e-02],
#        [3.00415400e-02],
#        [2.00912835e-02],
#        [6.06359959e-02],
#        [3.15863851e-02],
#        [2.59847002e-02],
#        [4.98706226e-03],
#        [7.24152235e-02],
#        [3.00966744e-02],
#        [1.14494963e-02],
#        [2.29110420e-02],
#        [8.02992065e-03],
#        [2.67655569e-02],
#        [3.18638416e-02],
#        [1.65450313e-02],
#        [6.39097295e-02],
#        [1.21011129e-02],
#        [5.39142168e-02],
#        [1.03277789e-02],
#        [3.18782101e-02],
#        [6.64598286e-03],
#        [8.72394600e-03],
# ...

# %%
df = pd.DataFrame(data=result, columns=["preference"])
df
# Out:
#      preference
# 0      0.019603
# 1      0.061776
# 2      0.021721
# 3      0.010087
# 4      0.035923
# ..          ...
# 841    0.022984
# 842    0.014211
# 843    0.004357
# 844    0.009445
# 845    0.013839
#
# [846 rows x 1 columns]

# %%
place_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/normalized_item_matrix.csv')
place_df['preference'] = result

# %%
# place_df.sort_value()

# %%
place_df.sort_values(by=['preference'], axis=0, ascending=False, inplace=True)

# %%
place_df
# Out:
#      p_id         0    1    2         3    4    5         6    7    8  ...  \
# 378   200  0.003962  0.0  0.0  0.000000  0.0  0.0  0.000000  0.0  0.0  ...
# 214   662  0.000000  0.0  0.0  0.000000  0.0  0.0  0.000000  0.0  0.0  ...
# 829   788  0.000000  0.0  0.0  0.000000  0.0  0.0  0.000000  0.0  0.0  ...
# 185   630  0.005972  0.0  0.0  0.000000  0.0  0.0  0.086746  0.0  0.0  ...
# 442   310  0.003397  0.0  0.0  0.007523  0.0  0.0  0.148033  0.0  0.0  ...
# ..    ...       ...  ...  ...       ...  ...  ...       ...  ...  ...  ...
# 514   212  0.000000  0.0  0.0  0.000000  0.0  0.0  0.092010  0.0  0.0  ...
# 73    155  0.000000  0.0  0.0  0.000000  0.0  0.0  0.000000  0.0  0.0  ...
# 655   539  0.000000  0.0  0.0  0.000000  0.0  0.0  0.000000  0.0  0.0  ...
# 370   622  0.000000  0.0  0.0  0.000000  0.0  0.0  0.069028  0.0  0.0  ...
# 781   372  0.000000  0.0  0.0  0.000000  0.0  0.0  1.000000  0.0  0.0  ...
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index  preference
# 0        0    0.019603
# 1        1    0.061776
# 2        2    0.021721
# 3        3    0.010087
# 4        4    0.035923
# ..     ...         ...
# 841    841    0.022984
# 842    842    0.014211
# 843    843    0.004357
# 844    844    0.009445
# 845    845    0.013839
#
# [846 rows x 2 columns]

# %%
ex = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/exxxx2')

# %%
ex
# Out:
#      Unnamed: 0      0         1
# 0             0   43.0  0.747401
# 1             1  220.0  0.413094
# 2             2  102.0  0.166350
# 3             3  222.0  0.000112
# 4             4  327.0  0.078526
# ..          ...    ...       ...
# 839         839  191.0  0.002421
# 840         840  367.0  0.000101
# 841         841  419.0  0.522728
# 842         842  242.0  0.000001
# 843         843  202.0  0.042925
#
# [844 rows x 3 columns]

# %%
del ex['Unnamed: 0']

# %%
a=pd.merge(df,ex,left_on='index',right_on ='0', how='left' )
a
# Out:
#      index  preference      0         1
# 0        0    0.019603    0.0  0.019531
# 1        1    0.061776    1.0  0.038946
# 2        2    0.021721    2.0  0.003209
# 3        3    0.010087    3.0  0.009525
# 4        4    0.035923    4.0  0.015847
# ..     ...         ...    ...       ...
# 841    841    0.022984  841.0  0.533918
# 842    842    0.014211  842.0  0.001475
# 843    843    0.004357  843.0  0.005713
# 844    844    0.009445    NaN       NaN
# 845    845    0.013839    NaN       NaN
#
# [846 rows x 4 columns]

# %%
del a['0']

# %%
a['cbf_score']=a['preference']*a['1']
a
# Out:
#      index  preference         1  cbf_score
# 0        0    0.019603  0.019531   0.000383
# 1        1    0.061776  0.038946   0.002406
# 2        2    0.021721  0.003209   0.000070
# 3        3    0.010087  0.009525   0.000096
# 4        4    0.035923  0.015847   0.000569
# ..     ...         ...       ...        ...
# 841    841    0.022984  0.533918   0.012272
# 842    842    0.014211  0.001475   0.000021
# 843    843    0.004357  0.005713   0.000025
# 844    844    0.009445       NaN        NaN
# 845    845    0.013839       NaN        NaN
#
# [846 rows x 4 columns]

# %%
a.rename(columns={'index':'p_id'}, inplace=True)

# %%
a=a[['p_id', 'cbf_score']]

# %%
a
# Out:
#      p_id  cbf_score
# 0       0   0.000383
# 1       1   0.002406
# 2       2   0.000070
# 3       3   0.000096
# 4       4   0.000569
# ..    ...        ...
# 841   841   0.012272
# 842   842   0.000021
# 843   843   0.000025
# 844   844        NaN
# 845   845        NaN
#
# [846 rows x 2 columns]

# %%
pd.DataFrame(a).to_csv('/content/drive/MyDrive/Colab Notebooks/data/prediction/107_cbf.csv')
